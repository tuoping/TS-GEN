# %%
from mdgen.model.gemnet.gemnet import GemNetT
# Out:
# MODELS_PROJECT_ROOT: /home/tuoping/odefed_mdgen/odefed_mdgen/mdgen

# %%
from mdgen.model.gemnet.layers.embedding_block import AtomEmbedding

# %%
device = "cuda:0"
def get_model(**kwargs) -> GemNetT:
    return GemNetT(
        atom_embedding=AtomEmbedding(emb_size=4),
        num_targets=1,
        latent_dim=4,
        num_radial=4,
        num_blocks=1,
        emb_size_atom=4,
        emb_size_edge=4,
        emb_size_trip=4,
        emb_size_bil_trip=4,
        otf_graph=True,
        scale_file=f"mdgen/model/gemnet/gemnet-dT.json",
        **kwargs,
    ).to(device)

# %%
model = get_model(
    max_neighbors=20,
    cutoff=7.0,
    # regress stress in a non-conservative way
    regress_stress=True,
    max_cell_images_per_dim=20,
)

# %%
model.eval()
# Out:
# GemNetT(
#   (angle_edge_emb): Sequential(
#     (0): Linear(in_features=7, out_features=4, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=4, out_features=4, bias=True)
#   )
#   (radial_basis): RadialBasis(
#     (envelope): PolynomialEnvelope()
#     (rbf): GaussianSmearing()
#   )
#   (cbf_basis3): CircularBasisLayer(
#     (radial_basis): RadialBasis(
#       (envelope): PolynomialEnvelope()
#       (rbf): GaussianSmearing()
#     )
#   )
#   (lattice_out_blocks): ModuleList(
#     (0-1): 2 x RBFBasedLatticeUpdateBlockFrac(
#       (mlp): Sequential(
#         (0): Dense(
#           (linear): Linear(in_features=4, out_features=4, bias=False)
#           (_activation): ScaledSiLU(
#             (_activation): SiLU()
#           )
#         )
#         (1): Dense(
#           (linear): Linear(in_features=4, out_features=4, bias=False)
#           (_activation): Identity()
#         )
#       )
#       (dense_rbf_F): Dense(
#         (linear): Linear(in_features=16, out_features=4, bias=False)
#         (_activation): Identity()
#       )
#       (out_forces): Dense(
#         (linear): Linear(in_features=4, out_features=1, bias=False)
#         (_activation): Identity()
#       )
#     )
#   )
#   (mlp_rbf_lattice): Dense(
#     (linear): Linear(in_features=4, out_features=16, bias=False)
#     (_activation): Identity()
#   )
#   (mlp_rbf3): Dense(
#     (linear): Linear(in_features=4, out_features=16, bias=False)
#     (_activation): Identity()
#   )
#   (mlp_cbf3): EfficientInteractionDownProjection()
#   (mlp_rbf_h): Dense(
#     (linear): Linear(in_features=4, out_features=16, bias=False)
#     (_activation): Identity()
#   )
#   (mlp_rbf_out): Dense(
#     (linear): Linear(in_features=4, out_features=16, bias=False)
#     (_activation): Identity()
#   )
#   (atom_emb): AtomEmbedding(
#     (embeddings): Embedding(100, 4)
#   )
#   (atom_latent_emb): Linear(in_features=8, out_features=4, bias=True)
#   (edge_emb): EdgeEmbedding(
#     (dense): Dense(
#       (linear): Linear(in_features=12, out_features=4, bias=False)
#       (_activation): ScaledSiLU(
#         (_activation): SiLU()
#       )
#     )
#   )
#   (out_blocks): ModuleList(
#     (0-1): 2 x OutputBlock(
#       (dense_rbf): Dense(
#         (linear): Linear(in_features=16, out_features=4, bias=False)
#         (_activation): Identity()
#       )
#       (scale_sum): ScalingFactor()
#       (layers): ModuleList(
#         (0): Dense(
#           (linear): Linear(in_features=4, out_features=4, bias=False)
#           (_activation): ScaledSiLU(
#             (_activation): SiLU()
#           )
#         )
#         (1-3): 3 x ResidualLayer(
#           (dense_mlp): Sequential(
#             (0): Dense(
#               (linear): Linear(in_features=4, out_features=4, bias=False)
#               (_activation): ScaledSiLU(
#                 (_activation): SiLU()
#               )
#             )
#             (1): Dense(
#               (linear): Linear(in_features=4, out_features=4, bias=False)
#               (_activation): ScaledSiLU(
#                 (_activation): SiLU()
#               )
#             )
#           )
#         )
#       )
#       (seq_energy): ModuleList(
#         (0): Dense(
#           (linear): Linear(in_features=4, out_features=4, bias=False)
#           (_activation): ScaledSiLU(
#             (_activation): SiLU()
#           )
#         )
#         (1-3): 3 x ResidualLayer(
#           (dense_mlp): Sequential(
#             (0): Dense(
#               (linear): Linear(in_features=4, out_features=4, bias=False)
#               (_activation): ScaledSiLU(
#                 (_activation): SiLU()
#               )
#             )
#             (1): Dense(
#               (linear): Linear(in_features=4, out_features=4, bias=False)
#               (_activation): ScaledSiLU(
#                 (_activation): SiLU()
#               )
#             )
#           )
#         )
#       )
#       (out_energy): Dense(
#         (linear): Linear(in_features=4, out_features=1, bias=False)
#         (_activation): Identity()
#       )
#       (scale_rbf_F): ScalingFactor()
#       (seq_forces): ModuleList(
#         (0): Dense(
#           (linear): Linear(in_features=4, out_features=4, bias=False)
#           (_activation): ScaledSiLU(
#             (_activation): SiLU()
#           )
#         )
#         (1-3): 3 x ResidualLayer(
#           (dense_mlp): Sequential(
#             (0): Dense(
#               (linear): Linear(in_features=4, out_features=4, bias=False)
#               (_activation): ScaledSiLU(
#                 (_activation): SiLU()
#               )
#             )
#             (1): Dense(
#               (linear): Linear(in_features=4, out_features=4, bias=False)
#               (_activation): ScaledSiLU(
#                 (_activation): SiLU()
#               )
#             )
#           )
#         )
#       )
#       (out_forces): Dense(
#         (linear): Linear(in_features=4, out_features=1, bias=False)
#         (_activation): Identity()
#       )
#       (dense_rbf_F): Dense(
#         (linear): Linear(in_features=16, out_features=4, bias=False)
#         (_activation): Identity()
#       )
#     )
#   )
#   (int_blocks): ModuleList(
#     (0): InteractionBlockTripletsOnly(
#       (dense_ca): Dense(
#         (linear): Linear(in_features=4, out_features=4, bias=False)
#         (_activation): ScaledSiLU(
#           (_activation): SiLU()
#         )
#       )
#       (trip_interaction): TripletInteraction(
#         (dense_ba): Dense(
#           (linear): Linear(in_features=4, out_features=4, bias=False)
#           (_activation): ScaledSiLU(
#             (_activation): SiLU()
#           )
#         )
#         (mlp_rbf): Dense(
#           (linear): Linear(in_features=16, out_features=4, bias=False)
#           (_activation): Identity()
#         )
#         (scale_rbf): ScalingFactor()
#         (mlp_cbf): EfficientInteractionBilinear()
#         (scale_cbf_sum): ScalingFactor()
#         (down_projection): Dense(
#           (linear): Linear(in_features=4, out_features=4, bias=False)
#           (_activation): ScaledSiLU(
#             (_activation): SiLU()
#           )
#         )
#         (up_projection_ca): Dense(
#           (linear): Linear(in_features=4, out_features=4, bias=False)
#           (_activation): ScaledSiLU(
#             (_activation): SiLU()
#           )
#         )
#         (up_projection_ac): Dense(
#           (linear): Linear(in_features=4, out_features=4, bias=False)
#           (_activation): ScaledSiLU(
#             (_activation): SiLU()
#           )
#         )
#       )
#       (layers_before_skip): ModuleList(
#         (0): ResidualLayer(
#           (dense_mlp): Sequential(
#             (0): Dense(
#               (linear): Linear(in_features=4, out_features=4, bias=False)
#               (_activation): ScaledSiLU(
#                 (_activation): SiLU()
#               )
#             )
#             (1): Dense(
#               (linear): Linear(in_features=4, out_features=4, bias=False)
#               (_activation): ScaledSiLU(
#                 (_activation): SiLU()
#               )
#             )
#           )
#         )
#       )
#       (layers_after_skip): ModuleList(
#         (0-1): 2 x ResidualLayer(
#           (dense_mlp): Sequential(
#             (0): Dense(
#               (linear): Linear(in_features=4, out_features=4, bias=False)
#               (_activation): ScaledSiLU(
#                 (_activation): SiLU()
#               )
#             )
#             (1): Dense(
#               (linear): Linear(in_features=4, out_features=4, bias=False)
#               (_activation): ScaledSiLU(
#                 (_activation): SiLU()
#               )
#             )
#           )
#         )
#       )
#       (atom_update): AtomUpdateBlock(
#         (dense_rbf): Dense(
#           (linear): Linear(in_features=16, out_features=4, bias=False)
#           (_activation): Identity()
#         )
#         (scale_sum): ScalingFactor()
#         (layers): ModuleList(
#           (0): Dense(
#             (linear): Linear(in_features=4, out_features=4, bias=False)
#             (_activation): ScaledSiLU(
#               (_activation): SiLU()
#             )
#           )
#           (1-3): 3 x ResidualLayer(
#             (dense_mlp): Sequential(
#               (0): Dense(
#                 (linear): Linear(in_features=4, out_features=4, bias=False)
#                 (_activation): ScaledSiLU(
#                   (_activation): SiLU()
#                 )
#               )
#               (1): Dense(
#                 (linear): Linear(in_features=4, out_features=4, bias=False)
#                 (_activation): ScaledSiLU(
#                   (_activation): SiLU()
#                 )
#               )
#             )
#           )
#         )
#       )
#       (concat_layer): EdgeEmbedding(
#         (dense): Dense(
#           (linear): Linear(in_features=12, out_features=4, bias=False)
#           (_activation): ScaledSiLU(
#             (_activation): SiLU()
#           )
#         )
#       )
#       (residual_m): ModuleList(
#         (0): ResidualLayer(
#           (dense_mlp): Sequential(
#             (0): Dense(
#               (linear): Linear(in_features=4, out_features=4, bias=False)
#               (_activation): ScaledSiLU(
#                 (_activation): SiLU()
#               )
#             )
#             (1): Dense(
#               (linear): Linear(in_features=4, out_features=4, bias=False)
#               (_activation): ScaledSiLU(
#                 (_activation): SiLU()
#               )
#             )
#           )
#         )
#       )
#     )
#   )
# )

# %%
from mdgen.model.tests.testutils import get_mp_20_debug_batch

# %%
batch = get_mp_20_debug_batch().to(device)

# %%
import torch
with torch.no_grad():
    model_out = model.forward(
        None,
        batch.frac_coords,
        batch.atom_types,
        batch.num_atoms,
        batch.batch,
        batch.lengths,
        batch.angles,
    )
# Out:
# cuda:0 cuda:0 cuda:0 cuda:0 cuda:0 cuda:0 cuda:0 cuda:0 cuda:0

# %%
# for mypy
assert model_out.stress is not None
assert torch.allclose(model_out.stress, model_out.stress.transpose(1, 2), atol=1e-5)

# %%
print(model_out)
# Out:
# ModelOutput(energy=tensor([[ 7.3401],
#         [19.4495],
#         [12.7095],
#         [ 1.6860],
#         [ 5.2052],
#         [23.3484],
#         [ 7.0529],
#         [17.4456],
#         [11.0498],
#         [13.5993],
#         [14.6290],
#         [ 3.7225],
#         [ 8.2983],
#         [ 7.4768],
#         [29.1272],
#         [ 4.2671],
#         [ 7.3273],
#         [12.6814],
#         [21.7417],
#         [14.6777],
#         [ 9.4412],
#         [ 1.2599],
#         [19.9703],
#         [10.7226],
#         [ 5.4895],
#         [ 5.3953],
#         [23.3612],
#         [ 1.3512],
#         [ 8.2811],
#         [30.0697],
#         [35.4383],
#         [ 9.7728],
#         [29.9570],
#         [11.9289],
#         [ 8.0838],
#         [ 8.6024],
#         [ 3.8489],
#         [ 3.3731],
#         [17.0748],
#         [ 6.0037],
#         [ 0.0480],
#         [14.7376],
#         [ 5.1421],
#         [20.8301],
#         [ 6.3134],
#         [12.9787],
#         [12.0138],
#         [39.5103],
#         [ 5.8957],
#         [ 6.1863],
#         [17.3277],
#         [19.9905],
#         [13.9224],
#         [21.0165],
#         [26.0278],
#         [15.5853],
#         [ 7.3140],
#         [ 4.6068],
#         [26.3461],
#         [ 8.2069],
#         [ 3.9830],
#         [10.8436],
#         [ 2.8273],
#         [11.5436]], device='cuda:0'), node_embeddings=tensor([[2.9949, 1.1691, 4.3455, 4.4021],
#         [2.9769, 1.1581, 4.3099, 4.3539],
#         [2.9599, 1.1477, 4.2763, 4.3081],
#         ...,
#         [2.2516, 1.7680, 5.1843, 6.8244],
#         [2.1218, 1.6947, 4.9233, 6.4781],
#         [2.0780, 1.6702, 4.8433, 6.3785]], device='cuda:0'), forces=tensor([[ 0.1533, -0.3755,  0.1054],
#         [ 0.1438, -0.2434,  0.1285],
#         [ 0.1590, -0.3616,  0.1412],
#         ...,
#         [-1.0342, -1.3175,  0.7703],
#         [-0.5835, -0.6496,  0.1441],
#         [ 0.4321, -1.2044,  0.1987]], device='cuda:0'), stress=tensor([[[ 5.4030e-03,  4.9560e-06, -6.2320e-05],
#          [ 4.9560e-06,  6.5859e-03, -1.7923e-04],
#          [-6.2320e-05, -1.7923e-04,  6.7614e-03]],
#
#         [[ 1.4229e-02, -1.5248e-04, -1.8297e-04],
#          [-1.5248e-04,  1.5037e-02, -4.5133e-05],
#          [-1.8297e-04, -4.5133e-05,  1.4811e-02]],
#
#         [[ 3.0337e-02, -8.7133e-05, -2.9086e-04],
#          [-8.7133e-05,  2.9308e-02, -3.7241e-04],
#          [-2.9086e-04, -3.7241e-04,  3.1527e-02]],
#
#         [[ 3.7915e-03, -3.5450e-05,  7.4374e-05],
#          [-3.5450e-05,  3.7523e-03, -9.7736e-05],
#          [ 7.4374e-05, -9.7736e-05, -4.2714e-04]],
#
#         [[ 2.0127e-03,  6.8415e-05,  2.0023e-04],
#          [ 6.8415e-05,  1.9689e-03,  2.3395e-04],
#          [ 2.0023e-04,  2.3395e-04,  2.3543e-03]],
#
#         [[ 1.0068e-02, -5.9666e-06, -1.2549e-04],
#          [-5.9666e-06,  1.0295e-02,  5.0769e-05],
#          [-1.2549e-04,  5.0769e-05,  1.0407e-02]],
#
#         [[ 6.4727e-03,  1.7755e-04,  1.8196e-04],
#          [ 1.7755e-04,  6.5763e-03,  1.9562e-04],
#          [ 1.8196e-04,  1.9562e-04,  5.9185e-03]],
#
#         [[ 3.3517e-02,  8.5793e-05, -2.7775e-04],
#          [ 8.5793e-05,  3.2964e-02, -2.7115e-05],
#          [-2.7775e-04, -2.7115e-05,  3.2417e-02]],
#
#         [[ 7.5986e-03,  4.4520e-05, -1.3293e-04],
#          [ 4.4520e-05,  8.6885e-03, -2.0256e-05],
#          [-1.3293e-04, -2.0256e-05,  8.9676e-03]],
#
#         [[ 3.7002e-03, -2.7141e-05, -3.0775e-05],
#          [-2.7141e-05,  3.6836e-03,  5.5265e-05],
#          [-3.0775e-05,  5.5265e-05,  3.7504e-03]],
#
#         [[ 1.7227e-02,  1.4025e-04, -4.0995e-04],
#          [ 1.4025e-04,  1.7239e-02, -4.0288e-04],
#          [-4.0995e-04, -4.0288e-04,  1.8268e-02]],
#
#         [[ 4.4092e-03,  5.5097e-05,  1.1027e-04],
#          [ 5.5097e-05,  5.2084e-03,  3.6590e-04],
#          [ 1.1027e-04,  3.6590e-04,  7.9612e-03]],
#
#         [[ 1.6513e-02,  1.1988e-04,  3.5976e-04],
#          [ 1.1988e-04,  1.6458e-02,  3.0428e-04],
#          [ 3.5976e-04,  3.0428e-04,  1.7061e-02]],
#
#         [[ 1.3172e-02, -3.3915e-04, -3.4379e-04],
#          [-3.3915e-04,  1.2266e-02, -1.0540e-03],
#          [-3.4379e-04, -1.0540e-03,  1.1253e-02]],
#
#         [[ 1.0157e-02,  7.3878e-05,  1.1340e-04],
#          [ 7.3878e-05,  1.0101e-02, -1.3968e-04],
#          [ 1.1340e-04, -1.3968e-04,  1.0042e-02]],
#
#         [[ 1.1412e-02,  3.0583e-04,  5.5493e-04],
#          [ 3.0583e-04,  1.1164e-02,  2.2108e-04],
#          [ 5.5493e-04,  2.2108e-04,  1.2038e-02]],
#
#         [[ 4.0328e-03, -4.5051e-05, -1.0511e-05],
#          [-4.5051e-05,  3.3015e-03,  1.6520e-04],
#          [-1.0511e-05,  1.6520e-04,  2.8089e-03]],
#
#         [[ 1.8239e-02, -1.4921e-04, -3.2109e-04],
#          [-1.4921e-04,  1.8305e-02, -1.6977e-04],
#          [-3.2109e-04, -1.6977e-04,  1.8631e-02]],
#
#         [[ 2.6015e-02,  1.9929e-04, -1.7805e-04],
#          [ 1.9929e-04,  2.6864e-02,  1.8841e-04],
#          [-1.7805e-04,  1.8841e-04,  2.2217e-02]],
#
#         [[ 1.1577e-02,  2.9935e-05, -9.1162e-05],
#          [ 2.9935e-05,  1.0822e-02, -6.4645e-05],
#          [-9.1162e-05, -6.4645e-05,  1.2693e-02]],
#
#         [[ 1.8291e-03, -1.5806e-05, -1.2744e-05],
#          [-1.5806e-05,  1.7862e-03, -6.2843e-05],
#          [-1.2744e-05, -6.2843e-05,  1.7590e-03]],
#
#         [[ 1.0890e-02, -7.7167e-05,  7.3241e-05],
#          [-7.7167e-05,  1.0646e-02,  1.0381e-04],
#          [ 7.3241e-05,  1.0381e-04,  9.7848e-03]],
#
#         [[ 2.0053e-02,  1.5650e-04,  1.8416e-04],
#          [ 1.5650e-04,  1.9950e-02,  1.7194e-04],
#          [ 1.8416e-04,  1.7194e-04,  2.0578e-02]],
#
#         [[ 4.2613e-03,  1.3440e-04, -2.0035e-04],
#          [ 1.3440e-04,  4.0308e-03, -7.4420e-05],
#          [-2.0035e-04, -7.4419e-05,  4.9411e-03]],
#
#         [[ 3.7262e-03,  6.6969e-06,  5.1647e-05],
#          [ 6.6969e-06,  3.7640e-03, -1.6860e-05],
#          [ 5.1647e-05, -1.6860e-05,  3.6573e-03]],
#
#         [[ 2.3858e-02,  1.4576e-04,  4.9450e-05],
#          [ 1.4576e-04,  2.4297e-02, -3.1201e-04],
#          [ 4.9450e-05, -3.1201e-04,  2.3941e-02]],
#
#         [[ 1.0253e-02,  1.5945e-04, -1.5074e-04],
#          [ 1.5945e-04,  9.6431e-03, -3.6287e-04],
#          [-1.5074e-04, -3.6287e-04,  1.0768e-02]],
#
#         [[ 2.0093e-03, -1.1789e-05,  1.5123e-04],
#          [-1.1789e-05,  2.3581e-03, -5.9709e-06],
#          [ 1.5123e-04, -5.9709e-06,  1.8323e-03]],
#
#         [[ 1.6591e-02,  5.3401e-04, -3.7333e-04],
#          [ 5.3401e-04,  1.6561e-02, -3.5640e-04],
#          [-3.7333e-04, -3.5640e-04,  1.6475e-02]],
#
#         [[ 2.5351e-02,  8.3603e-04, -5.8660e-05],
#          [ 8.3603e-04,  2.1578e-02,  5.6789e-04],
#          [-5.8660e-05,  5.6789e-04,  1.6623e-02]],
#
#         [[ 2.1688e-02,  8.8195e-05, -2.2996e-04],
#          [ 8.8195e-05,  2.1700e-02, -1.1599e-04],
#          [-2.2996e-04, -1.1599e-04,  2.1945e-02]],
#
#         [[ 1.2598e-02, -8.9761e-05, -9.9915e-05],
#          [-8.9761e-05,  1.1497e-02, -4.9801e-04],
#          [-9.9915e-05, -4.9801e-04,  1.3274e-02]],
#
#         [[ 1.3542e-02,  5.8247e-05, -1.4833e-04],
#          [ 5.8247e-05,  1.3567e-02, -1.1153e-04],
#          [-1.4833e-04, -1.1153e-04,  1.4668e-02]],
#
#         [[ 6.0302e-03,  5.7367e-05, -7.2588e-04],
#          [ 5.7367e-05,  7.5531e-03, -1.1769e-04],
#          [-7.2588e-04, -1.1769e-04,  7.3518e-03]],
#
#         [[ 1.6643e-02, -1.5063e-04,  1.0962e-04],
#          [-1.5063e-04,  1.6810e-02,  2.6064e-05],
#          [ 1.0962e-04,  2.6064e-05,  1.6659e-02]],
#
#         [[ 1.0629e-02,  6.7616e-06,  3.4877e-05],
#          [ 6.7616e-06,  1.0689e-02,  1.7326e-05],
#          [ 3.4877e-05,  1.7326e-05,  1.0403e-02]],
#
#         [[ 3.2291e-02,  3.4448e-04, -2.6241e-04],
#          [ 3.4448e-04,  3.1541e-02, -3.8584e-04],
#          [-2.6241e-04, -3.8584e-04,  3.2997e-02]],
#
#         [[ 2.1482e-02,  3.0894e-04,  6.5670e-05],
#          [ 3.0894e-04,  2.1371e-02,  2.4116e-04],
#          [ 6.5670e-05,  2.4116e-04,  2.2424e-02]],
#
#         [[ 8.3372e-03,  1.8584e-05, -4.5647e-05],
#          [ 1.8584e-05,  8.3492e-03, -3.9887e-05],
#          [-4.5647e-05, -3.9887e-05,  6.1595e-03]],
#
#         [[ 2.2576e-02,  1.7325e-05, -2.2639e-04],
#          [ 1.7325e-05,  2.3647e-02,  6.5733e-04],
#          [-2.2639e-04,  6.5733e-04,  2.3829e-02]],
#
#         [[ 1.6130e-03, -9.1511e-06,  7.3457e-05],
#          [-9.1511e-06,  1.2667e-03,  1.3955e-04],
#          [ 7.3457e-05,  1.3955e-04,  1.1325e-03]],
#
#         [[ 3.5550e-03,  6.7337e-05,  8.5131e-05],
#          [ 6.7337e-05,  3.6163e-03,  9.8485e-05],
#          [ 8.5131e-05,  9.8485e-05,  2.7630e-03]],
#
#         [[ 2.2602e-03, -1.8588e-04, -1.1620e-04],
#          [-1.8588e-04,  2.1519e-03, -1.6874e-04],
#          [-1.1620e-04, -1.6874e-04,  1.7774e-03]],
#
#         [[ 1.3638e-02, -4.7859e-04, -6.4210e-04],
#          [-4.7859e-04,  1.3356e-02, -6.3310e-04],
#          [-6.4210e-04, -6.3310e-04,  1.3408e-02]],
#
#         [[ 7.1575e-03,  4.3292e-05, -2.9733e-04],
#          [ 4.3292e-05,  7.2959e-03, -1.9862e-04],
#          [-2.9733e-04, -1.9862e-04,  7.0948e-03]],
#
#         [[ 2.0267e-02,  1.2572e-05, -3.0669e-04],
#          [ 1.2572e-05,  1.9784e-02, -3.7585e-04],
#          [-3.0669e-04, -3.7585e-04,  1.9633e-02]],
#
#         [[ 8.5416e-03, -3.1106e-04, -3.4074e-04],
#          [-3.1106e-04,  9.4655e-03, -6.7220e-04],
#          [-3.4074e-04, -6.7220e-04,  1.0194e-02]],
#
#         [[ 1.5323e-02,  1.1317e-04, -1.0800e-04],
#          [ 1.1317e-04,  1.6349e-02, -9.6132e-05],
#          [-1.0800e-04, -9.6132e-05,  1.5984e-02]],
#
#         [[ 1.3496e-02,  1.5949e-04, -1.5721e-04],
#          [ 1.5949e-04,  1.3382e-02, -3.7464e-04],
#          [-1.5721e-04, -3.7464e-04,  1.4116e-02]],
#
#         [[ 6.5695e-03, -1.5050e-04, -5.5818e-04],
#          [-1.5050e-04,  6.5533e-03, -6.1466e-04],
#          [-5.5818e-04, -6.1466e-04,  5.4853e-03]],
#
#         [[ 8.1550e-03,  4.6876e-05, -5.7730e-05],
#          [ 4.6876e-05,  7.5232e-03, -2.4091e-05],
#          [-5.7730e-05, -2.4091e-05,  8.0593e-03]],
#
#         [[ 2.1842e-02, -2.0784e-04,  1.7137e-04],
#          [-2.0784e-04,  2.1218e-02,  3.9734e-04],
#          [ 1.7137e-04,  3.9734e-04,  2.1366e-02]],
#
#         [[ 1.5775e-02, -5.6317e-05, -9.1365e-05],
#          [-5.6317e-05,  1.5729e-02, -8.0326e-06],
#          [-9.1365e-05, -8.0327e-06,  1.1952e-02]],
#
#         [[ 1.7798e-02, -1.7674e-04,  1.8595e-04],
#          [-1.7674e-04,  1.6903e-02,  5.2032e-04],
#          [ 1.8595e-04,  5.2032e-04,  1.7195e-02]],
#
#         [[ 9.7334e-03, -2.9209e-05, -2.1094e-04],
#          [-2.9209e-05,  9.8830e-03, -7.6293e-05],
#          [-2.1094e-04, -7.6293e-05,  7.2385e-03]],
#
#         [[ 1.3852e-02,  8.7738e-05, -2.6166e-04],
#          [ 8.7738e-05,  1.3551e-02, -5.5506e-04],
#          [-2.6166e-04, -5.5506e-04,  1.4986e-02]],
#
#         [[ 2.8539e-04,  4.2925e-06,  8.8352e-05],
#          [ 4.2926e-06,  1.9554e-04,  5.6686e-05],
#          [ 8.8352e-05,  5.6686e-05, -8.6618e-06]],
#
#         [[ 6.9667e-03, -1.8089e-04,  4.8060e-04],
#          [-1.8089e-04,  7.2818e-03,  2.4329e-04],
#          [ 4.8060e-04,  2.4329e-04,  5.2530e-03]],
#
#         [[ 1.6030e-02, -9.5892e-06, -3.6221e-05],
#          [-9.5892e-06,  1.5952e-02, -1.4537e-04],
#          [-3.6221e-05, -1.4537e-04,  1.6676e-02]],
#
#         [[ 5.4094e-03,  2.2578e-05,  6.5369e-05],
#          [ 2.2578e-05,  5.6808e-03,  2.6128e-05],
#          [ 6.5369e-05,  2.6128e-05,  5.5519e-03]],
#
#         [[ 6.8661e-03, -1.6258e-05,  3.7787e-05],
#          [-1.6258e-05,  7.7749e-03, -1.5401e-04],
#          [ 3.7787e-05, -1.5401e-04,  7.7625e-03]],
#
#         [[ 1.6823e-02, -2.3920e-04, -1.2449e-04],
#          [-2.3920e-04,  1.6604e-02, -2.4940e-04],
#          [-1.2449e-04, -2.4940e-04,  1.7395e-02]],
#
#         [[ 2.0451e-03,  8.6036e-05,  8.5110e-05],
#          [ 8.6036e-05,  1.3331e-03,  1.2389e-04],
#          [ 8.5110e-05,  1.2389e-04,  1.9107e-03]],
#
#         [[ 1.3660e-02,  2.8615e-04, -4.8012e-04],
#          [ 2.8615e-04,  1.6807e-02, -2.6753e-04],
#          [-4.8012e-04, -2.6753e-04,  1.4862e-02]]], device='cuda:0'))
