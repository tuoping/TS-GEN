# %%
import h5py
import numpy as np

# %%
from torch_geometric.data import Data
import torch

# %%
hartree_2_eV = 27.211386245988

# %%
import h5py
import numpy as np

class RGD1Loader:
    """
    Loader for the RGD1 reaction dataset.

    Parameters
    ----------
    chno_h5_path : str
        Path to 'RGD1_CHNO.h5' containing reaction geometries and energies.
    rps_h5_path : str
        Path to 'RGD1_RPs.h5' containing individual reactant/product optimized geometries.
    randp_smiles_txt : str
        Path to 'RandP_smiles.txt' mapping reaction SMILES to molecule indices in RPs file.
    """
    def __init__(self, chno_h5_path, rps_h5_path=None, randp_smiles_txt=None):
        # Open main reaction file
        self.rg1 = h5py.File(chno_h5_path, 'r')
        # Optional: open individual molecule file
        self.rps = h5py.File(rps_h5_path, 'r') if rps_h5_path else None
        # Load reactant/product smiles mapping
        self.rp_dict = {}
        if randp_smiles_txt:
            with open(randp_smiles_txt, 'r', encoding='utf-8') as f:
                for idx, line in enumerate(f):
                    if idx == 0:
                        continue  # skip header
                    key, val = line.strip().split()[:2]
                    self.rp_dict[key] = val

        # Cache reaction IDs
        self.rxn_ids = list(self.rg1.keys())

    def __len__(self):
        """Return the number of reactions in the dataset."""
        return len(self.rxn_ids)

    def __iter__(self):
        """Iterate over all reactions as dictionaries."""
        for rid in self.rxn_ids:
            yield self.get_reaction(rid)

    def __getitem__(self, idx):
        """Get reaction by index or ID."""
        if isinstance(idx, int):
            rid = self.rxn_ids[idx]
        else:
            rid = idx
        return self.get_reaction(rid)

    def get_reaction(self, rid):
        """Parse a single reaction into a structured dict."""
        rxn = self.rg1[rid]
        # Atom numbers map for CHNOF
        num2elm = {1: 'H', 6: 'C', 7: 'N', 8: 'O', 9: 'F'}

        # Decode SMILES
        react_smiles = rxn['Rsmiles'][()].decode('utf-8')
        prod_smiles = rxn['Psmiles'][()].decode('utf-8')

        # Atomic numbers and geometries
        elems = np.array(rxn['elements'], dtype=int)
        atomic_numbers = elems.tolist()
        R_pos = np.array(rxn['RG'])        # reactant positions
        P_pos = np.array(rxn['PG'])        # product positions
        TS_pos = np.array(rxn['TSG'])     # transition state positions

        # Energies (single-point, enthalpy, free) in Hartree
        R_E, P_E, TS_E = (float(rxn['R_E'][()]),
                          float(rxn['P_E'][()]),
                          float(rxn['TS_E'][()]))
        R_H, P_H, TS_H = (float(rxn['R_H'][()]),
                          float(rxn['P_H'][()]),
                          float(rxn['TS_H'][()]))
        R_F, P_F, TS_F = (float(rxn['R_F'][()]),
                          float(rxn['P_F'][()]),
                          float(rxn['TS_F'][()]))

        reaction = {
            'rxn_id': rid,
            'reactant': {
                'smiles': react_smiles,
                'atomic_numbers': atomic_numbers,
                'positions': R_pos,
                'energy': R_E,
                'enthalpy': R_H,
                'free_energy': R_F,
            },
            'product': {
                'smiles': prod_smiles,
                'atomic_numbers': atomic_numbers,
                'positions': P_pos,
                'energy': P_E,
                'enthalpy': P_H,
                'free_energy': P_F,
            },
            'transition_state': {
                'atomic_numbers': atomic_numbers,
                'positions': TS_pos,
                'energy': TS_E,
                'enthalpy': TS_H,
                'free_energy': TS_F,
            }
        }

        # Optional: attach optimized individual molecule geometries & energies
        if self.rps and self.rp_dict:
            # map reactant/products mapping
            R_keys = react_smiles.split('.')
            P_keys = prod_smiles.split('.')
            reaction['reactant']['molecules'] = []
            reaction['product']['molecules'] = []
            for key in R_keys:
                idx = self.rp_dict.get(key)
                if idx and idx in self.rps:
                    mol = self.rps[idx]
                    reaction['reactant']['molecules'].append({
                        'atomic_numbers': list(mol['elements']),
                        'positions': np.array(mol['DFTG']),
                        'energy': float(mol['DFT_SPE'][()]),
                    })
            for key in P_keys:
                idx = self.rp_dict.get(key)
                if idx and idx in self.rps:
                    mol = self.rps[idx]
                    reaction['product']['molecules'].append({
                        'atomic_numbers': list(mol['elements']),
                        'positions': np.array(mol['DFTG']),
                        'energy': float(mol['DFT_SPE'][()]),
                    })

        return reaction

# Example usage
if __name__ == '__main__':
    loader = RGD1Loader(
        chno_h5_path='RGD1_CHNO.h5',
    )
    print(f"Total reactions: {len(loader)}")
    # Print first reaction summary
    rxn = loader[0]
    print(rxn['rxn_id'], rxn['reactant']['smiles'], "→", rxn['product']['smiles'])
# Out:
# Total reactions: 176992
# MR_100001_2 CC.C[C@H]1N[C@@H](N)CO1 → CC[C@H](N[C@H](CO)N)C

# %%
import numpy as np
from scipy.spatial.distance import pdist, squareform
# Constants
C = 6

def get_cc_bonds(atomic_numbers, positions, cutoff=(1.2, 1.7)):
    """Returns a set of tuples (i, j) for bonded C–C pairs"""
    dist = squareform(pdist(positions))
    bonds = set()
    for i in range(len(atomic_numbers)):
        if atomic_numbers[i] != C:
            continue
        for j in range(i + 1, len(atomic_numbers)):
            if atomic_numbers[j] != C:
                continue
            d = dist[i, j]
            if cutoff[0] <= d <= cutoff[1]:
                bonds.add((i, j))
    return bonds

from ase.io import write
def cc_bond_formed(reactant, product):
    """
    Compares reactant and product to detect if any new C–C bond formed.
    Returns True if any new C–C bond is present in the product.
    """
    r_cc = get_cc_bonds(reactant["atomic_numbers"], reactant["positions"])
    p_cc = get_cc_bonds(product["atomic_numbers"], product["positions"])
    new_bonds = p_cc - r_cc
    return len(new_bonds) > 0

# Atomic number constants
C, H, O = 6, 1, 8

def is_alpha_deprotonation(reactant, product):
    Z = reactant["atomic_numbers"]
    pos_r = np.array(reactant["positions"])
    pos_p = np.array(product["positions"])

    dist_r = squareform(pdist(pos_r))
    dist_p = squareform(pdist(pos_p))

    num_atoms = len(Z)

    for i in range(num_atoms):
        if Z[i] != C:
            continue

        for j in range(num_atoms):
            if Z[j] == O and 1.15 < dist_r[i][j] < 1.30:
                # C=O found; check for adjacent C with H in reactant
                for k in range(num_atoms):
                    if Z[k] == C and 1.3 < dist_r[i][k] < 1.7:
                        h_neighbors_r = [l for l in range(num_atoms)
                                         if Z[l] == H and dist_r[k][l] < 1.2]
                        h_neighbors_p = [l for l in range(num_atoms)
                                         if Z[l] == H and dist_p[k][l] < 1.2]
                        # H present in reactant but gone in product
                        if len(h_neighbors_r) > 0 and len(h_neighbors_p) == 0:
                            return True
    return False
from ase import Atoms
def to_atoms(numbers, positions):
    return Atoms(numbers=numbers, positions=positions)

def save_linked_reactions_to_xyz(r1, r2, filename="linked_reactions"):

    def save_reaction(reaction, label):
        for state in ["reactant", "transition_state", "product"]:
            atoms = to_atoms(
                reaction[state]["atomic_numbers"],
                reaction[state]["positions"]
            )
            write(filename, atoms, append=True, format="extxyz",)

    if r1:
        save_reaction(r1, "step1_deprotonation")
    if r2:
        save_reaction(r2, "step2_enolate_attack")

    print(f"\nSaved r1 and r2 reactions to folder: {filename}/")

from scipy.optimize import linear_sum_assignment
from scipy.spatial.distance import cdist
import numpy as np

def same_geometry(atomic_numbers1, pos1, atomic_numbers2, pos2, tol=0.3):
    """
    Compares two molecular geometries using atom-wise optimal matching.
    Returns True if they match within `tol` RMSD per atom.
    """
    if len(atomic_numbers1) != len(atomic_numbers2):
        return False
    if sorted(atomic_numbers1) != sorted(atomic_numbers2):
        return False

    pos1 = np.array(pos1)
    pos2 = np.array(pos2)
    Z1 = np.array(atomic_numbers1)
    Z2 = np.array(atomic_numbers2)

    total_rmsd = 0.0
    count = 0

    # Match atoms by type (H, C, O, N)
    for z in sorted(set(Z1)):
        idx1 = np.where(Z1 == z)[0]
        idx2 = np.where(Z2 == z)[0]

        if len(idx1) != len(idx2):
            return False

        sub_pos1 = pos1[idx1]
        sub_pos2 = pos2[idx2]

        dists = cdist(sub_pos1, sub_pos2)
        row_ind, col_ind = linear_sum_assignment(dists)
        rmsd = np.sqrt(np.mean((sub_pos1[row_ind] - sub_pos2[col_ind]) ** 2))
        total_rmsd += rmsd * len(idx1)
        count += len(idx1)

    avg_rmsd = total_rmsd / count
    return avg_rmsd < tol


def find_alpha_deprotonation_then_enolate_attack(dataloader):
    reactions = list(dataloader)
    idx_seq = 0
    for i, r1 in enumerate(reactions):
        if is_alpha_deprotonation(r1["reactant"], r1["product"]):
            prod1_Z = r1["product"]["atomic_numbers"]
            prod1_pos = r1["product"]["positions"]

            for r2 in reactions:
                if same_geometry(prod1_Z, prod1_pos,
                                 r2["reactant"]["atomic_numbers"],
                                 r2["reactant"]["positions"]):
                    if cc_bond_formed(r2["reactant"], r2["product"]):
                        print(f"\nFound linked pair:")
                        # return r1, r2
                        save_linked_reactions_to_xyz(r1, r2, filename=f"linked_reactions_{idx_seq}.xyz")
                        idx_seq += 1

    print("No matching sequence found.")
    # return None, None



# Run inspection
find_alpha_deprotonation_then_enolate_attack(loader)
# Out:
# Found linked pair:
#
# Saved r1 and r2 reactions to folder: linked_reactions_0.xyz/
#
# Found linked pair:
#
# Saved r1 and r2 reactions to folder: linked_reactions_1.xyz/
#
# Found linked pair:
#
# Saved r1 and r2 reactions to folder: linked_reactions_2.xyz/
#
# Found linked pair:
#
# Saved r1 and r2 reactions to folder: linked_reactions_3.xyz/
#
# Found linked pair:
#
# Saved r1 and r2 reactions to folder: linked_reactions_4.xyz/
#
# Found linked pair:
#
# Saved r1 and r2 reactions to folder: linked_reactions_5.xyz/
# No matching sequence found.

# %%
# find_beckmann_rgd1.py

import os
from rdkit import Chem

def find_beckmann_rearrangements(chno_h5, rps_h5=None, randp_smiles_txt=None,
                                 out_txt="beckmann_hits.txt"):
    """
    Scan the RGD1 dataset for reactions where:
      Reactant contains an oxime (C=N–O)
      Product contains an amide (C(=O)–N)
    Writes matching reaction IDs and SMILES to out_txt.
    """
    # SMARTS patterns
    oxime_pat  = Chem.MolFromSmarts("[CX3]=[NX2]-[OX1]")
    amide_pat  = Chem.MolFromSmarts("[CX3](=O)[NX3]")

    loader = RGD1Loader(chno_h5_path=chno_h5,
                        rps_h5_path=rps_h5,
                        randp_smiles_txt=randp_smiles_txt)

    with open(out_txt, "w") as fout:
        fout.write("rxn_id\treactant_smiles\tproduct_smiles\n")
        for rxn in loader:
            r_smiles = rxn["reactant"]["smiles"]
            p_smiles = rxn["product"]["smiles"]

            # Parse with RDKit
            r_mol = Chem.MolFromSmiles(r_smiles)
            p_mol = Chem.MolFromSmiles(p_smiles)
            if r_mol is None or p_mol is None:
                continue

            # Pattern match
            if r_mol.HasSubstructMatch(oxime_pat) and p_mol.HasSubstructMatch(amide_pat):
                rid = rxn["rxn_id"]
                print(f"Beckmann hit: {rid}  {r_smiles} → {p_smiles}")
                fout.write(f"{rid}\t{r_smiles}\t{p_smiles}\n")

    print(f"\nDone — results in {out_txt}")

if __name__ == "__main__":
    # adjust paths as needed
    chno = "RGD1_CHNO.h5"

    find_beckmann_rearrangements(chno,)
# Out:
# Done — results in beckmann_hits.txt

# %%
# find_perkin_rgd1_with_xyz.py

import os
from rdkit import Chem
from ase import Atoms
from ase.io import write

# SMARTS patterns
aldehyde_pat         = Chem.MolFromSmarts("[CX3H1](=O)[#6]")         # R–CHO
acid_anhydride_pat   = Chem.MolFromSmarts("[CX3](=O)O[CX3](=O)")     # R–C(=O)–O–C(=O)–R
alpha_beta_unsat_pat = Chem.MolFromSmarts("[CX3H1]=[CX2]C(=O)[OX2H]") # R–CH=CH–C(=O)–OH

def to_atoms(numbers, positions):
    return Atoms(numbers=numbers, positions=positions)

def find_perkin_reactions(chno_h5, rps_h5=None, randp_txt=None,
                          out_txt="perkin_hits.txt", xyz_dir="perkin_xyz"):
    loader = RGD1Loader(chno_h5_path=chno_h5,
                        rps_h5_path=rps_h5,
                        randp_smiles_txt=randp_txt)

    os.makedirs(xyz_dir, exist_ok=True)

    with open(out_txt, "w") as fout:
        fout.write("rxn_id\treactant_smiles\tproduct_smiles\n")
        for rxn in loader:
            rid       = rxn["rxn_id"]
            r_smiles  = rxn["reactant"]["smiles"]
            p_smiles  = rxn["product"]["smiles"]
            r_mol     = Chem.MolFromSmiles(r_smiles)
            p_mol     = Chem.MolFromSmiles(p_smiles)
            if r_mol is None or p_mol is None:
                continue

            if (r_mol.HasSubstructMatch(aldehyde_pat)
             and r_mol.HasSubstructMatch(acid_anhydride_pat)
             and p_mol.HasSubstructMatch(alpha_beta_unsat_pat)):

                # record in text file
                fout.write(f"{rid}\t{r_smiles}\t{p_smiles}\n")
                print(f"Perkin hit: {rid}  {r_smiles} → {p_smiles}")

                # save xyz for this reaction
                for state in ("reactant", "transition_state", "product"):
                    geom = rxn[state]
                    atoms = to_atoms(geom["atomic_numbers"], geom["positions"])
                    fn = os.path.join(xyz_dir, f"{rid}.xyz")
                    write(fn, atoms, append=True, format="extxyz")
                print(f"  → saved geometries to {xyz_dir}/{rid}_*.xyz")

    print(f"\nDone — hits in {out_txt}, xyz in {xyz_dir}/")


if __name__ == "__main__":
    CHNO    = "RGD1_CHNO.h5"

    find_perkin_reactions(CHNO, )
# Out:
# Done — hits in perkin_hits.txt, xyz in perkin_xyz/

# %%
# find_diels_alder_rgd1_with_xyz.py

import os
from rdkit import Chem
from rdkit.Chem.rdchem import BondType
from ase import Atoms
from ase.io import write

# SMARTS for conjugated diene and simple alkene
DIENE_PAT   = Chem.MolFromSmarts("[#6]=[#6]-[#6]=[#6]")
ALKENE_PAT  = Chem.MolFromSmarts("[#6]=[#6]")

def is_diels_alder(r_smiles: str, p_smiles: str) -> bool:
    """
    Returns True if reactant SMILES contains one conjugated diene fragment
    plus one alkene fragment, and product SMILES contains a cyclohexene ring
    (6-membered ring with exactly one C=C).
    """
    frags = r_smiles.split('.')
    if len(frags) != 2:
        return False

    diene_found = False
    alkene_found = False

    for frag in frags:
        mol = Chem.MolFromSmiles(frag)
        if mol is None:
            return False
        # Count double bonds
        n_db = sum(1 for b in mol.GetBonds() if b.GetBondType() == BondType.DOUBLE)

        if mol.HasSubstructMatch(DIENE_PAT) and n_db >= 2:
            diene_found = True
        elif mol.HasSubstructMatch(ALKENE_PAT) and n_db == 1:
            alkene_found = True

    if not (diene_found and alkene_found):
        return False

    # Check product for cyclohexene: 6-membered ring with exactly one double bond
    p_mol = Chem.MolFromSmiles(p_smiles)
    if p_mol is None:
        return False

    ring_info = p_mol.GetRingInfo()
    for ring in ring_info.AtomRings():
        if len(ring) == 6:
            # Count double bonds within this ring
            count_db = 0
            for i in range(len(ring)):
                a1 = ring[i]
                a2 = ring[(i + 1) % len(ring)]
                bond = p_mol.GetBondBetweenAtoms(a1, a2)
                if bond and bond.GetBondType() == BondType.DOUBLE:
                    count_db += 1
            if count_db == 1:
                return True

    return False

def save_diels_alder_xyz(chno_h5: str,
                         rps_h5: str = None,
                         randp_txt: str = None,
                         out_txt: str = "diels_alder_hits.txt",
                         xyz_dir: str = "diels_alder_xyz"):
    """
    Scan RGD1 for Diels–Alder candidates and:
      - Write hits to out_txt (rxn_id, reactant_smiles, product_smiles)
      - Save reactant/TS/product geometries as separate .xyz files
    """
    loader = RGD1Loader(chno_h5_path=chno_h5,
                        rps_h5_path=rps_h5,
                        randp_smiles_txt=randp_txt)
    os.makedirs(xyz_dir, exist_ok=True)

    with open(out_txt, "w") as fout:
        fout.write("rxn_id\treactant_smiles\tproduct_smiles\n")
        idx_seq = 0
        for rxn in loader:
            rid      = rxn["rxn_id"]
            r_smiles = rxn["reactant"]["smiles"]
            p_smiles = rxn["product"]["smiles"]

            if is_diels_alder(r_smiles, p_smiles):
                fout.write(f"{rid}\t{r_smiles}\t{p_smiles}\n")
                print(f"Diels–Alder hit: {rid}  {r_smiles} → {p_smiles}")

                # Save geometries
                for state in ("reactant", "transition_state", "product"):
                    geom  = rxn[state]
                    atoms = Atoms(numbers=geom["atomic_numbers"],
                                  positions=geom["positions"])
                    fn = os.path.join(xyz_dir, f"r{idx_seq}.xyz")
                    write(fn, atoms, append=True, format="extxyz")
                idx_seq += 1
                print(f" → saved XYZs to {xyz_dir}/{rid}_*.xyz")

    print(f"\nDone — see {out_txt} and {xyz_dir}/")

if __name__ == "__main__":
    CHNO    = "RGD1_CHNO.h5"
    RPS     = None            # optional
    MAPPING = None            # optional

    save_diels_alder_xyz(CHNO, RPS, MAPPING)
# Out:
# Diels–Alder hit: MR_117032_2  C=CC=C=O.C=C → O=C1CCCC=C1
#  → saved XYZs to diels_alder_xyz/MR_117032_2_*.xyz
# Diels–Alder hit: MR_591173_0  O=C=C(C=C(C)C)O.C=C → OC1=CC(C)(C)CCC1=O
#  → saved XYZs to diels_alder_xyz/MR_591173_0_*.xyz
#
# Done — see diels_alder_hits.txt and diels_alder_xyz/

# %%
# find_robinson_annulation_rgd1.py

import os
from rdkit import Chem
from rdkit.Chem.rdchem import BondType
from ase import Atoms
from ase.io import write

# SMARTS for a Michael donor (1,3-diketone) and Michael acceptor (α,β-unsaturated ketone)
DKETONE_PAT  = Chem.MolFromSmarts("[#6]C(=O)CC(=O)[#6]")          # R–C(=O)–CH2–C(=O)–R
ENONE_PAT    = Chem.MolFromSmarts("[CX3H1]=[CX2]C(=O)[#6]")       # R–CH=CH–C(=O)–R

def is_michael_addition(r_smiles: str, p_smiles: str) -> bool:
    """Step 1: Michael addition of a 1,3-diketone onto an enone → 1,5-diketone."""
    frags = r_smiles.split('.')
    if len(frags) != 2:
        return False
    d1, d2 = Chem.MolFromSmiles(frags[0]), Chem.MolFromSmiles(frags[1])
    prod = Chem.MolFromSmiles(p_smiles)
    if not all((d1, d2, prod)):
        return False

    # one fragment is 1,3-diketone, the other is enone
    if (d1.HasSubstructMatch(DKETONE_PAT) and d2.HasSubstructMatch(ENONE_PAT)) \
    or (d2.HasSubstructMatch(DKETONE_PAT) and d1.HasSubstructMatch(ENONE_PAT)):
        # product should still have two carbonyls (now 1,5-diketone) and no C=C
        if prod.HasSubstructMatch(DKETONE_PAT) and not prod.HasSubstructMatch(ENONE_PAT):
            return True
    return False

def is_aldol_cyclization(r_smiles: str, p_smiles: str) -> bool:
    """Step 2: Intramolecular aldol + dehydration → cyclohexenone ring."""
    react = Chem.MolFromSmiles(r_smiles)
    prod  = Chem.MolFromSmiles(p_smiles)
    if not (react and prod):
        return False

    # product must contain a 6-membered ring with exactly one C=C and one C=O
    ri = prod.GetRingInfo()
    for ring in ri.AtomRings():
        if len(ring) == 6:
            dbonds = 0
            carbonyls = 0
            for i in range(len(ring)):
                a1 = ring[i]
                a2 = ring[(i+1)%len(ring)]
                b = prod.GetBondBetweenAtoms(a1, a2)
                if b.GetBondType() == BondType.DOUBLE:
                    dbonds += 1
            # count C=O attachments into the ring
            for a in ring:
                atom = prod.GetAtomWithIdx(a)
                for nbr in atom.GetNeighbors():
                    b2 = prod.GetBondBetweenAtoms(a, nbr.GetIdx())
                    if nbr.GetAtomicNum() == 8 and b2.GetBondType() == BondType.DOUBLE:
                        carbonyls += 1
            if dbonds == 1 and carbonyls == 1:
                return True
    return False

def to_atoms(numbers, positions):
    return Atoms(numbers=numbers, positions=positions)

def find_robinson_annulation(chno_h5, rps_h5=None, randp_txt=None,
                             out_txt="robinson_hits.txt", xyz_dir="robinson_xyz"):
    loader = RGD1Loader(chno_h5_path=chno_h5,
                        rps_h5_path=rps_h5,
                        randp_smiles_txt=randp_txt)

    # index by product SMILES
    prod_index = {}
    for rxn in loader:
        p_sm = rxn["product"]["smiles"]
        prod_index.setdefault(p_sm, []).append(rxn)

    os.makedirs(xyz_dir, exist_ok=True)
    with open(out_txt, "w") as fout:
        fout.write("step1_rxn\tstep2_rxn\treactant1\tintermediate2\tproduct2\n")
        idx_seq = 0
        for r1 in loader:
            r1_sm = r1["reactant"]["smiles"]
            p1_sm = r1["product"]["smiles"]

            if not is_michael_addition(r1_sm, p1_sm):
                continue

            # look for intramolecular aldol on that intermediate
            for r2 in prod_index.get(p1_sm, []):
                if is_aldol_cyclization(r2["reactant"]["smiles"], r2["product"]["smiles"]):
                    # record
                    fout.write(f"{r1['rxn_id']}\t{r2['rxn_id']}\t"
                               f"{r1_sm}\t{p1_sm}\t{r2['product']['smiles']}\n")
                    print(f"Robinson annulation: {r1['rxn_id']} → {r2['rxn_id']}")

                    # save geometries
                    for label, rxn in [("step1", r1), ("step2", r2)]:
                        for state in ("reactant", "transition_state", "product"):
                            geom = rxn[state]
                            atoms = to_atoms(geom["atomic_numbers"], geom["positions"])
                            fn = os.path.join(xyz_dir, f"r{idx_seq}.xyz")
                            write(fn, atoms, append=True, format="extxyz")
                    break
            idx_seq += 1    

    print(f"\nDone — see hits in {out_txt} and geometries in {xyz_dir}/")

if __name__ == "__main__":
    CHNO    = "RGD1_CHNO.h5"
    RPS     = None
    MAPPING = None

    find_robinson_annulation(CHNO, RPS, MAPPING)
# Out:
# Done — see hits in robinson_hits.txt and geometries in robinson_xyz/

# %%
import os
from rdkit import Chem
from ase import Atoms
from ase.io import write

# SMARTS patterns for Michael donors and acceptors
DKETONE_PAT = Chem.MolFromSmarts("[#6]C(=O)CC(=O)[#6]")      # 1,3-diketone
ENONE_PAT   = Chem.MolFromSmarts("[CX3H1]=[CX2]C(=O)[#6]")    # α,β-unsaturated ketone

def is_michael_addition(r_smiles: str, p_smiles: str) -> bool:
    """
    Detects Michael addition: 1,3-diketone + enone -> 1,5-diketone
    """
    frags = r_smiles.split('.')
    if len(frags) != 2:
        return False
    mols = [Chem.MolFromSmiles(f) for f in frags]
    prod = Chem.MolFromSmiles(p_smiles)
    if None in mols or prod is None:
        return False
    d1, d2 = mols
    # one fragment is diketone, the other is enone
    if ((d1.HasSubstructMatch(DKETONE_PAT) and d2.HasSubstructMatch(ENONE_PAT)) or
        (d2.HasSubstructMatch(DKETONE_PAT) and d1.HasSubstructMatch(ENONE_PAT))):
        # product should have both carbonyls (diketone) and no C=C
        if prod.HasSubstructMatch(DKETONE_PAT) and not prod.HasSubstructMatch(ENONE_PAT):
            return True
    return False

def to_atoms(numbers, positions):
    return Atoms(numbers=numbers, positions=positions)

def find_michael_and_save_extxyz(chno_h5, rps_h5=None, randp_txt=None,
                                 xyz_dir="michael_extxyz"):
    """
    Finds Michael addition reactions in RGD1 and saves each reaction
    (reactant, TS, product) into individual extended XYZ files.
    """
    loader = RGD1Loader(chno_h5_path=chno_h5,
                        rps_h5_path=rps_h5,
                        randp_smiles_txt=randp_txt)
    os.makedirs(xyz_dir, exist_ok=True)

    idx_seq = 0
    for rxn in loader:
        r_sm = rxn["reactant"]["smiles"]
        p_sm = rxn["product"]["smiles"]
        if not is_michael_addition(r_sm, p_sm):
            continue

        filename = os.path.join(xyz_dir, f"r{idx_seq}.xyz")
        # remove existing file if any
        if os.path.exists(filename):
            os.remove(filename)

        # append all states to one extended XYZ
        for state in ("reactant", "transition_state", "product"):
            geom = rxn[state]
            atoms = to_atoms(geom["atomic_numbers"], geom["positions"])
            atoms.info["reaction_id"] = rxn.get("rxn_id", f"r{idx_seq}")
            atoms.info["state"] = state
            write(filename, atoms, append=True, format="extxyz")
        print(f"Saved Michael reaction {rxn.get('rxn_id', idx_seq)} to {filename}")
        idx_seq += 1

    print(f"\nTotal Michael additions saved: {idx_seq}")

if __name__ == "__main__":
    CHNO    = "RGD1_CHNO.h5"
    RPS     = None            # optional
    MAPPING = None            # optional

    find_michael_and_save_extxyz(CHNO, RPS, MAPPING)
# Out:
# Total Michael additions saved: 0

# %%
# Corrected script for detecting named reactions in RGD1 with RDKit and ASE
# Fix: Use Chem.MolToSmiles instead of non-existent Chem.CanonicalSmiles

import os
from rdkit import Chem
from rdkit.Chem import rdMolDescriptors
from ase import Atoms
from ase.io import write

# SMARTS patterns (approximate) for named reactions
PATTERNS = {
    'claisen': {
        'reactant': Chem.MolFromSmarts('[#6]=[#6]-[#6]-O-[#6]'),      # vinyl ether
        'product':  Chem.MolFromSmarts('[#6]-[#6]=[#6]-C(=O)[#6]')   # γ,δ-unsat carbonyl
    },
    'cope': {
        'reactant': Chem.MolFromSmarts('[#6]=[#6]-[#6]-[#6]-[#6]=[#6]'),  # 1,5-diene
        'product':  Chem.MolFromSmarts('[#6]=[#6]-[#6]-[#6]-[#6]=[#6]')   # isomerization
    },
    'pinacol': {
        'reactant': Chem.MolFromSmarts('C([OX2H])[C;!H0]([OX2H])'),        # vicinal diol
        'product':  Chem.MolFromSmarts('C(=O)C([OX2H])')                  # α-hydroxy ketone
    },
    'wagner_meerwein': {
        # general carbon rearrangement
        'reactant': None,
        'product':  None
    }
}

def is_isomerization(r_mol, p_mol):
    """Check same formula and different connectivity."""
    return (rdMolDescriptors.CalcMolFormula(r_mol) == rdMolDescriptors.CalcMolFormula(p_mol)
            and Chem.MolToSmiles(r_mol, canonical=True) != Chem.MolToSmiles(p_mol, canonical=True))

def detect_claisen(r_mol, p_mol):
    return (r_mol.HasSubstructMatch(PATTERNS['claisen']['reactant'])
            and p_mol.HasSubstructMatch(PATTERNS['claisen']['product']))

def detect_cope(r_mol, p_mol):
    return (r_mol.HasSubstructMatch(PATTERNS['cope']['reactant'])
            and p_mol.HasSubstructMatch(PATTERNS['cope']['product'])
            and is_isomerization(r_mol, p_mol))

def detect_pinacol(r_mol, p_mol):
    return (r_mol.HasSubstructMatch(PATTERNS['pinacol']['reactant'])
            and p_mol.HasSubstructMatch(PATTERNS['pinacol']['product']))

def detect_wagner_meerwein(r_mol, p_mol):
    # pure carbon isomerization
    return (len(r_mol.GetAtoms()) == len(p_mol.GetAtoms())
            and all(atom.GetAtomicNum() == 6 for atom in r_mol.GetAtoms())
            and all(atom.GetAtomicNum() == 6 for atom in p_mol.GetAtoms())
            and is_isomerization(r_mol, p_mol))

def to_atoms(geom):
    return Atoms(numbers=geom['atomic_numbers'], positions=geom['positions'])

def save_extxyz(rxn, out_dir, idx):
    os.makedirs(out_dir, exist_ok=True)
    filename = os.path.join(out_dir, f"r{idx}.xyz")
    if os.path.exists(filename):
        os.remove(filename)
    for state in ('reactant', 'transition_state', 'product'):
        geom = rxn[state]
        atoms = to_atoms(geom)
        atoms.info['rxn_id'] = rxn['rxn_id']
        atoms.info['state'] = state
        atoms.info['energy'] = geom.get('energy')
        write(filename, atoms, append=True, format='extxyz')

def find_named_reactions(chno_h5, rps_h5=None, randp_txt=None):
    loader = RGD1Loader(chno_h5_path=chno_h5,
                        rps_h5_path=rps_h5,
                        randp_smiles_txt=randp_txt)
    detectors = {
        #'claisen':           detect_claisen,
        'cope':              detect_cope,
        #'pinacol':           detect_pinacol,
        #'wagner_meerwein':   detect_wagner_meerwein
    }
    counts = {name: 0 for name in detectors}
    for name, detector in detectors.items():
        out_dir = f"{name}_xyz"
        idx = 0
        for rxn in loader:
            r_mol = Chem.MolFromSmiles(rxn['reactant']['smiles'])
            p_mol = Chem.MolFromSmiles(rxn['product']['smiles'])
            if not r_mol or not p_mol:
                continue
            if detector(r_mol, p_mol):
                save_extxyz(rxn, out_dir, idx)
                print(f"{name.title()} hit: {rxn['rxn_id']} → saved to {out_dir}/r{idx}.xyz")
                idx += 1
        counts[name] = idx
    print("Summary of hits:")
    for name, count in counts.items():
        print(f"  {name.title()}: {count}")

if __name__ == '__main__':
    CHNO = 'RGD1_CHNO.h5'
    RPS = None
    MAP = None
    find_named_reactions(CHNO, RPS, MAP)
# Out:
# Cope hit: MR_103198_0 → saved to cope_xyz/r0.xyz
# Cope hit: MR_103198_2 → saved to cope_xyz/r1.xyz
# Cope hit: MR_104090_1 → saved to cope_xyz/r2.xyz
# Cope hit: MR_110865_0 → saved to cope_xyz/r3.xyz
# Cope hit: MR_110865_1 → saved to cope_xyz/r4.xyz
# Cope hit: MR_110865_2 → saved to cope_xyz/r5.xyz
# Cope hit: MR_125664_2 → saved to cope_xyz/r6.xyz
# Cope hit: MR_125915_1 → saved to cope_xyz/r7.xyz
# Cope hit: MR_130501_0 → saved to cope_xyz/r8.xyz
# Cope hit: MR_130501_1 → saved to cope_xyz/r9.xyz
# Cope hit: MR_130755_0 → saved to cope_xyz/r10.xyz
# Cope hit: MR_130755_2 → saved to cope_xyz/r11.xyz
# Cope hit: MR_134331_0 → saved to cope_xyz/r12.xyz
# Cope hit: MR_134331_2 → saved to cope_xyz/r13.xyz
# Cope hit: MR_142477_0 → saved to cope_xyz/r14.xyz
# Cope hit: MR_143120_0 → saved to cope_xyz/r15.xyz
# Cope hit: MR_143120_1 → saved to cope_xyz/r16.xyz
# Cope hit: MR_163294_0 → saved to cope_xyz/r17.xyz
# Cope hit: MR_163294_1 → saved to cope_xyz/r18.xyz
# Cope hit: MR_171476_0 → saved to cope_xyz/r19.xyz
# Cope hit: MR_171476_1 → saved to cope_xyz/r20.xyz
# Cope hit: MR_177230_0 → saved to cope_xyz/r21.xyz
# Cope hit: MR_177230_1 → saved to cope_xyz/r22.xyz
# Cope hit: MR_182272_0 → saved to cope_xyz/r23.xyz
# Cope hit: MR_185231_1 → saved to cope_xyz/r24.xyz
# Cope hit: MR_187069_1 → saved to cope_xyz/r25.xyz
# Cope hit: MR_197065_0 → saved to cope_xyz/r26.xyz
# Cope hit: MR_203331_0 → saved to cope_xyz/r27.xyz
# Cope hit: MR_221480_0 → saved to cope_xyz/r28.xyz
# Cope hit: MR_236776_0 → saved to cope_xyz/r29.xyz
# Cope hit: MR_245602_1 → saved to cope_xyz/r30.xyz
# Cope hit: MR_257116_0 → saved to cope_xyz/r31.xyz
# Cope hit: MR_276223_1 → saved to cope_xyz/r32.xyz
# Cope hit: MR_28332_2 → saved to cope_xyz/r33.xyz
# Cope hit: MR_286552_0 → saved to cope_xyz/r34.xyz
# Cope hit: MR_28807_2 → saved to cope_xyz/r35.xyz
# Cope hit: MR_293276_0 → saved to cope_xyz/r36.xyz
# Cope hit: MR_307071_0 → saved to cope_xyz/r37.xyz
# Cope hit: MR_307071_1 → saved to cope_xyz/r38.xyz
# Cope hit: MR_307071_2 → saved to cope_xyz/r39.xyz
# Cope hit: MR_318093_0 → saved to cope_xyz/r40.xyz
# Cope hit: MR_318093_1 → saved to cope_xyz/r41.xyz
# Cope hit: MR_318093_2 → saved to cope_xyz/r42.xyz
# Cope hit: MR_319622_0 → saved to cope_xyz/r43.xyz
# Cope hit: MR_327570_1 → saved to cope_xyz/r44.xyz
# Cope hit: MR_327570_2 → saved to cope_xyz/r45.xyz
# Cope hit: MR_329877_0 → saved to cope_xyz/r46.xyz
# Cope hit: MR_340193_0 → saved to cope_xyz/r47.xyz
# Cope hit: MR_340193_1 → saved to cope_xyz/r48.xyz
# Cope hit: MR_340193_2 → saved to cope_xyz/r49.xyz
# Cope hit: MR_34479_0 → saved to cope_xyz/r50.xyz
# Cope hit: MR_34479_1 → saved to cope_xyz/r51.xyz
# Cope hit: MR_34479_2 → saved to cope_xyz/r52.xyz
# Cope hit: MR_344873_0 → saved to cope_xyz/r53.xyz
# Cope hit: MR_372092_2 → saved to cope_xyz/r54.xyz
# Cope hit: MR_386698_0 → saved to cope_xyz/r55.xyz
# Cope hit: MR_391099_0 → saved to cope_xyz/r56.xyz
# Cope hit: MR_393303_1 → saved to cope_xyz/r57.xyz
# Cope hit: MR_401793_1 → saved to cope_xyz/r58.xyz
# Cope hit: MR_404691_0 → saved to cope_xyz/r59.xyz
# Cope hit: MR_40502_0 → saved to cope_xyz/r60.xyz
# Cope hit: MR_40502_2 → saved to cope_xyz/r61.xyz
# Cope hit: MR_408921_0 → saved to cope_xyz/r62.xyz
# Cope hit: MR_408921_2 → saved to cope_xyz/r63.xyz
# Cope hit: MR_411569_1 → saved to cope_xyz/r64.xyz
# Cope hit: MR_425644_2 → saved to cope_xyz/r65.xyz
# Cope hit: MR_436861_0 → saved to cope_xyz/r66.xyz
# Cope hit: MR_436861_2 → saved to cope_xyz/r67.xyz
# Cope hit: MR_442734_0 → saved to cope_xyz/r68.xyz
# Cope hit: MR_483543_1 → saved to cope_xyz/r69.xyz
# Cope hit: MR_483543_2 → saved to cope_xyz/r70.xyz
# Cope hit: MR_48522_0 → saved to cope_xyz/r71.xyz
# Cope hit: MR_48583_0 → saved to cope_xyz/r72.xyz
# Cope hit: MR_48583_1 → saved to cope_xyz/r73.xyz
# Cope hit: MR_48583_2 → saved to cope_xyz/r74.xyz
# Cope hit: MR_492050_0 → saved to cope_xyz/r75.xyz
# Cope hit: MR_492050_1 → saved to cope_xyz/r76.xyz
# Cope hit: MR_493056_0 → saved to cope_xyz/r77.xyz
# Cope hit: MR_493056_1 → saved to cope_xyz/r78.xyz
# Cope hit: MR_493056_2 → saved to cope_xyz/r79.xyz
# Cope hit: MR_498617_2 → saved to cope_xyz/r80.xyz
# Cope hit: MR_500865_0 → saved to cope_xyz/r81.xyz
# Cope hit: MR_500865_1 → saved to cope_xyz/r82.xyz
# Cope hit: MR_500865_2 → saved to cope_xyz/r83.xyz
# Cope hit: MR_51142_0 → saved to cope_xyz/r84.xyz
# Cope hit: MR_521101_0 → saved to cope_xyz/r85.xyz
# Cope hit: MR_521101_1 → saved to cope_xyz/r86.xyz
# Cope hit: MR_521101_2 → saved to cope_xyz/r87.xyz
# Cope hit: MR_528803_0 → saved to cope_xyz/r88.xyz
# Cope hit: MR_531666_1 → saved to cope_xyz/r89.xyz
# Cope hit: MR_535571_1 → saved to cope_xyz/r90.xyz
# Cope hit: MR_538675_2 → saved to cope_xyz/r91.xyz
# Cope hit: MR_538989_2 → saved to cope_xyz/r92.xyz
# Cope hit: MR_54089_1 → saved to cope_xyz/r93.xyz
# Cope hit: MR_549353_2 → saved to cope_xyz/r94.xyz
# Cope hit: MR_552609_0 → saved to cope_xyz/r95.xyz
# Cope hit: MR_552609_1 → saved to cope_xyz/r96.xyz
# Cope hit: MR_562023_0 → saved to cope_xyz/r97.xyz
# Cope hit: MR_568848_0 → saved to cope_xyz/r98.xyz
# Cope hit: MR_573402_1 → saved to cope_xyz/r99.xyz
# Cope hit: MR_59616_0 → saved to cope_xyz/r100.xyz
# Cope hit: MR_59616_1 → saved to cope_xyz/r101.xyz
# Cope hit: MR_611121_0 → saved to cope_xyz/r102.xyz
# Cope hit: MR_611121_2 → saved to cope_xyz/r103.xyz
# Cope hit: MR_639470_0 → saved to cope_xyz/r104.xyz
# Cope hit: MR_646017_2 → saved to cope_xyz/r105.xyz
# Cope hit: MR_683412_1 → saved to cope_xyz/r106.xyz
# Cope hit: MR_697272_1 → saved to cope_xyz/r107.xyz
# Cope hit: MR_706003_1 → saved to cope_xyz/r108.xyz
# Cope hit: MR_706657_0 → saved to cope_xyz/r109.xyz
# Cope hit: MR_81708_0 → saved to cope_xyz/r110.xyz
# Cope hit: MR_81708_1 → saved to cope_xyz/r111.xyz
# Cope hit: MR_81708_2 → saved to cope_xyz/r112.xyz
# Cope hit: MR_94012_0 → saved to cope_xyz/r113.xyz
# Cope hit: MR_94012_2 → saved to cope_xyz/r114.xyz
# Summary of hits:
#   Cope: 115

# %%
import os
from rdkit import Chem
from ase import Atoms
from ase.io import write

# SMARTS patterns for Beckmann rearrangement
oxime_pat  = Chem.MolFromSmarts("[CX3]=[NX2]-[OX2H]")  # R1R2C=NOH
amide_pat  = Chem.MolFromSmarts("[CX3](=O)[NX3]")      # R1C(=O)NR2

def to_atoms(numbers, positions):
    return Atoms(numbers=numbers, positions=positions)

def find_beckmann_and_save_xyz(chno_h5, rps_h5=None, randp_txt=None,
                               xyz_dir="beckmann_xyz"):
    """
    Finds Beckmann rearrangement reactions in RGD1 (oxime -> amide)
    and saves reactant, TS, and product geometries to individual .xyz files.
    """
    loader = RGD1Loader(chno_h5_path=chno_h5,
                        rps_h5_path=rps_h5,
                        randp_smiles_txt=randp_txt)
    os.makedirs(xyz_dir, exist_ok=True)

    hits = 0
    for rxn in loader:
        rid = rxn["rxn_id"]
        r_sm = rxn["reactant"]["smiles"]
        p_sm = rxn["product"]["smiles"]
        r_mol = Chem.MolFromSmiles(r_sm)
        p_mol = Chem.MolFromSmiles(p_sm)
        if not r_mol or not p_mol:
            continue

        # detect Beckmann: oxime -> amide
        if r_mol.HasSubstructMatch(oxime_pat) and p_mol.HasSubstructMatch(amide_pat):
            hits += 1
            print(f"Beckmann hit: {rid}  {r_sm} → {p_sm}")

            # save XYZ files
            for state in ("reactant", "transition_state", "product"):
                geom = rxn[state]
                atoms = to_atoms(geom["atomic_numbers"], geom["positions"])
                filename = os.path.join(xyz_dir, f"r{hits-1}.xyz")
                write(filename, atoms, append=True, format="extxyz")
            print(f"  → saved geometries to {xyz_dir}/{rid}_*.xyz")

    print(f"\nTotal Beckmann reactions found: {hits}")

# Example usage:
if __name__ == "__main__":
    CHNO    = "RGD1_CHNO.h5"
    RPS     = None            # optional
    MAPPING = None            # optional

    find_beckmann_and_save_xyz(CHNO, RPS, MAPPING)
# Out:
# Beckmann hit: MR_100791_1  O/N=C/[C@H](C(=O)O)C → C/C=C\N(C(=O)O)O
#   → saved geometries to beckmann_xyz/MR_100791_1_*.xyz
# Beckmann hit: MR_1010_0  C/C(=N\O)/OCC → CCN(C(=O)C)O
#   → saved geometries to beckmann_xyz/MR_1010_0_*.xyz
# Beckmann hit: MR_102368_0  C/C(=N\O)/OC(=O)N → ON(C(=O)N)C(=O)C
#   → saved geometries to beckmann_xyz/MR_102368_0_*.xyz
# Beckmann hit: MR_102381_1  CC(=O)O/C(=N/O)/N → ON(C(=O)N)C(=O)C
#   → saved geometries to beckmann_xyz/MR_102381_1_*.xyz
# Beckmann hit: MR_110072_0  C/C(=N\O)/OC=C → CC(=O)N(C=C)O
#   → saved geometries to beckmann_xyz/MR_110072_0_*.xyz
# Beckmann hit: MR_114005_0  CC(O)(O)N.ON=C → NC(=O)O.CN(O)C
#   → saved geometries to beckmann_xyz/MR_114005_0_*.xyz
# Beckmann hit: MR_114201_2  O/N=C(/CC(=O)O)\C → CC(=C)N(C(=O)O)O
#   → saved geometries to beckmann_xyz/MR_114201_2_*.xyz
# Beckmann hit: MR_116607_0  CC(=O)C.C/C=N\O → CC(N(C(=O)C)O)C
#   → saved geometries to beckmann_xyz/MR_116607_0_*.xyz
# Beckmann hit: MR_120529_1  CC(=O)N.ON=C → CC(=O)N(CN)O
#   → saved geometries to beckmann_xyz/MR_120529_1_*.xyz
# Beckmann hit: MR_120532_1  N/C=N\O.CC=O → CC(=O)N(CN)O
#   → saved geometries to beckmann_xyz/MR_120532_1_*.xyz
# Beckmann hit: MR_121316_0  C/C(=N\O)/OC → CC(=O)N(O)C
#   → saved geometries to beckmann_xyz/MR_121316_0_*.xyz
# Beckmann hit: MR_124437_0  CCC=O.ON=C → CCCN(C=O)O
#   → saved geometries to beckmann_xyz/MR_124437_0_*.xyz
# Beckmann hit: MR_129551_1  O/N=C\C(=O)CO → OC[C@@H]1N(C1=O)O
#   → saved geometries to beckmann_xyz/MR_129551_1_*.xyz
# Beckmann hit: MR_137126_2  COC(=O)/C=N/O → CO[C@H]1N(C1=O)O
#   → saved geometries to beckmann_xyz/MR_137126_2_*.xyz
# Beckmann hit: MR_139129_1  CCC(=O)N.ON=C → CCCN(C(=O)N)O
#   → saved geometries to beckmann_xyz/MR_139129_1_*.xyz
# Beckmann hit: MR_143838_2  C/C(=N\O)/NC(=O)N → CC(=N)N(C(=O)N)O
#   → saved geometries to beckmann_xyz/MR_143838_2_*.xyz
# Beckmann hit: MR_145007_0  C[N@H+](O)/C([O-])=N/O → ONC(=O)N(O)C
#   → saved geometries to beckmann_xyz/MR_145007_0_*.xyz
# Beckmann hit: MR_150883_1  CC(O/C(=N/O)/N)C → CC(N(C(=O)N)O)C
#   → saved geometries to beckmann_xyz/MR_150883_1_*.xyz
# Beckmann hit: MR_150884_0  ON=C(C)C.NC=O → CC(N(C(=O)N)O)C
#   → saved geometries to beckmann_xyz/MR_150884_0_*.xyz
# Beckmann hit: MR_153667_1  O/N=C\CCC=O → O=CN(C1CC1)O
#   → saved geometries to beckmann_xyz/MR_153667_1_*.xyz
# Beckmann hit: MR_155136_1  C/C=N/O.N=C=O → C/C(=N/O)/NC=O
#   → saved geometries to beckmann_xyz/MR_155136_1_*.xyz
# Beckmann hit: MR_160004_1  C/C(=N\O)/N.NC(=O)O → NC(=O)N([C@](O)(N)C)O
#   → saved geometries to beckmann_xyz/MR_160004_1_*.xyz
# Beckmann hit: MR_160100_0  CC(C(=O)/C=N/O)C → CC([C@@H]1C(=O)N1O)C
#   → saved geometries to beckmann_xyz/MR_160100_0_*.xyz
# Beckmann hit: MR_160100_2  CC(C(=O)/C=N/O)C → CC([C@@H]1C(=O)N1O)C
#   → saved geometries to beckmann_xyz/MR_160100_2_*.xyz
# Beckmann hit: MR_163440_0  NC(=O)O.C/C=N/O → C[C@H](N(C(=O)O)O)N
#   → saved geometries to beckmann_xyz/MR_163440_0_*.xyz
# Beckmann hit: MR_164567_0  O/N=C\CN=C=O → ON1[C@@H]2CN2C1=O
#   → saved geometries to beckmann_xyz/MR_164567_0_*.xyz
# Beckmann hit: MR_168255_0  CCC(=O)/C(=N\O)/C → C[C@@]1(CC)N(C1=O)O
#   → saved geometries to beckmann_xyz/MR_168255_0_*.xyz
# Beckmann hit: MR_173907_0  CC(=O)C/C=N/O → CC(=O)N(C=C)O
#   → saved geometries to beckmann_xyz/MR_173907_0_*.xyz
# Beckmann hit: MR_174227_2  NC(=O)C(=N)/C=N/O → NC(=O)N(C=C=N)O
#   → saved geometries to beckmann_xyz/MR_174227_2_*.xyz
# Beckmann hit: MR_185477_1  ON=C.NC=O.C=C → CN(CCC(=O)N)O
#   → saved geometries to beckmann_xyz/MR_185477_1_*.xyz
# Beckmann hit: MR_186207_0  C/C(=N\O)/OCN → CC(=O)N(CN)O
#   → saved geometries to beckmann_xyz/MR_186207_0_*.xyz
# Beckmann hit: MR_186221_2  NC(=O)/C(=N/O)/O → [C-](=[OH+])N(C(=O)N)O
#   → saved geometries to beckmann_xyz/MR_186221_2_*.xyz
# Beckmann hit: MR_193436_0  ON=C(C)C.CNC(=O)C → CNC(N(C(=O)C)O)(C)C
#   → saved geometries to beckmann_xyz/MR_193436_0_*.xyz
# Beckmann hit: MR_193533_0  C/C(=N\O)/N.CC(=O)C → CC(=O)N(C(N)(C)C)O
#   → saved geometries to beckmann_xyz/MR_193533_0_*.xyz
# Beckmann hit: MR_195569_1  C[C@@H](C(=O)N)/C(=N/O)/N → C/C=C(\N(C(=O)N)O)/N
#   → saved geometries to beckmann_xyz/MR_195569_1_*.xyz
# Beckmann hit: MR_195580_1  C=C(N)[N+](=C)/C([O-])=N/O → C=NC(=O)N(C(=C)N)O
#   → saved geometries to beckmann_xyz/MR_195580_1_*.xyz
# Beckmann hit: MR_197855_2  C/C(=N/O)/C(=O)N → NC(=O)O.CC#N
#   → saved geometries to beckmann_xyz/MR_197855_2_*.xyz
# Beckmann hit: MR_198378_1  O/N=C/O.CC=O → CC(=O)N(CO)O
#   → saved geometries to beckmann_xyz/MR_198378_1_*.xyz
# Beckmann hit: MR_198379_1  O/N=C\O.CC=O → CC(=O)N(CO)O
#   → saved geometries to beckmann_xyz/MR_198379_1_*.xyz
# Beckmann hit: MR_202501_0  CO/C(=N/O)/O → OC(=O)N(O)C
#   → saved geometries to beckmann_xyz/MR_202501_0_*.xyz
# Beckmann hit: MR_202701_0  O/N=C/C(=C)C(=O)O → ON(C(=O)O)C=C=C
#   → saved geometries to beckmann_xyz/MR_202701_0_*.xyz
# Beckmann hit: MR_202701_1  O/N=C/C(=C)C(=O)O → ON(C(=O)O)C=C=C
#   → saved geometries to beckmann_xyz/MR_202701_1_*.xyz
# Beckmann hit: MR_202817_1  O/N=C(/[C@@H](O)C)\O → ONC(=O)[C@@H](O)C
#   → saved geometries to beckmann_xyz/MR_202817_1_*.xyz
# Beckmann hit: MR_205413_0  C/C(=N\O)/CC(=O)C → ON(C(=O)C)C(=C)C
#   → saved geometries to beckmann_xyz/MR_205413_0_*.xyz
# Beckmann hit: MR_206789_0  NC(=O)C/C=N/O → NC(=O)N(C=C)O
#   → saved geometries to beckmann_xyz/MR_206789_0_*.xyz
# Beckmann hit: MR_212348_1  C[C@H](O)N.C/C=N/O → ONC(C)C.NC=O
#   → saved geometries to beckmann_xyz/MR_212348_1_*.xyz
# Beckmann hit: MR_216263_1  CC(=C)O/C(=N/O)/N → CC(=C)N(C(=O)N)O
#   → saved geometries to beckmann_xyz/MR_216263_1_*.xyz
# Beckmann hit: MR_227872_2  CC(=O)/C=N\O → C[C@H]1N(C1=O)O
#   → saved geometries to beckmann_xyz/MR_227872_2_*.xyz
# Beckmann hit: MR_229866_0  CC(=O)C(=C)/C=N/O → CC(=O)N(C=C=C)O
#   → saved geometries to beckmann_xyz/MR_229866_0_*.xyz
# Beckmann hit: MR_230710_0  NC(=O)O/C(=N/O)/O → ON(C(=O)O)C(=O)N
#   → saved geometries to beckmann_xyz/MR_230710_0_*.xyz
# Beckmann hit: MR_230710_1  NC(=O)O/C(=N/O)/O → ON(C(=O)O)C(=O)N
#   → saved geometries to beckmann_xyz/MR_230710_1_*.xyz
# Beckmann hit: MR_230939_0  CC(O/C=N/O)C → O=CN(C(C)C)O
#   → saved geometries to beckmann_xyz/MR_230939_0_*.xyz
# Beckmann hit: MR_244419_2  O/N=C(/O)\C → CC(=O)NO
#   → saved geometries to beckmann_xyz/MR_244419_2_*.xyz
# Beckmann hit: MR_244573_2  ON=C(C)C.NCO → ONC(C)C.NC=O
#   → saved geometries to beckmann_xyz/MR_244573_2_*.xyz
# Beckmann hit: MR_247470_1  C1OC1=O.C/C=N/O → C[C@@H]1COC(=O)N1O
#   → saved geometries to beckmann_xyz/MR_247470_1_*.xyz
# Beckmann hit: MR_247723_1  O/N=C(/C(=N)C(=O)O)\C → CC(=C=N)N(C(=O)O)O
#   → saved geometries to beckmann_xyz/MR_247723_1_*.xyz
# Beckmann hit: MR_24799_0  CC(=O)C#C.ON=C → CC(=O)N(CC#C)O
#   → saved geometries to beckmann_xyz/MR_24799_0_*.xyz
# Beckmann hit: MR_24811_2  C/C=N/O.CC=O → CCN(C(=O)C)O
#   → saved geometries to beckmann_xyz/MR_24811_2_*.xyz
# Beckmann hit: MR_251514_1  C/C(=N\O)/CCC=O → O=CN(C1(C)CC1)O
#   → saved geometries to beckmann_xyz/MR_251514_1_*.xyz
# Beckmann hit: MR_252948_1  N/C(=N\O)/OC(=O)N → ON(C(=O)N)C(=O)N
#   → saved geometries to beckmann_xyz/MR_252948_1_*.xyz
# Beckmann hit: MR_255365_1  ON=C.NC=O.C#C → NC(=O)N(CC=C)O
#   → saved geometries to beckmann_xyz/MR_255365_1_*.xyz
# Beckmann hit: MR_255901_0  O/N=C(/N(C(=O)N)C)\C → C/C(=N\C)/N(C(=O)N)O
#   → saved geometries to beckmann_xyz/MR_255901_0_*.xyz
# Beckmann hit: MR_257296_1  NC(=O)C(=O)C.ON=C → NC(=O)CN(C(=O)C)O
#   → saved geometries to beckmann_xyz/MR_257296_1_*.xyz
# Beckmann hit: MR_257875_2  CC=C=O.ON=C.N → C[C@@H](C(=O)N)N(O)C
#   → saved geometries to beckmann_xyz/MR_257875_2_*.xyz
# Beckmann hit: MR_259852_2  N/C(=N\O)/OC=O → O=CN(C(=O)N)O
#   → saved geometries to beckmann_xyz/MR_259852_2_*.xyz
# Beckmann hit: MR_260510_0  O/N=C\N(C)C.[C-]#[O+] → O/N=C\C(=O)N(C)C
#   → saved geometries to beckmann_xyz/MR_260510_0_*.xyz
# Beckmann hit: MR_260614_1  C#C.[NH3+]/C([O-])=N/O → NC(=O)N(C=C)O
#   → saved geometries to beckmann_xyz/MR_260614_1_*.xyz
# Beckmann hit: MR_265372_0  OC/C(=N/O)/O → OCC(=O)NO
#   → saved geometries to beckmann_xyz/MR_265372_0_*.xyz
# Beckmann hit: MR_265372_1  OC/C(=N/O)/O → OCC(=O)NO
#   → saved geometries to beckmann_xyz/MR_265372_1_*.xyz
# Beckmann hit: MR_267302_1  C=C[N@H+](C)/C([O-])=N/O → CNC(=O)N(C=C)O
#   → saved geometries to beckmann_xyz/MR_267302_1_*.xyz
# Beckmann hit: MR_271375_0  CC(=O)N/C=N\O → CN([C@H]1NC1=O)O
#   → saved geometries to beckmann_xyz/MR_271375_0_*.xyz
# Beckmann hit: MR_274290_0  CC(=C)O/C(=N/O)/O → CC(=C)N(C(=O)O)O
#   → saved geometries to beckmann_xyz/MR_274290_0_*.xyz
# Beckmann hit: MR_274586_0  NC(=O)/C=N\O → NC(=O)O.C#N
#   → saved geometries to beckmann_xyz/MR_274586_0_*.xyz
# Beckmann hit: MR_274587_1  NC(=O)/C=N/O → NC(=O)C#N.O
#   → saved geometries to beckmann_xyz/MR_274587_1_*.xyz
# Beckmann hit: MR_274645_0  N/C(=N\O)/NC(=O)N → ON(C(=O)N)C(=N)N
#   → saved geometries to beckmann_xyz/MR_274645_0_*.xyz
# Beckmann hit: MR_274654_1  N/C(=N\O)/NC(=O)N → N[C@@]1(NC1=O)N(O)N
#   → saved geometries to beckmann_xyz/MR_274654_1_*.xyz
# Beckmann hit: MR_278606_0  C/C=N\O.OC=O → C[C@@H](N(C=O)O)O
#   → saved geometries to beckmann_xyz/MR_278606_0_*.xyz
# Beckmann hit: MR_278983_1  CC(=O)C/C(=N/O)/N → NC(=C)N(C(=O)C)O
#   → saved geometries to beckmann_xyz/MR_278983_1_*.xyz
# Beckmann hit: MR_283509_2  CN/C=N\O.[C-]#[O+] → CNC(=O)/C=N\O
#   → saved geometries to beckmann_xyz/MR_283509_2_*.xyz
# Beckmann hit: MR_285708_1  O/N=C/C=C/C(=O)N → NC(=O)[C@H]1C=CN1O
#   → saved geometries to beckmann_xyz/MR_285708_1_*.xyz
# Beckmann hit: MR_285709_0  NC(=O)/C=N/O.C#C → O/N=C\C=C/C(=O)N
#   → saved geometries to beckmann_xyz/MR_285709_0_*.xyz
# Beckmann hit: MR_287076_0  O/N=C/CC=O → C=CN(C=O)O
#   → saved geometries to beckmann_xyz/MR_287076_0_*.xyz
# Beckmann hit: MR_287076_1  O/N=C/CC=O → C=CN(C=O)O
#   → saved geometries to beckmann_xyz/MR_287076_1_*.xyz
# Beckmann hit: MR_287852_0  N/C(=N\O)/OC(=O)N → ON(C(=O)N)C(=O)N
#   → saved geometries to beckmann_xyz/MR_287852_0_*.xyz
# Beckmann hit: MR_291262_1  O/N=C(\[C@@H](C(=O)N)N)/N → N/C=C(/N(C(=O)N)O)\N
#   → saved geometries to beckmann_xyz/MR_291262_1_*.xyz
# Beckmann hit: MR_295766_0  C/C(=N/O)/N.CN=C=O → O=C1N(C)[C@](N1O)(C)N
#   → saved geometries to beckmann_xyz/MR_295766_0_*.xyz
# Beckmann hit: MR_295767_1  C/C(=N/O)/N.CN=C=O → CN1N(O)[C@@](C1=O)(C)N
#   → saved geometries to beckmann_xyz/MR_295767_1_*.xyz
# Beckmann hit: MR_297140_0  NO/C(=N/O)/O → OC(=O)N(O)N
#   → saved geometries to beckmann_xyz/MR_297140_0_*.xyz
# Beckmann hit: MR_298613_1  C/C(=N/O)/CC(=O)N → C[C@@]1(CN1O)C(=O)N
#   → saved geometries to beckmann_xyz/MR_298613_1_*.xyz
# Beckmann hit: MR_300127_0  NC(=O)N.ON=C.CC → NC(=O)N.CCN(O)C
#   → saved geometries to beckmann_xyz/MR_300127_0_*.xyz
# Beckmann hit: MR_304785_0  NN/C=N\O.[C-]#[O+] → NNC(=O)/C=N\O
#   → saved geometries to beckmann_xyz/MR_304785_0_*.xyz
# Beckmann hit: MR_304789_1  NNC(=O)/C=N\O → NNC(=O)O.C#N
#   → saved geometries to beckmann_xyz/MR_304789_1_*.xyz
# Beckmann hit: MR_307342_1  C/C(=N/O)/N.CC(=O)NO → C[C@@](N(C(=O)C)O)(NO)N
#   → saved geometries to beckmann_xyz/MR_307342_1_*.xyz
# Beckmann hit: MR_308080_1  NC(=O)N/C=N/O → NN([C@@H]1NC1=O)O
#   → saved geometries to beckmann_xyz/MR_308080_1_*.xyz
# Beckmann hit: MR_308515_0  CC(C)C.O/N=C(/O)\C → CC(=O)NO.CC=C.C
#   → saved geometries to beckmann_xyz/MR_308515_0_*.xyz
# Beckmann hit: MR_308736_0  O/N=C(\C(=N)C=O)/C → CC(=C=N)N(C=O)O
#   → saved geometries to beckmann_xyz/MR_308736_0_*.xyz
# Beckmann hit: MR_308995_0  O/N=C(\C(=O)C(C)(C)C)/C → ON1C(=O)[C@]1(C)C(C)(C)C
#   → saved geometries to beckmann_xyz/MR_308995_0_*.xyz
# Beckmann hit: MR_308995_2  O/N=C(/C(=O)C(C)(C)C)\C → ON1C(=O)[C@]1(C)C(C)(C)C
#   → saved geometries to beckmann_xyz/MR_308995_2_*.xyz
# Beckmann hit: MR_310715_1  NC(=N)O.ON=C → CN(NC(=O)N)O
#   → saved geometries to beckmann_xyz/MR_310715_1_*.xyz
# Beckmann hit: MR_311433_0  O/N=C(/O)\N.[C-]#[O+] → NC(=O)/C(=N\O)/O
#   → saved geometries to beckmann_xyz/MR_311433_0_*.xyz
# Beckmann hit: MR_319523_1  CC(=O)N/C=N\O → CC(=O)N(C=N)O
#   → saved geometries to beckmann_xyz/MR_319523_1_*.xyz
# Beckmann hit: MR_321285_1  C=NO/C=N/O → ON(N=C)C=O
#   → saved geometries to beckmann_xyz/MR_321285_1_*.xyz
# Beckmann hit: MR_321286_0  C=NO/C=N/O → ON(N=C)C=O
#   → saved geometries to beckmann_xyz/MR_321286_0_*.xyz
# Beckmann hit: MR_321336_0  CC(=O)N/C(=N/O)/N → NC(=N)N(C(=O)C)O
#   → saved geometries to beckmann_xyz/MR_321336_0_*.xyz
# Beckmann hit: MR_321336_1  CC(=O)N/C(=N/O)/N → NC(=N)N(C(=O)C)O
#   → saved geometries to beckmann_xyz/MR_321336_1_*.xyz
# Beckmann hit: MR_322501_1  O/N=C(/N(C(=O)C)C)\C → C/N=C(/N(C(=O)C)O)\C
#   → saved geometries to beckmann_xyz/MR_322501_1_*.xyz
# Beckmann hit: MR_322506_1  C/C(=N\O)/OC(=N)C → ON(C(=O)C)C(=N)C
#   → saved geometries to beckmann_xyz/MR_322506_1_*.xyz
# Beckmann hit: MR_324787_1  O/N=C(/C(C(=O)N)(C)C)\C → NC(=O)N(C(=C(C)C)C)O
#   → saved geometries to beckmann_xyz/MR_324787_1_*.xyz
# Beckmann hit: MR_324788_1  O/N=C(/C(C(=O)N)(C)C)\C → ON1C([C@]1(C)C(=O)N)(C)C
#   → saved geometries to beckmann_xyz/MR_324788_1_*.xyz
# Beckmann hit: MR_325575_2  ON/C(=N\O)/N.[C-]#[O+] → ONC(=O)/C(=N\O)/N
#   → saved geometries to beckmann_xyz/MR_325575_2_*.xyz
# Beckmann hit: MR_336970_1  O/N=C(/O)\C.CC#N → C/C=N/N(C(=O)C)O
#   → saved geometries to beckmann_xyz/MR_336970_1_*.xyz
# Beckmann hit: MR_336971_0  C=NO/C(=N/O)/C → CC(=O)N(N=C)O
#   → saved geometries to beckmann_xyz/MR_336971_0_*.xyz
# Beckmann hit: MR_345617_1  NC(=O)C=C.ON=C → C=C[N+](=C)[O-].NC=O
#   → saved geometries to beckmann_xyz/MR_345617_1_*.xyz
# Beckmann hit: MR_345652_2  ON=C(O)O.CC=C → ONC(=O)O.CC=C
#   → saved geometries to beckmann_xyz/MR_345652_2_*.xyz
# Beckmann hit: MR_346709_1  ON=C.C=O → CN(C=O)O
#   → saved geometries to beckmann_xyz/MR_346709_1_*.xyz
# Beckmann hit: MR_349137_0  O/N=C/O.NC=O → NC(=O)N(CO)O
#   → saved geometries to beckmann_xyz/MR_349137_0_*.xyz
# Beckmann hit: MR_352556_1  C=NO/C(=N\O)/C → CC(=O)N(N=C)O
#   → saved geometries to beckmann_xyz/MR_352556_1_*.xyz
# Beckmann hit: MR_356173_0  N/C=N\O.NC=O → N[C@H](C(=O)N)NO
#   → saved geometries to beckmann_xyz/MR_356173_0_*.xyz
# Beckmann hit: MR_356173_2  N/C=N\O.NC=O → N[C@H](C(=O)N)NO
#   → saved geometries to beckmann_xyz/MR_356173_2_*.xyz
# Beckmann hit: MR_35805_0  O/N=C(/O)\N → NC(=O)NO
#   → saved geometries to beckmann_xyz/MR_35805_0_*.xyz
# Beckmann hit: MR_36162_2  O/N=C(/C(=O)C(C)C)\C → CC([C@@]1(C)C(=O)N1O)C
#   → saved geometries to beckmann_xyz/MR_36162_2_*.xyz
# Beckmann hit: MR_362819_0  N/C(=N\O)/CC(=O)N → ON(C(=O)N)C(=C)N
#   → saved geometries to beckmann_xyz/MR_362819_0_*.xyz
# Beckmann hit: MR_363525_0  O/N=C/C=O → ON1CC1=O
#   → saved geometries to beckmann_xyz/MR_363525_0_*.xyz
# Beckmann hit: MR_367361_1  O/N=C(/C(C(=O)C)(C)C)\N → CC(=C(N(C(=O)C)O)N)C
#   → saved geometries to beckmann_xyz/MR_367361_1_*.xyz
# Beckmann hit: MR_372102_0  CC(=O)C.ON=C → ON1CC1=O.CC
#   → saved geometries to beckmann_xyz/MR_372102_0_*.xyz
# Beckmann hit: MR_374220_0  ON=C.C=C=O → O=C1CCN1O
#   → saved geometries to beckmann_xyz/MR_374220_0_*.xyz
# Beckmann hit: MR_374585_0  C/C(=N\O)/C(=O)N → C/C(=N\C(=O)N)/O
#   → saved geometries to beckmann_xyz/MR_374585_0_*.xyz
# Beckmann hit: MR_375850_1  COC(=O)C.C/C=N\O → CO[C@@H](N(C(=O)C)O)C
#   → saved geometries to beckmann_xyz/MR_375850_1_*.xyz
# Beckmann hit: MR_37819_0  N/C(=N\O)/CC=O → NC(=C)N(C=O)O
#   → saved geometries to beckmann_xyz/MR_37819_0_*.xyz
# Beckmann hit: MR_381269_0  ON=C(C)C.COC=O → COC(N(C=O)O)(C)C
#   → saved geometries to beckmann_xyz/MR_381269_0_*.xyz
# Beckmann hit: MR_382334_0  O/N=C\C(C(=O)O)(C)C → CC(=CN(C(=O)O)O)C
#   → saved geometries to beckmann_xyz/MR_382334_0_*.xyz
# Beckmann hit: MR_382334_1  O/N=C/C(C(=O)O)(C)C → CC(=CN(C(=O)O)O)C
#   → saved geometries to beckmann_xyz/MR_382334_1_*.xyz
# Beckmann hit: MR_38462_2  CC(=O)O.N/C=N\O → CC(=O)N([C@@H](O)N)O
#   → saved geometries to beckmann_xyz/MR_38462_2_*.xyz
# Beckmann hit: MR_385944_2  O/N=C(\O)/N.NC=O → N[C@H](N(C(=O)N)O)O
#   → saved geometries to beckmann_xyz/MR_385944_2_*.xyz
# Beckmann hit: MR_385964_0  O/N=C(/O)\N.NC=O → N[C@H](N(C(=O)N)O)O
#   → saved geometries to beckmann_xyz/MR_385964_0_*.xyz
# Beckmann hit: MR_385964_1  O/N=C(\O)/N.NC=O → N[C@H](N(C(=O)N)O)O
#   → saved geometries to beckmann_xyz/MR_385964_1_*.xyz
# Beckmann hit: MR_385964_2  O/N=C(\O)/N.NC=O → N[C@H](N(C(=O)N)O)O
#   → saved geometries to beckmann_xyz/MR_385964_2_*.xyz
# Beckmann hit: MR_38677_0  O/N=C(/O)\C.CO → CC(=O)NO.CO
#   → saved geometries to beckmann_xyz/MR_38677_0_*.xyz
# Beckmann hit: MR_388406_0  C/C(=N\O)/OC=N → CC(=O)N(C=N)O
#   → saved geometries to beckmann_xyz/MR_388406_0_*.xyz
# Beckmann hit: MR_388410_0  C/C(=N\O)/OC=N → CC(=O)NO.[C-]#[NH+]
#   → saved geometries to beckmann_xyz/MR_388410_0_*.xyz
# Beckmann hit: MR_389351_1  O/N=C(/C(=N)C(=O)O)\N → NC(=C=N)N(C(=O)O)O
#   → saved geometries to beckmann_xyz/MR_389351_1_*.xyz
# Beckmann hit: MR_389965_1  O/N=C(/C(=C)C=O)\C → CC(=C=C)N(C=O)O
#   → saved geometries to beckmann_xyz/MR_389965_1_*.xyz
# Beckmann hit: MR_389966_0  O/N=C(/C(=C)C=O)\C → CC(=C=C)N(C=O)O
#   → saved geometries to beckmann_xyz/MR_389966_0_*.xyz
# Beckmann hit: MR_412955_0  CCO/C=N/O → CCN(C=O)O
#   → saved geometries to beckmann_xyz/MR_412955_0_*.xyz
# Beckmann hit: MR_412955_2  CCO/C=N/O → CCN(C=O)O
#   → saved geometries to beckmann_xyz/MR_412955_2_*.xyz
# Beckmann hit: MR_416885_0  CN(C(=O)N)/C=N/O → C/N=C/N(C(=O)N)O
#   → saved geometries to beckmann_xyz/MR_416885_0_*.xyz
# Beckmann hit: MR_416885_1  CN(C(=O)N)/C=N/O → C/N=C/N(C(=O)N)O
#   → saved geometries to beckmann_xyz/MR_416885_1_*.xyz
# Beckmann hit: MR_416890_1  CNC(=O)N/C=N/O → CNN([C@@H]1NC1=O)O
#   → saved geometries to beckmann_xyz/MR_416890_1_*.xyz
# Beckmann hit: MR_419452_1  C/C(=N\O)/CC=O → CC(=C)N(C=O)O
#   → saved geometries to beckmann_xyz/MR_419452_1_*.xyz
# Beckmann hit: MR_420313_1  CN(C(=O)N)C.ON=C → CN(C(=O)N)C.C#N.O
#   → saved geometries to beckmann_xyz/MR_420313_1_*.xyz
# Beckmann hit: MR_420315_1  NC(=O)N.ON=C(C)C → NC(=O)N(C(N)(C)C)O
#   → saved geometries to beckmann_xyz/MR_420315_1_*.xyz
# Beckmann hit: MR_422095_0  C[N@@H+](N)/C([O-])=N/O → CN(C(=O)NO)N
#   → saved geometries to beckmann_xyz/MR_422095_0_*.xyz
# Beckmann hit: MR_422573_0  CC(=O)C(=N)/C=N/O → CC(=O)N(C=C=N)O
#   → saved geometries to beckmann_xyz/MR_422573_0_*.xyz
# Beckmann hit: MR_422573_1  CC(=O)C(=N)/C=N/O → CC(=O)N(C=C=N)O
#   → saved geometries to beckmann_xyz/MR_422573_1_*.xyz
# Beckmann hit: MR_424327_1  ON=C(C)C.CNC(=O)O → CNC(N(C(=O)O)O)(C)C
#   → saved geometries to beckmann_xyz/MR_424327_1_*.xyz
# Beckmann hit: MR_424333_0  NC(=O)O.ON=C(C)C → ON(C(O)(C)C)C(=O)N
#   → saved geometries to beckmann_xyz/MR_424333_0_*.xyz
# Beckmann hit: MR_42816_0  O/N=C/C(=C)C=O → ON(C=O)C=C=C
#   → saved geometries to beckmann_xyz/MR_42816_0_*.xyz
# Beckmann hit: MR_428174_1  O/N=C/C(=O)C(=O)O → O=C=CN(C(=O)O)O
#   → saved geometries to beckmann_xyz/MR_428174_1_*.xyz
# Beckmann hit: MR_428174_2  O/N=C/C(=O)C(=O)O → O=C=CN(C(=O)O)O
#   → saved geometries to beckmann_xyz/MR_428174_2_*.xyz
# Beckmann hit: MR_431071_2  O/N=C\O.N=C=O → O=CN(C(=O)N)O
#   → saved geometries to beckmann_xyz/MR_431071_2_*.xyz
# Beckmann hit: MR_43377_0  CC/C=N\O.CC=O → CCCN(C(=O)C)O
#   → saved geometries to beckmann_xyz/MR_43377_0_*.xyz
# Beckmann hit: MR_43377_2  CC/C=N\O.CC=O → CCCN(C(=O)C)O
#   → saved geometries to beckmann_xyz/MR_43377_2_*.xyz
# Beckmann hit: MR_434957_0  N/C(=N/O)/C(=O)N.[C-]#[NH+] → O/N=C(\C(=N)C(=O)N)/N
#   → saved geometries to beckmann_xyz/MR_434957_0_*.xyz
# Beckmann hit: MR_440413_1  CCC(=O)NO.ON=C → CCN(CC(=O)NO)O
#   → saved geometries to beckmann_xyz/MR_440413_1_*.xyz
# Beckmann hit: MR_442148_1  O/C(=N\O)/OC=C → ON(C(=O)O)C=C
#   → saved geometries to beckmann_xyz/MR_442148_1_*.xyz
# Beckmann hit: MR_442780_0  CC=C=O.ON=C → C[C@@H]1CN(C1=O)O
#   → saved geometries to beckmann_xyz/MR_442780_0_*.xyz
# Beckmann hit: MR_443551_0  N/C(=N/O)/C(=O)N → NC(=O)O.NC#N
#   → saved geometries to beckmann_xyz/MR_443551_0_*.xyz
# Beckmann hit: MR_444530_0  C/C(=N\O)/NNC=O → O=CN(C1(C)NN1)O
#   → saved geometries to beckmann_xyz/MR_444530_0_*.xyz
# Beckmann hit: MR_44790_1  CCO/C(=N/O)/N → CCN(C(=O)N)O
#   → saved geometries to beckmann_xyz/MR_44790_1_*.xyz
# Beckmann hit: MR_44793_0  C/C=N/O.NC=O → CCN(C(=O)N)O
#   → saved geometries to beckmann_xyz/MR_44793_0_*.xyz
# Beckmann hit: MR_447986_1  N/C(=N/O)/NN.[C-]#[O+] → NNC(=O)/C(=N\O)/N
#   → saved geometries to beckmann_xyz/MR_447986_1_*.xyz
# Beckmann hit: MR_449455_0  CC(=O)O.ON=C(N)N → ON(C(O)(N)N)C(=O)C
#   → saved geometries to beckmann_xyz/MR_449455_0_*.xyz
# Beckmann hit: MR_449520_0  NC(=O)C(=O)C.ON=C → CC(=O)CN(C(=O)N)O
#   → saved geometries to beckmann_xyz/MR_449520_0_*.xyz
# Beckmann hit: MR_456796_1  CN(C(=O)N)/C(=N/O)/N → C/N=C(/N(C(=O)N)O)\N
#   → saved geometries to beckmann_xyz/MR_456796_1_*.xyz
# Beckmann hit: MR_462448_1  O/N=C(/O)\C.CC=C.C → CC(=O)NO.CC(C)C
#   → saved geometries to beckmann_xyz/MR_462448_1_*.xyz
# Beckmann hit: MR_462882_0  CC(=O)O/C=N/O → O=CN(C(=O)C)O
#   → saved geometries to beckmann_xyz/MR_462882_0_*.xyz
# Beckmann hit: MR_46319_0  CC(=O)O.ON=C → CCN(C(=O)O)O
#   → saved geometries to beckmann_xyz/MR_46319_0_*.xyz
# Beckmann hit: MR_46326_1  COC(=O)C.ON=C → COCN(C(=O)C)O
#   → saved geometries to beckmann_xyz/MR_46326_1_*.xyz
# Beckmann hit: MR_464712_1  ON=C(C)C.NC=O → ONC(C(=O)N)(C)C
#   → saved geometries to beckmann_xyz/MR_464712_1_*.xyz
# Beckmann hit: MR_464712_2  ON=C(C)C.NC=O → ONC(C(=O)N)(C)C
#   → saved geometries to beckmann_xyz/MR_464712_2_*.xyz
# Beckmann hit: MR_469646_0  O/N=C(/NC(=O)C#C)\C → C[C@@]1(NC1=O)N(C#C)O
#   → saved geometries to beckmann_xyz/MR_469646_0_*.xyz
# Beckmann hit: MR_473073_1  C/C(=N\O)/N.OC(=O)O → OC(=O)N([C@](O)(N)C)O
#   → saved geometries to beckmann_xyz/MR_473073_1_*.xyz
# Beckmann hit: MR_489102_1  N=C=O.ON=C → O=NCC(=O)N
#   → saved geometries to beckmann_xyz/MR_489102_1_*.xyz
# Beckmann hit: MR_496245_1  O/N=C(\[C@](O)(N)C)/C → CC(=O)N.CC#N.O
#   → saved geometries to beckmann_xyz/MR_496245_1_*.xyz
# Beckmann hit: MR_507931_1  NNC(=O)N.C/C=N/O → NN[C@H](N(C(=O)N)O)C
#   → saved geometries to beckmann_xyz/MR_507931_1_*.xyz
# Beckmann hit: MR_509963_0  CC(=O)C/C=N\O → CC(=O)N(C=C)O
#   → saved geometries to beckmann_xyz/MR_509963_0_*.xyz
# Beckmann hit: MR_511248_1  CC(=O)CO/C(=N\O)/N → CC(=O)N([C@]1(N)CO1)O
#   → saved geometries to beckmann_xyz/MR_511248_1_*.xyz
# Beckmann hit: MR_511252_1  CC(=O)C.O/N=C(\O)/N → CC(=O)N([C@@](O)(N)C)O
#   → saved geometries to beckmann_xyz/MR_511252_1_*.xyz
# Beckmann hit: MR_513555_0  ON=C.OC=O → ON(C=O)CO
#   → saved geometries to beckmann_xyz/MR_513555_0_*.xyz
# Beckmann hit: MR_514096_1  C=[N+](C)/C([O-])=N/O → CN(C(=O)N=C)O
#   → saved geometries to beckmann_xyz/MR_514096_1_*.xyz
# Beckmann hit: MR_516602_0  CO/C(=N/O)/N → CN(C(=O)N)O
#   → saved geometries to beckmann_xyz/MR_516602_0_*.xyz
# Beckmann hit: MR_517982_0  C/C(=N/O)/OC=O → O=CN(C(=O)C)O
#   → saved geometries to beckmann_xyz/MR_517982_0_*.xyz
# Beckmann hit: MR_519820_0  ON=C(C)C.NNC=O → NNC(N(C=O)O)(C)C
#   → saved geometries to beckmann_xyz/MR_519820_0_*.xyz
# Beckmann hit: MR_524893_1  CN(C(=O)C)/C=N/O → C/N=C/N(C(=O)C)O
#   → saved geometries to beckmann_xyz/MR_524893_1_*.xyz
# Beckmann hit: MR_524894_1  CN(C(=O)C)/C=N/O → C/N=C\N(C(=O)C)O
#   → saved geometries to beckmann_xyz/MR_524894_1_*.xyz
# Beckmann hit: MR_527028_0  N/C(=N/O)/CCC=O → O=CN(C1(N)CC1)O
#   → saved geometries to beckmann_xyz/MR_527028_0_*.xyz
# Beckmann hit: MR_539540_2  O/N=C(/C(=O)[C@@H](N)C)\C → C[C@]1([C@@H](N)C)N(C1=O)O
#   → saved geometries to beckmann_xyz/MR_539540_2_*.xyz
# Beckmann hit: MR_540024_2  O/N=C(\O)/C.C=C.CO → CC(=O)NO.COCC
#   → saved geometries to beckmann_xyz/MR_540024_2_*.xyz
# Beckmann hit: MR_541205_2  O/N=C(\O)/C.NC=O.C=O → NC(=O)CO.CC(=O)NO
#   → saved geometries to beckmann_xyz/MR_541205_2_*.xyz
# Beckmann hit: MR_544941_0  NC(=O)C#C.ON=C → NC(=O)N(CC#C)O
#   → saved geometries to beckmann_xyz/MR_544941_0_*.xyz
# Beckmann hit: MR_54690_0  CC(=O)O.C/C=N/O → C[C@H](N(C(=O)C)O)O
#   → saved geometries to beckmann_xyz/MR_54690_0_*.xyz
# Beckmann hit: MR_547153_1  O/N=C/C/C=C(\O)/N → ON[C@H]1C[C@H]1C(=O)N
#   → saved geometries to beckmann_xyz/MR_547153_1_*.xyz
# Beckmann hit: MR_549318_1  CC(=O)NO.ON=C → ONC(=O)CN(O)C
#   → saved geometries to beckmann_xyz/MR_549318_1_*.xyz
# Beckmann hit: MR_555239_0  ON=C(N)N.COC(=O)C → COC(N(C(=O)C)O)(N)N
#   → saved geometries to beckmann_xyz/MR_555239_0_*.xyz
# Beckmann hit: MR_557837_0  CC(=O)N/C(=N/O)/O → OC(=N)N(C(=O)C)O
#   → saved geometries to beckmann_xyz/MR_557837_0_*.xyz
# Beckmann hit: MR_558064_0  N/C(=N\O)/C(=O)N → N/C(=N\C(=O)N)/O
#   → saved geometries to beckmann_xyz/MR_558064_0_*.xyz
# Beckmann hit: MR_56022_0  O/N=C\C(=O)NO.[H][H] → ONCC(=O)NO
#   → saved geometries to beckmann_xyz/MR_56022_0_*.xyz
# Beckmann hit: MR_56136_0  C/C(=N/O)/NC(=O)C → C[C@@]1(NC1=O)N(O)C
#   → saved geometries to beckmann_xyz/MR_56136_0_*.xyz
# Beckmann hit: MR_56164_0  C/C(=N\O)/NC(=O)C → ON(C(=O)C)C(=N)C
#   → saved geometries to beckmann_xyz/MR_56164_0_*.xyz
# Beckmann hit: MR_56164_1  C/C(=N\O)/NC(=O)C → ON(C(=O)C)C(=N)C
#   → saved geometries to beckmann_xyz/MR_56164_1_*.xyz
# Beckmann hit: MR_563486_0  C=C(C)[N+](=C)/C([O-])=N/O → C=NC(=O)N(C(=C)C)O
#   → saved geometries to beckmann_xyz/MR_563486_0_*.xyz
# Beckmann hit: MR_568091_1  C[C@H](C(=O)N)/C(=N/O)/O → C/C=C(\N(C(=O)N)O)/O
#   → saved geometries to beckmann_xyz/MR_568091_1_*.xyz
# Beckmann hit: MR_572484_1  ON=C(N)N.CC=O → NC(N(C(=O)C)O)N
#   → saved geometries to beckmann_xyz/MR_572484_1_*.xyz
# Beckmann hit: MR_574663_0  O/N=C(/ON(C)C)\C → CN(N(C(=O)C)O)C
#   → saved geometries to beckmann_xyz/MR_574663_0_*.xyz
# Beckmann hit: MR_582137_1  C/C(=N\O)/OC=O → O=CN(C(=O)C)O
#   → saved geometries to beckmann_xyz/MR_582137_1_*.xyz
# Beckmann hit: MR_586281_0  O/N=C/NC(=O)O → ON(C(=O)O)C=N
#   → saved geometries to beckmann_xyz/MR_586281_0_*.xyz
# Beckmann hit: MR_586281_1  O/N=C/NC(=O)O → ON(C(=O)O)C=N
#   → saved geometries to beckmann_xyz/MR_586281_1_*.xyz
# Beckmann hit: MR_586652_0  C/C(=N\O)/OCC(=O)N → C/C(=N\O)/C(=O)N.C=O
#   → saved geometries to beckmann_xyz/MR_586652_0_*.xyz
# Beckmann hit: MR_590196_2  ONO/C=N/O → ON(C=O)NO
#   → saved geometries to beckmann_xyz/MR_590196_2_*.xyz
# Beckmann hit: MR_595069_2  CC(=N)C=O.C/C=N/O → C[C@@H](C(=N)C)N(C=O)O
#   → saved geometries to beckmann_xyz/MR_595069_2_*.xyz
# Beckmann hit: MR_597868_0  NCO/C=N/O → NCN(C=O)O
#   → saved geometries to beckmann_xyz/MR_597868_0_*.xyz
# Beckmann hit: MR_597870_0  ON=C.NC=O → NCN(C=O)O
#   → saved geometries to beckmann_xyz/MR_597870_0_*.xyz
# Beckmann hit: MR_597872_0  N/C=N\O.C=O → NCN(C=O)O
#   → saved geometries to beckmann_xyz/MR_597872_0_*.xyz
# Beckmann hit: MR_598890_0  NCC(=N)/C(=N\O)/O → NCC(=N)C(=O)NO
#   → saved geometries to beckmann_xyz/MR_598890_0_*.xyz
# Beckmann hit: MR_604157_0  NC(=O)/C(=N/O)/O → OC(=NC(=O)N)O
#   → saved geometries to beckmann_xyz/MR_604157_0_*.xyz
# Beckmann hit: MR_609493_1  CN(C(=O)N)O.C/C=N\O → C[C@@H](N(O)C)N(C(=O)N)O
#   → saved geometries to beckmann_xyz/MR_609493_1_*.xyz
# Beckmann hit: MR_61143_0  C/C=N/O.NC=O → C[C@H](C(=O)N)NO
#   → saved geometries to beckmann_xyz/MR_61143_0_*.xyz
# Beckmann hit: MR_624692_1  O/N=C/C(=O)C=O → O=C=CN(C=O)O
#   → saved geometries to beckmann_xyz/MR_624692_1_*.xyz
# Beckmann hit: MR_632293_0  C[C@@H](C(=O)/C=N\O)N → C[C@@H]([C@H]1N(C1=O)O)N
#   → saved geometries to beckmann_xyz/MR_632293_0_*.xyz
# Beckmann hit: MR_632293_2  C[C@@H](C(=O)/C=N\O)N → C[C@@H]([C@H]1N(C1=O)O)N
#   → saved geometries to beckmann_xyz/MR_632293_2_*.xyz
# Beckmann hit: MR_637665_0  NC(=O)O.C/C=N\O → C[C@H](C(=O)N)N(O)O
#   → saved geometries to beckmann_xyz/MR_637665_0_*.xyz
# Beckmann hit: MR_639202_0  OC(=O)O.ON=C(C)C → OC(=O)N(C(O)(C)C)O
#   → saved geometries to beckmann_xyz/MR_639202_0_*.xyz
# Beckmann hit: MR_639218_0  NOC(=O)N.C/C=N\O → NO[C@H](N(C(=O)N)O)C
#   → saved geometries to beckmann_xyz/MR_639218_0_*.xyz
# Beckmann hit: MR_639219_0  NOC(=O)N.ON=C → NC(=O)O.C#N.NO
#   → saved geometries to beckmann_xyz/MR_639219_0_*.xyz
# Beckmann hit: MR_644034_1  O/N=C(/O)\C.COC=O → O=CN([C@](OC)(O)C)O
#   → saved geometries to beckmann_xyz/MR_644034_1_*.xyz
# Beckmann hit: MR_644174_0  O=CC(=O)O.ON=C → O=CN(CC(=O)O)O
#   → saved geometries to beckmann_xyz/MR_644174_0_*.xyz
# Beckmann hit: MR_645697_1  O/N=C\C(=O)O.O → OCN(C(=O)O)O
#   → saved geometries to beckmann_xyz/MR_645697_1_*.xyz
# Beckmann hit: MR_646783_0  ON=C1CN(C1)C(=O)O → ON([C@]12CN2C1)C(=O)O
#   → saved geometries to beckmann_xyz/MR_646783_0_*.xyz
# Beckmann hit: MR_646783_1  ON=C1CN(C1)C(=O)O → ON([C@]12CN2C1)C(=O)O
#   → saved geometries to beckmann_xyz/MR_646783_1_*.xyz
# Beckmann hit: MR_647097_1  O/N=C(\CC(=C)C=O)/C → C[C@@]1(CC1=C)N(C=O)O
#   → saved geometries to beckmann_xyz/MR_647097_1_*.xyz
# Beckmann hit: MR_651542_0  [H]/N=C/[N+](=C)/C([O-])=N/O → ON(C(=O)N=C)C=N
#   → saved geometries to beckmann_xyz/MR_651542_0_*.xyz
# Beckmann hit: MR_651636_2  O/C(=N/O)/CC=N → ONC(=O)CC=N
#   → saved geometries to beckmann_xyz/MR_651636_2_*.xyz
# Beckmann hit: MR_654049_1  CC(=O)O/C=N\O → O=CN(C(=O)C)O
#   → saved geometries to beckmann_xyz/MR_654049_1_*.xyz
# Beckmann hit: MR_654051_1  C[C@H](/C(=N/O)/O)C=O → O=CN(/C(=C\C)/O)O
#   → saved geometries to beckmann_xyz/MR_654051_1_*.xyz
# Beckmann hit: MR_655870_0  C=C(C)[N+](=C)/C([O-])=N/O → C=NC(=O)N(C(=C)C)O
#   → saved geometries to beckmann_xyz/MR_655870_0_*.xyz
# Beckmann hit: MR_658993_0  O/N=C(/C(=C)C=O)\N → NC(=C=C)N(C=O)O
#   → saved geometries to beckmann_xyz/MR_658993_0_*.xyz
# Beckmann hit: MR_659435_1  C[C@@H]1C/C/1=N\O.N=C=O → C[C@@H]1C/C(=N\O)/NC1=O
#   → saved geometries to beckmann_xyz/MR_659435_1_*.xyz
# Beckmann hit: MR_660351_1  NC(=O)C#C.C/C=N\O → C[C@H](C(=O)N)N(C#C)O
#   → saved geometries to beckmann_xyz/MR_660351_1_*.xyz
# Beckmann hit: MR_664416_0  O/N=C/O.NC=O → NC(=O)[C@@H](NO)O
#   → saved geometries to beckmann_xyz/MR_664416_0_*.xyz
# Beckmann hit: MR_669153_1  O/N=C/OC=C → C=CN(C=O)O
#   → saved geometries to beckmann_xyz/MR_669153_1_*.xyz
# Beckmann hit: MR_669153_2  O/N=C/OC=C → C=CN(C=O)O
#   → saved geometries to beckmann_xyz/MR_669153_2_*.xyz
# Beckmann hit: MR_670827_0  O/N=C(\[C@@](C(=O)C)(N)C)/C → C/C(=C(/N(C(=O)C)O)\C)/N
#   → saved geometries to beckmann_xyz/MR_670827_0_*.xyz
# Beckmann hit: MR_672396_0  O/N=C/C(=N)C=O → ON(C=O)C=C=N
#   → saved geometries to beckmann_xyz/MR_672396_0_*.xyz
# Beckmann hit: MR_672396_2  O/N=C/C(=N)C=O → ON(C=O)C=C=N
#   → saved geometries to beckmann_xyz/MR_672396_2_*.xyz
# Beckmann hit: MR_673356_1  O/N=C(\C(=C)C=O)/O → O=CN(C(=C=C)O)O
#   → saved geometries to beckmann_xyz/MR_673356_1_*.xyz
# Beckmann hit: MR_678744_1  NC(=O)C(=N)N/C=N/O → NC(=O)N([C@@H]1NC1=N)O
#   → saved geometries to beckmann_xyz/MR_678744_1_*.xyz
# Beckmann hit: MR_68172_2  CCO/C=N/O → CCN(C=O)O
#   → saved geometries to beckmann_xyz/MR_68172_2_*.xyz
# Beckmann hit: MR_68173_2  C/C=N/O.C=O → CCN(C=O)O
#   → saved geometries to beckmann_xyz/MR_68173_2_*.xyz
# Beckmann hit: MR_682095_0  N[NH+](N)/C([O-])=N/O → ONC(=O)N(N)N
#   → saved geometries to beckmann_xyz/MR_682095_0_*.xyz
# Beckmann hit: MR_683937_1  ON=C(C)C.COC(=O)N → COC(N(C(=O)N)O)(C)C
#   → saved geometries to beckmann_xyz/MR_683937_1_*.xyz
# Beckmann hit: MR_695504_1  CC(=O)C(=N)/C=N/O → CC(=O)N(C=C=N)O
#   → saved geometries to beckmann_xyz/MR_695504_1_*.xyz
# Beckmann hit: MR_70213_0  ON=C.NC=O → CN(C(=O)N)O
#   → saved geometries to beckmann_xyz/MR_70213_0_*.xyz
# Beckmann hit: MR_73259_1  N/C(=N\O)/OC=C → NC(=O)N(C=C)O
#   → saved geometries to beckmann_xyz/MR_73259_1_*.xyz
# Beckmann hit: MR_73546_0  C[C@H](C(=O)N)/C=N\O → C/C=C\N(C(=O)N)O
#   → saved geometries to beckmann_xyz/MR_73546_0_*.xyz
# Beckmann hit: MR_73547_0  C[C@H](C(=O)N)/C=N\O → C/C=C/N(C(=O)N)O
#   → saved geometries to beckmann_xyz/MR_73547_0_*.xyz
# Beckmann hit: MR_89455_0  O/N=C/OC(C)(C)C → O=CN(C(C)(C)C)O
#   → saved geometries to beckmann_xyz/MR_89455_0_*.xyz
# Beckmann hit: MR_90023_0  C=NO/C(=N/O)/N → NC(=O)N(N=C)O
#   → saved geometries to beckmann_xyz/MR_90023_0_*.xyz
# Beckmann hit: MR_90023_2  C=NO/C(=N/O)/N → NC(=O)N(N=C)O
#   → saved geometries to beckmann_xyz/MR_90023_2_*.xyz
# Beckmann hit: MR_90889_2  C/C(=N/O)/N.CNC(=O)N → C[C@](C(=O)N)(N(NC)O)N
#   → saved geometries to beckmann_xyz/MR_90889_2_*.xyz
# Beckmann hit: MR_90916_2  C/C(=N/O)/N.NC(=O)N → NN([C@@](C(=O)N)(N)C)O
#   → saved geometries to beckmann_xyz/MR_90916_2_*.xyz
# Beckmann hit: MR_92377_2  C/C(=N\O)/C(=O)C → C/[C-]=[N+](/C(=O)C)\O
#   → saved geometries to beckmann_xyz/MR_92377_2_*.xyz
# Beckmann hit: MR_94956_0  C/C(=N\O)/OC(=C)C → ON(C(=O)C)C(=C)C
#   → saved geometries to beckmann_xyz/MR_94956_0_*.xyz
#
# Total Beckmann reactions found: 272

# %%
import os
from rdkit import Chem
from ase import Atoms
from ase.io import write

# SMARTS patterns for Curtius
acyl_azide_pat = Chem.MolFromSmarts('[CX3](=O)N=[NX2]=[NX1]')
isocyanate_pat = Chem.MolFromSmarts('[NX2]=[CX2]=[OX1]')

def to_atoms(geom):
    return Atoms(numbers=geom['atomic_numbers'], positions=geom['positions'])

def find_curtius_and_save_extxyz(checkpoint_path, xyz_dir="curtius_extxyz"):
    loader = RGD1Loader(checkpoint_path)
    os.makedirs(xyz_dir, exist_ok=True)

    idx = 0
    for rxn in loader:
        r_mol = Chem.MolFromSmiles(rxn['reactant']['smiles'])
        p_mol = Chem.MolFromSmiles(rxn['product']['smiles'])
        if not r_mol or not p_mol:
            continue

        if r_mol.HasSubstructMatch(acyl_azide_pat) and p_mol.HasSubstructMatch(isocyanate_pat):
            filename = os.path.join(xyz_dir, f"curtius_{idx}.xyz")
            if os.path.exists(filename):
                os.remove(filename)

            for state in ("reactant", "transition_state", "product"):
                geom = rxn[state]
                atoms = to_atoms(geom)
                atoms.info["rxn_id"] = rxn["rxn_id"]
                atoms.info["state"] = state
                write(filename, atoms, append=True, format="extxyz")

            print(f"Saved Curtius reaction {rxn['rxn_id']} to {filename}")
            idx += 1

    print(f"\nTotal Curtius rearrangements saved: {idx}")

if __name__ == "__main__":
    find_curtius_and_save_extxyz("RGD1_CHNO.h5")
# Out:
# Total Curtius rearrangements saved: 0

# %%
import os
from rdkit import Chem
from ase import Atoms
from ase.io import write

# SMARTS for Lossen rearrangement (hydroxamic acid → isocyanate)
hydroxamic_pat = Chem.MolFromSmarts('[CX3](=O)N[OX2H]')
isocyanate_pat = Chem.MolFromSmarts('[NX2]=[CX2]=[OX1]')

# SMARTS for Cannizzaro reaction (disproportionation of two aldehydes)
aldehyde_pat = Chem.MolFromSmarts('[CX3H1](=O)[#6]')
alcohol_pat  = Chem.MolFromSmarts('[CX4H2][OX2H]')
acid_pat     = Chem.MolFromSmarts('[CX3](=O)[OX2H]')

def to_atoms(geom):
    """Convert geometry dict to an ASE Atoms object."""
    return Atoms(numbers=geom['atomic_numbers'], positions=geom['positions'])

def save_extxyz(rxn, idx, rxn_type, out_dir):
    """
    Write reactant, TS, and product of a single reaction
    into one extended-XYZ file named {rxn_type}_{idx}.xyz.
    """
    os.makedirs(out_dir, exist_ok=True)
    fname = os.path.join(out_dir, f"r{idx}.xyz")
    # Remove existing to start fresh
    if os.path.exists(fname):
        os.remove(fname)
    for state in ('reactant', 'transition_state', 'product'):
        geom = rxn[state]
        atoms = to_atoms(geom)
        atoms.info['rxn_id'] = rxn['rxn_id']
        atoms.info['state']  = state
        write(fname, atoms, append=True, format='extxyz')

def find_lossen(chno_h5, out_dir="lossen_extxyz"):
    """
    Scan RGD1 for Lossen rearrangements (hydroxamic acid → isocyanate)
    and save each hit to an extended XYZ.
    """
    loader = RGD1Loader(chno_h5)
    idx = 0
    for rxn in loader:
        r_sm = rxn['reactant']['smiles']
        p_sm = rxn['product']['smiles']
        r_mol = Chem.MolFromSmiles(r_sm)
        p_mol = Chem.MolFromSmiles(p_sm)
        if r_mol and p_mol:
            if (r_mol.HasSubstructMatch(hydroxamic_pat)
             and p_mol.HasSubstructMatch(isocyanate_pat)):
                save_extxyz(rxn, idx, "lossen", out_dir)
                print(f"Lossen hit: {rxn['rxn_id']} → {out_dir}/lossen_{idx}.xyz")
                idx += 1
    print(f"Total Lossen hits: {idx}")

def find_cannizzaro(chno_h5, out_dir="cannizzaro_extxyz"):
    """
    Scan RGD1 for Cannizzaro reactions (2 R–CHO → R–CH2OH + R–COOH)
    and save each hit to an extended XYZ.
    """
    loader = RGD1Loader(chno_h5)
    idx = 0
    for rxn in loader:
        r_sm = rxn['reactant']['smiles']
        p_sm = rxn['product']['smiles']
        # Reactant must be two aldehydes
        frags_r = r_sm.split('.')
        if len(frags_r) != 2:
            continue
        mols_r = [Chem.MolFromSmiles(f) for f in frags_r]
        if any(m is None for m in mols_r):
            continue
        if not all(m.HasSubstructMatch(aldehyde_pat) for m in mols_r):
            continue
        # Product must be one alcohol + one acid
        frags_p = p_sm.split('.')
        if len(frags_p) != 2:
            continue
        mols_p = [Chem.MolFromSmiles(f) for f in frags_p]
        if any(m is None for m in mols_p):
            continue
        if ( any(m.HasSubstructMatch(alcohol_pat) for m in mols_p)
          and any(m.HasSubstructMatch(acid_pat)    for m in mols_p) ):
            save_extxyz(rxn, idx, "cannizzaro", out_dir)
            print(f"Cannizzaro hit: {rxn['rxn_id']} → {out_dir}/cannizzaro_{idx}.xyz")
            idx += 1
    print(f"Total Cannizzaro hits: {idx}")

if __name__ == "__main__":
    # Path to your RGD1_CHNO.h5
    CHNO_PATH = "RGD1_CHNO.h5"

    # Find and save Lossen rearrangements
    find_lossen(CHNO_PATH, out_dir="lossen_extxyz")

    # Find and save Cannizzaro reactions
    find_cannizzaro(CHNO_PATH, out_dir="cannizzaro_extxyz")
# Out:
# Lossen hit: MR_110070_1 → lossen_extxyz/lossen_0.xyz
# Lossen hit: MR_118404_1 → lossen_extxyz/lossen_1.xyz
# Lossen hit: MR_119727_0 → lossen_extxyz/lossen_2.xyz
# Lossen hit: MR_124830_0 → lossen_extxyz/lossen_3.xyz
# Lossen hit: MR_125002_2 → lossen_extxyz/lossen_4.xyz
# Lossen hit: MR_143778_0 → lossen_extxyz/lossen_5.xyz
# Lossen hit: MR_145939_1 → lossen_extxyz/lossen_6.xyz
# Lossen hit: MR_148737_0 → lossen_extxyz/lossen_7.xyz
# Lossen hit: MR_148737_1 → lossen_extxyz/lossen_8.xyz
# Lossen hit: MR_176761_2 → lossen_extxyz/lossen_9.xyz
# Lossen hit: MR_199418_0 → lossen_extxyz/lossen_10.xyz
# Lossen hit: MR_199418_2 → lossen_extxyz/lossen_11.xyz
# Lossen hit: MR_202499_0 → lossen_extxyz/lossen_12.xyz
# Lossen hit: MR_202818_1 → lossen_extxyz/lossen_13.xyz
# Lossen hit: MR_205252_1 → lossen_extxyz/lossen_14.xyz
# Lossen hit: MR_215323_1 → lossen_extxyz/lossen_15.xyz
# Lossen hit: MR_216566_2 → lossen_extxyz/lossen_16.xyz
# Lossen hit: MR_220656_1 → lossen_extxyz/lossen_17.xyz
# Lossen hit: MR_224101_1 → lossen_extxyz/lossen_18.xyz
# Lossen hit: MR_225275_1 → lossen_extxyz/lossen_19.xyz
# Lossen hit: MR_225517_0 → lossen_extxyz/lossen_20.xyz
# Lossen hit: MR_225517_1 → lossen_extxyz/lossen_21.xyz
# Lossen hit: MR_230699_0 → lossen_extxyz/lossen_22.xyz
# Lossen hit: MR_241129_0 → lossen_extxyz/lossen_23.xyz
# Lossen hit: MR_245271_1 → lossen_extxyz/lossen_24.xyz
# Lossen hit: MR_248529_0 → lossen_extxyz/lossen_25.xyz
# Lossen hit: MR_252925_0 → lossen_extxyz/lossen_26.xyz
# Lossen hit: MR_253410_1 → lossen_extxyz/lossen_27.xyz
# Lossen hit: MR_254984_0 → lossen_extxyz/lossen_28.xyz
# Lossen hit: MR_262815_1 → lossen_extxyz/lossen_29.xyz
# Lossen hit: MR_267301_1 → lossen_extxyz/lossen_30.xyz
# Lossen hit: MR_287850_0 → lossen_extxyz/lossen_31.xyz
# Lossen hit: MR_297938_1 → lossen_extxyz/lossen_32.xyz
# Lossen hit: MR_298596_1 → lossen_extxyz/lossen_33.xyz
# Lossen hit: MR_307260_2 → lossen_extxyz/lossen_34.xyz
# Lossen hit: MR_307346_0 → lossen_extxyz/lossen_35.xyz
# Lossen hit: MR_31130_0 → lossen_extxyz/lossen_36.xyz
# Lossen hit: MR_31130_2 → lossen_extxyz/lossen_37.xyz
# Lossen hit: MR_312953_0 → lossen_extxyz/lossen_38.xyz
# Lossen hit: MR_312956_0 → lossen_extxyz/lossen_39.xyz
# Lossen hit: MR_314921_1 → lossen_extxyz/lossen_40.xyz
# Lossen hit: MR_316843_0 → lossen_extxyz/lossen_41.xyz
# Lossen hit: MR_316843_2 → lossen_extxyz/lossen_42.xyz
# Lossen hit: MR_321233_1 → lossen_extxyz/lossen_43.xyz
# Lossen hit: MR_321233_2 → lossen_extxyz/lossen_44.xyz
# Lossen hit: MR_35804_2 → lossen_extxyz/lossen_45.xyz
# Lossen hit: MR_367674_0 → lossen_extxyz/lossen_46.xyz
# Lossen hit: MR_368802_2 → lossen_extxyz/lossen_47.xyz
# Lossen hit: MR_369669_1 → lossen_extxyz/lossen_48.xyz
# Lossen hit: MR_376052_0 → lossen_extxyz/lossen_49.xyz
# Lossen hit: MR_376883_1 → lossen_extxyz/lossen_50.xyz
# Lossen hit: MR_383964_2 → lossen_extxyz/lossen_51.xyz
# Lossen hit: MR_385950_1 → lossen_extxyz/lossen_52.xyz
# Lossen hit: MR_385968_1 → lossen_extxyz/lossen_53.xyz
# Lossen hit: MR_408550_1 → lossen_extxyz/lossen_54.xyz
# Lossen hit: MR_418065_1 → lossen_extxyz/lossen_55.xyz
# Lossen hit: MR_420753_0 → lossen_extxyz/lossen_56.xyz
# Lossen hit: MR_421358_1 → lossen_extxyz/lossen_57.xyz
# Lossen hit: MR_422098_2 → lossen_extxyz/lossen_58.xyz
# Lossen hit: MR_424443_0 → lossen_extxyz/lossen_59.xyz
# Lossen hit: MR_435759_1 → lossen_extxyz/lossen_60.xyz
# Lossen hit: MR_437958_1 → lossen_extxyz/lossen_61.xyz
# Lossen hit: MR_438265_1 → lossen_extxyz/lossen_62.xyz
# Lossen hit: MR_438265_2 → lossen_extxyz/lossen_63.xyz
# Lossen hit: MR_438266_2 → lossen_extxyz/lossen_64.xyz
# Lossen hit: MR_439285_0 → lossen_extxyz/lossen_65.xyz
# Lossen hit: MR_442438_0 → lossen_extxyz/lossen_66.xyz
# Lossen hit: MR_444002_0 → lossen_extxyz/lossen_67.xyz
# Lossen hit: MR_444004_0 → lossen_extxyz/lossen_68.xyz
# Lossen hit: MR_456474_0 → lossen_extxyz/lossen_69.xyz
# Lossen hit: MR_466597_0 → lossen_extxyz/lossen_70.xyz
# Lossen hit: MR_478446_0 → lossen_extxyz/lossen_71.xyz
# Lossen hit: MR_480622_1 → lossen_extxyz/lossen_72.xyz
# Lossen hit: MR_483283_0 → lossen_extxyz/lossen_73.xyz
# Lossen hit: MR_498446_0 → lossen_extxyz/lossen_74.xyz
# Lossen hit: MR_503380_0 → lossen_extxyz/lossen_75.xyz
# Lossen hit: MR_507630_0 → lossen_extxyz/lossen_76.xyz
# Lossen hit: MR_507631_1 → lossen_extxyz/lossen_77.xyz
# Lossen hit: MR_510002_0 → lossen_extxyz/lossen_78.xyz
# Lossen hit: MR_510002_2 → lossen_extxyz/lossen_79.xyz
# Lossen hit: MR_512449_1 → lossen_extxyz/lossen_80.xyz
# Lossen hit: MR_512934_0 → lossen_extxyz/lossen_81.xyz
# Lossen hit: MR_517975_0 → lossen_extxyz/lossen_82.xyz
# Lossen hit: MR_517979_1 → lossen_extxyz/lossen_83.xyz
# Lossen hit: MR_522379_1 → lossen_extxyz/lossen_84.xyz
# Lossen hit: MR_527059_1 → lossen_extxyz/lossen_85.xyz
# Lossen hit: MR_530695_2 → lossen_extxyz/lossen_86.xyz
# Lossen hit: MR_551449_1 → lossen_extxyz/lossen_87.xyz
# Lossen hit: MR_554906_1 → lossen_extxyz/lossen_88.xyz
# Lossen hit: MR_562280_2 → lossen_extxyz/lossen_89.xyz
# Lossen hit: MR_570032_0 → lossen_extxyz/lossen_90.xyz
# Lossen hit: MR_571149_2 → lossen_extxyz/lossen_91.xyz
# Lossen hit: MR_582241_0 → lossen_extxyz/lossen_92.xyz
# Lossen hit: MR_583724_1 → lossen_extxyz/lossen_93.xyz
# Lossen hit: MR_584549_0 → lossen_extxyz/lossen_94.xyz
# Lossen hit: MR_585257_1 → lossen_extxyz/lossen_95.xyz
# Lossen hit: MR_588257_1 → lossen_extxyz/lossen_96.xyz
# Lossen hit: MR_594360_2 → lossen_extxyz/lossen_97.xyz
# Lossen hit: MR_594639_1 → lossen_extxyz/lossen_98.xyz
# Lossen hit: MR_595794_1 → lossen_extxyz/lossen_99.xyz
# Lossen hit: MR_600838_0 → lossen_extxyz/lossen_100.xyz
# Lossen hit: MR_600852_0 → lossen_extxyz/lossen_101.xyz
# Lossen hit: MR_609712_1 → lossen_extxyz/lossen_102.xyz
# Lossen hit: MR_614243_0 → lossen_extxyz/lossen_103.xyz
# Lossen hit: MR_629997_1 → lossen_extxyz/lossen_104.xyz
# Lossen hit: MR_632208_0 → lossen_extxyz/lossen_105.xyz
# Lossen hit: MR_638704_1 → lossen_extxyz/lossen_106.xyz
# Lossen hit: MR_638705_1 → lossen_extxyz/lossen_107.xyz
# Lossen hit: MR_639410_0 → lossen_extxyz/lossen_108.xyz
# Lossen hit: MR_639411_0 → lossen_extxyz/lossen_109.xyz
# Lossen hit: MR_641227_1 → lossen_extxyz/lossen_110.xyz
# Lossen hit: MR_646381_1 → lossen_extxyz/lossen_111.xyz
# Lossen hit: MR_651185_0 → lossen_extxyz/lossen_112.xyz
# Lossen hit: MR_651275_1 → lossen_extxyz/lossen_113.xyz
# Lossen hit: MR_655726_2 → lossen_extxyz/lossen_114.xyz
# Lossen hit: MR_655867_0 → lossen_extxyz/lossen_115.xyz
# Lossen hit: MR_656637_1 → lossen_extxyz/lossen_116.xyz
# Lossen hit: MR_656637_2 → lossen_extxyz/lossen_117.xyz
# Lossen hit: MR_659519_0 → lossen_extxyz/lossen_118.xyz
# Lossen hit: MR_668230_1 → lossen_extxyz/lossen_119.xyz
# Lossen hit: MR_675495_0 → lossen_extxyz/lossen_120.xyz
# Lossen hit: MR_675495_1 → lossen_extxyz/lossen_121.xyz
# Lossen hit: MR_675507_0 → lossen_extxyz/lossen_122.xyz
# Lossen hit: MR_679419_0 → lossen_extxyz/lossen_123.xyz
# Lossen hit: MR_684545_0 → lossen_extxyz/lossen_124.xyz
# Lossen hit: MR_68916_1 → lossen_extxyz/lossen_125.xyz
# Lossen hit: MR_693442_0 → lossen_extxyz/lossen_126.xyz
# Lossen hit: MR_69525_0 → lossen_extxyz/lossen_127.xyz
# Lossen hit: MR_70213_1 → lossen_extxyz/lossen_128.xyz
# Lossen hit: MR_80421_0 → lossen_extxyz/lossen_129.xyz
# Lossen hit: MR_80421_2 → lossen_extxyz/lossen_130.xyz
# Lossen hit: MR_86281_0 → lossen_extxyz/lossen_131.xyz
# Lossen hit: MR_87944_2 → lossen_extxyz/lossen_132.xyz
# Lossen hit: MR_89999_0 → lossen_extxyz/lossen_133.xyz
# Lossen hit: MR_93664_1 → lossen_extxyz/lossen_134.xyz
# Total Lossen hits: 135
# Total Cannizzaro hits: 0

# %%
import os
from rdkit import Chem
from ase import Atoms
from ase.io import write

# SMARTS for Alder–ene reaction
# ene donor: allylic H next to C=C -> pattern: [CH2;!$(*=*)]-[CX2]=[CX2]
# enophile: C=O
ene_donor_pat = Chem.MolFromSmarts('[CH2;!$(*=*)]-[CX2]=[CX2]')
enophile_pat  = Chem.MolFromSmarts('[CX3]=O')
alkene_pat    = Chem.MolFromSmarts('[CX3]=[CX3]')  # product alkene or alcohol

# SMARTS for Dieckmann condensation (intramolecular Claisen)
ester_pat = Chem.MolFromSmarts('[CX3](=O)O[#6]')

def to_atoms(geom):
    return Atoms(numbers=geom['atomic_numbers'], positions=geom['positions'])

def save_extxyz(rxn, idx, rxn_type, out_dir):
    os.makedirs(out_dir, exist_ok=True)
    fname = os.path.join(out_dir, f"r{idx}.xyz")
    if os.path.exists(fname):
        os.remove(fname)
    for state in ('reactant', 'transition_state', 'product'):
        geom = rxn[state]
        atoms = to_atoms(geom)
        atoms.info['rxn_id'] = rxn['rxn_id']
        atoms.info['state']  = state
        write(fname, atoms, append=True, format='extxyz')

def find_ene(chno_h5, out_dir="ene_extxyz"):
    """
    Finds Alder–ene type reactions: an ene donor with allylic H and an enophile (C=O).
    """
    loader = RGD1Loader(chno_h5)
    idx = 0
    for rxn in loader:
        r_sm = rxn['reactant']['smiles']
        p_sm = rxn['product']['smiles']
        # require two fragments
        if '.' not in r_sm:
            continue
        frags = r_sm.split('.')
        if len(frags) != 2:
            continue
        donor_mol = Chem.MolFromSmiles(frags[0])
        enophile_mol = Chem.MolFromSmiles(frags[1])
        p_mol = Chem.MolFromSmiles(p_sm)
        if not donor_mol or not enophile_mol or not p_mol:
            continue
        # detect patterns
        if donor_mol.HasSubstructMatch(ene_donor_pat) and enophile_mol.HasSubstructMatch(enophile_pat):
            # product should have new C-O bond: detect alcohol pat
            if p_mol.HasSubstructMatch(Chem.MolFromSmarts('[OX2H]')) and p_mol.HasSubstructMatch(alkene_pat):
                save_extxyz(rxn, idx, "ene", out_dir)
                print(f"Ene hit: {rxn['rxn_id']} → {out_dir}/ene_{idx}.xyz")
                idx += 1
    print(f"Total Ene hits: {idx}")

def find_dieckmann(chno_h5, out_dir="dieckmann_extxyz"):
    """
    Finds Dieckmann condensations: intramolecular di-ester -> cyclic β-keto ester.
    """
    loader = RGD1Loader(chno_h5)
    idx = 0
    for rxn in loader:
        r_sm = rxn['reactant']['smiles']
        # single fragment containing at least two ester groups
        if '.' in r_sm:
            continue
        r_mol = Chem.MolFromSmiles(r_sm)
        p_mol = Chem.MolFromSmiles(rxn['product']['smiles'])
        if not r_mol or not p_mol:
            continue
        # count ester substructures
        ester_matches = r_mol.GetSubstructMatches(ester_pat)
        if len(ester_matches) < 2:
            continue
        # product should be cyclic (ring count > 0)
        if p_mol.GetRingInfo().NumRings() > 0:
            save_extxyz(rxn, idx, "dieckmann", out_dir)
            print(f"Dieckmann hit: {rxn['rxn_id']} → {out_dir}/dieckmann_{idx}.xyz")
            idx += 1
    print(f"Total Dieckmann hits: {idx}")

# Example usage:
find_ene("RGD1_CHNO.h5")
find_dieckmann("RGD1_CHNO.h5")
# Out:
# Total Ene hits: 0
# Dieckmann hit: MR_104396_0 → dieckmann_extxyz/dieckmann_0.xyz
# Dieckmann hit: MR_148002_1 → dieckmann_extxyz/dieckmann_1.xyz
# Dieckmann hit: MR_148012_0 → dieckmann_extxyz/dieckmann_2.xyz
# Dieckmann hit: MR_16903_1 → dieckmann_extxyz/dieckmann_3.xyz
# Dieckmann hit: MR_179761_1 → dieckmann_extxyz/dieckmann_4.xyz
# Dieckmann hit: MR_249031_1 → dieckmann_extxyz/dieckmann_5.xyz
# Dieckmann hit: MR_249057_0 → dieckmann_extxyz/dieckmann_6.xyz
# Dieckmann hit: MR_274870_1 → dieckmann_extxyz/dieckmann_7.xyz
# Dieckmann hit: MR_291167_0 → dieckmann_extxyz/dieckmann_8.xyz
# Dieckmann hit: MR_295877_1 → dieckmann_extxyz/dieckmann_9.xyz
# Dieckmann hit: MR_307782_1 → dieckmann_extxyz/dieckmann_10.xyz
# Dieckmann hit: MR_362268_1 → dieckmann_extxyz/dieckmann_11.xyz
# Dieckmann hit: MR_362396_0 → dieckmann_extxyz/dieckmann_12.xyz
# Dieckmann hit: MR_362929_0 → dieckmann_extxyz/dieckmann_13.xyz
# Dieckmann hit: MR_369955_1 → dieckmann_extxyz/dieckmann_14.xyz
# Dieckmann hit: MR_373937_0 → dieckmann_extxyz/dieckmann_15.xyz
# Dieckmann hit: MR_381432_1 → dieckmann_extxyz/dieckmann_16.xyz
# Dieckmann hit: MR_399272_1 → dieckmann_extxyz/dieckmann_17.xyz
# Dieckmann hit: MR_405417_1 → dieckmann_extxyz/dieckmann_18.xyz
# Dieckmann hit: MR_430966_0 → dieckmann_extxyz/dieckmann_19.xyz
# Dieckmann hit: MR_45140_1 → dieckmann_extxyz/dieckmann_20.xyz
# Dieckmann hit: MR_45155_0 → dieckmann_extxyz/dieckmann_21.xyz
# Dieckmann hit: MR_467452_0 → dieckmann_extxyz/dieckmann_22.xyz
# Dieckmann hit: MR_584525_1 → dieckmann_extxyz/dieckmann_23.xyz
# Dieckmann hit: MR_63193_0 → dieckmann_extxyz/dieckmann_24.xyz
# Dieckmann hit: MR_63195_2 → dieckmann_extxyz/dieckmann_25.xyz
# Dieckmann hit: MR_636152_0 → dieckmann_extxyz/dieckmann_26.xyz
# Dieckmann hit: MR_70168_1 → dieckmann_extxyz/dieckmann_27.xyz
# Dieckmann hit: MR_86175_0 → dieckmann_extxyz/dieckmann_28.xyz
# Dieckmann hit: MR_86175_1 → dieckmann_extxyz/dieckmann_29.xyz
# Total Dieckmann hits: 30

# %%
import os
from rdkit import Chem
from ase import Atoms
from ase.io import write

# Common SMARTS
aldehyde_pat      = Chem.MolFromSmarts('[CX3H1](=O)[#6]')
aldol_product_pat = Chem.MolFromSmarts('C([OX2H])C(=O)')       # β‑hydroxy carbonyl

ester_pat         = Chem.MolFromSmarts('[CX3](=O)O[#6]')
ketone_pat        = Chem.MolFromSmarts('[CX3](=O)[#6]')

hexatriene_pat    = Chem.MolFromSmarts('C=C-C=C-C=C')
cyclohexadiene_pat= Chem.MolFromSmarts('C1=CC=CC=C1')

def to_atoms(geom):
    return Atoms(numbers=geom['atomic_numbers'], positions=geom['positions'])

def save_extxyz(rxn, idx, name, out_dir):
    os.makedirs(out_dir, exist_ok=True)
    fn = os.path.join(out_dir, f"r{idx}.xyz")
    if os.path.exists(fn):
        os.remove(fn)
    for state in ('reactant','transition_state','product'):
        geom = rxn[state]
        atoms = to_atoms(geom)
        atoms.info['rxn_id'] = rxn['rxn_id']
        atoms.info['state']  = state
        write(fn, atoms, append=True, format='extxyz')

def find_aldol(RGD1_h5, out_dir="aldol_extxyz"):
    loader = RGD1Loader(RGD1_h5)
    idx = 0
    for rxn in loader:
        r_sm = rxn['reactant']['smiles']
        p_sm = rxn['product']['smiles']
        if '.' not in r_sm: 
            continue
        frags = r_sm.split('.')
        if len(frags)!=2: 
            continue
        mols = [Chem.MolFromSmiles(f) for f in frags]
        if None in mols: 
            continue
        # both fragments must be aldehydes
        if not all(m.HasSubstructMatch(aldehyde_pat) for m in mols):
            continue
        p_mol = Chem.MolFromSmiles(p_sm)
        if p_mol and p_mol.HasSubstructMatch(aldol_product_pat):
            save_extxyz(rxn, idx, "aldol", out_dir)
            print(f"Aldol hit: {rxn['rxn_id']} → {out_dir}/aldol_{idx}.xyz")
            idx += 1
    print(f"Total Aldol hits: {idx}")

def find_claisen_condensation(RGD1_h5, out_dir="claisen_cond_extxyz"):
    loader = RGD1Loader(RGD1_h5)
    idx = 0
    for rxn in loader:
        r_sm = rxn['reactant']['smiles']
        p_sm = rxn['product']['smiles']
        if '.' not in r_sm:
            continue
        frags = r_sm.split('.')
        if len(frags)!=2:
            continue
        mols = [Chem.MolFromSmiles(f) for f in frags]
        if None in mols:
            continue
        # both fragments must be esters
        if not all(m.HasSubstructMatch(ester_pat) for m in mols):
            continue
        p_mol = Chem.MolFromSmiles(p_sm)
        # product must have at least two ketones and still an ester
        if (p_mol and
            len(p_mol.GetSubstructMatches(ketone_pat)) >= 2 and
            p_mol.HasSubstructMatch(ester_pat)):
            save_extxyz(rxn, idx, "claisen_cond", out_dir)
            print(f"Claisen condensation hit: {rxn['rxn_id']} → {out_dir}/claisen_cond_{idx}.xyz")
            idx += 1
    print(f"Total Claisen condensation hits: {idx}")

def find_electrocyclic(RGD1_h5, out_dir="electrocyclic_extxyz"):
    loader = RGD1Loader(RGD1_h5)
    idx = 0
    for rxn in loader:
        r_sm = rxn['reactant']['smiles']
        p_sm = rxn['product']['smiles']
        # linear hexatriene reactant
        if Chem.MolFromSmiles(r_sm).HasSubstructMatch(hexatriene_pat):
            p_mol = Chem.MolFromSmiles(p_sm)
            # cyclohexadiene product
            if p_mol and p_mol.HasSubstructMatch(cyclohexadiene_pat):
                save_extxyz(rxn, idx, "electrocyclic", out_dir)
                print(f"Electrocyclic hit: {rxn['rxn_id']} → {out_dir}/electrocyclic_{idx}.xyz")
                idx += 1
    print(f"Total electrocyclic hits: {idx}")

if __name__ == "__main__":
    H5 = "RGD1_CHNO.h5"
    find_aldol(H5)
    find_claisen_condensation(H5)
    find_electrocyclic(H5)
# Out:
# Aldol hit: MR_153989_0 → aldol_extxyz/aldol_0.xyz
# Aldol hit: MR_187971_1 → aldol_extxyz/aldol_1.xyz
# Aldol hit: MR_190968_2 → aldol_extxyz/aldol_2.xyz
# Aldol hit: MR_208332_1 → aldol_extxyz/aldol_3.xyz
# Aldol hit: MR_267947_0 → aldol_extxyz/aldol_4.xyz
# Aldol hit: MR_27718_2 → aldol_extxyz/aldol_5.xyz
# Aldol hit: MR_293218_1 → aldol_extxyz/aldol_6.xyz
# Aldol hit: MR_295659_2 → aldol_extxyz/aldol_7.xyz
# Aldol hit: MR_311415_0 → aldol_extxyz/aldol_8.xyz
# Aldol hit: MR_353564_2 → aldol_extxyz/aldol_9.xyz
# Aldol hit: MR_360083_1 → aldol_extxyz/aldol_10.xyz
# Aldol hit: MR_395380_1 → aldol_extxyz/aldol_11.xyz
# Aldol hit: MR_412211_0 → aldol_extxyz/aldol_12.xyz
# Aldol hit: MR_425354_2 → aldol_extxyz/aldol_13.xyz
# Aldol hit: MR_426234_1 → aldol_extxyz/aldol_14.xyz
# Aldol hit: MR_434267_0 → aldol_extxyz/aldol_15.xyz
# Aldol hit: MR_472789_0 → aldol_extxyz/aldol_16.xyz
# Aldol hit: MR_492610_2 → aldol_extxyz/aldol_17.xyz
# Aldol hit: MR_499007_0 → aldol_extxyz/aldol_18.xyz
# Aldol hit: MR_499007_2 → aldol_extxyz/aldol_19.xyz
# Aldol hit: MR_568963_0 → aldol_extxyz/aldol_20.xyz
# Aldol hit: MR_583501_0 → aldol_extxyz/aldol_21.xyz
# Aldol hit: MR_591558_1 → aldol_extxyz/aldol_22.xyz
# Aldol hit: MR_591558_2 → aldol_extxyz/aldol_23.xyz
# Aldol hit: MR_623351_0 → aldol_extxyz/aldol_24.xyz
# Aldol hit: MR_623351_2 → aldol_extxyz/aldol_25.xyz
# Aldol hit: MR_625393_1 → aldol_extxyz/aldol_26.xyz
# Aldol hit: MR_625393_2 → aldol_extxyz/aldol_27.xyz
# Aldol hit: MR_668097_1 → aldol_extxyz/aldol_28.xyz
# Total Aldol hits: 29
# Claisen condensation hit: MR_588684_2 → claisen_cond_extxyz/claisen_cond_0.xyz
# Total Claisen condensation hits: 1
# Total electrocyclic hits: 0

# %%
import os
from rdkit import Chem
from ase import Atoms
from ase.io import write

# SMARTS patterns
ketone_pat   = Chem.MolFromSmarts('[#6][CX3](=O)[#6]')     # R-CO-R'
enol_pat     = Chem.MolFromSmarts('[#6][CX3]=[CX3]O[H]')   # R-C=C-OH

alcohol_pat  = Chem.MolFromSmarts('[CX4H2][OX2H]')         # R-CH2-OH
betaH_pat    = Chem.MolFromSmarts('[#6][CX4H2][#6]')      # CH2 with at least one neighbor C
alkene_pat   = Chem.MolFromSmarts('[#6]=[#6]')            # C=C

def to_atoms(geom):
    return Atoms(numbers=geom['atomic_numbers'], positions=geom['positions'])

def save_extxyz(rxn, idx, name, out_dir):
    os.makedirs(out_dir, exist_ok=True)
    fn = os.path.join(out_dir, f"r{idx}.xyz")
    if os.path.exists(fn):
        os.remove(fn)
    for state in ('reactant', 'transition_state', 'product'):
        geom = rxn[state]
        atoms = to_atoms(geom)
        atoms.info['rxn_id'] = rxn['rxn_id']
        atoms.info['state']  = state
        write(fn, atoms, append=True, format='extxyz')

def find_tautomerism(h5path, out_dir="tautomerism_extxyz"):
    loader = RGD1Loader(h5path)
    idx = 0
    for rxn in loader:
        r_sm = rxn['reactant']['smiles']
        p_sm = rxn['product']['smiles']
        r_mol = Chem.MolFromSmiles(r_sm)
        p_mol = Chem.MolFromSmiles(p_sm)
        if not r_mol or not p_mol:
            continue
        if (r_mol.HasSubstructMatch(ketone_pat)
         and p_mol.HasSubstructMatch(enol_pat)):
            save_extxyz(rxn, idx, "tautomer", out_dir)
            print(f"Tautomerism hit: {rxn['rxn_id']} → {out_dir}/tautomer_{idx}.xyz")
            idx += 1
    print(f"Total keto–enol tautomers: {idx}")

def find_dehydration(h5path, out_dir="dehydration_extxyz"):
    loader = RGD1Loader(h5path)
    idx = 0
    for rxn in loader:
        r_sm = rxn['reactant']['smiles']
        p_sm = rxn['product']['smiles']
        r_mol = Chem.MolFromSmiles(r_sm)
        p_mol = Chem.MolFromSmiles(p_sm)
        if not r_mol or not p_mol:
            continue
        # require an alcohol with a beta‑CH2 in reactant
        if r_mol.HasSubstructMatch(alcohol_pat) and r_mol.HasSubstructMatch(betaH_pat):
            # product must form a C=C
            if p_mol.HasSubstructMatch(alkene_pat):
                save_extxyz(rxn, idx, "dehydration", out_dir)
                print(f"Dehydration hit: {rxn['rxn_id']} → {out_dir}/dehydration_{idx}.xyz")
                idx += 1
    print(f"Total alcohol dehydrations: {idx}")

if __name__ == "__main__":
    H5 = "RGD1_CHNO.h5"
    find_tautomerism(H5)
    find_dehydration(H5)
# Out:
# Total keto–enol tautomers: 0
# Dehydration hit: MR_101772_0 → dehydration_extxyz/dehydration_0.xyz
# Dehydration hit: MR_101773_1 → dehydration_extxyz/dehydration_1.xyz
# Dehydration hit: MR_10322_1 → dehydration_extxyz/dehydration_2.xyz
# Dehydration hit: MR_104325_2 → dehydration_extxyz/dehydration_3.xyz
# Dehydration hit: MR_104852_1 → dehydration_extxyz/dehydration_4.xyz
# Dehydration hit: MR_105613_0 → dehydration_extxyz/dehydration_5.xyz
# Dehydration hit: MR_106761_0 → dehydration_extxyz/dehydration_6.xyz
# Dehydration hit: MR_10709_0 → dehydration_extxyz/dehydration_7.xyz
# Dehydration hit: MR_10709_2 → dehydration_extxyz/dehydration_8.xyz
# Dehydration hit: MR_10730_1 → dehydration_extxyz/dehydration_9.xyz
# Dehydration hit: MR_107709_2 → dehydration_extxyz/dehydration_10.xyz
# Dehydration hit: MR_107794_0 → dehydration_extxyz/dehydration_11.xyz
# Dehydration hit: MR_107794_1 → dehydration_extxyz/dehydration_12.xyz
# Dehydration hit: MR_107794_2 → dehydration_extxyz/dehydration_13.xyz
# Dehydration hit: MR_108837_0 → dehydration_extxyz/dehydration_14.xyz
# Dehydration hit: MR_108837_1 → dehydration_extxyz/dehydration_15.xyz
# Dehydration hit: MR_108868_2 → dehydration_extxyz/dehydration_16.xyz
# Dehydration hit: MR_110231_1 → dehydration_extxyz/dehydration_17.xyz
# Dehydration hit: MR_110234_2 → dehydration_extxyz/dehydration_18.xyz
# Dehydration hit: MR_111748_0 → dehydration_extxyz/dehydration_19.xyz
# Dehydration hit: MR_111748_1 → dehydration_extxyz/dehydration_20.xyz
# Dehydration hit: MR_112981_1 → dehydration_extxyz/dehydration_21.xyz
# Dehydration hit: MR_113591_1 → dehydration_extxyz/dehydration_22.xyz
# Dehydration hit: MR_114248_1 → dehydration_extxyz/dehydration_23.xyz
# Dehydration hit: MR_115036_1 → dehydration_extxyz/dehydration_24.xyz
# Dehydration hit: MR_115899_1 → dehydration_extxyz/dehydration_25.xyz
# Dehydration hit: MR_117076_1 → dehydration_extxyz/dehydration_26.xyz
# Dehydration hit: MR_117752_0 → dehydration_extxyz/dehydration_27.xyz
# Dehydration hit: MR_118325_1 → dehydration_extxyz/dehydration_28.xyz
# Dehydration hit: MR_118583_0 → dehydration_extxyz/dehydration_29.xyz
# Dehydration hit: MR_120788_2 → dehydration_extxyz/dehydration_30.xyz
# Dehydration hit: MR_124713_1 → dehydration_extxyz/dehydration_31.xyz
# Dehydration hit: MR_124713_2 → dehydration_extxyz/dehydration_32.xyz
# Dehydration hit: MR_12692_0 → dehydration_extxyz/dehydration_33.xyz
# Dehydration hit: MR_12737_2 → dehydration_extxyz/dehydration_34.xyz
# Dehydration hit: MR_127846_1 → dehydration_extxyz/dehydration_35.xyz
# Dehydration hit: MR_12818_1 → dehydration_extxyz/dehydration_36.xyz
# Dehydration hit: MR_129520_2 → dehydration_extxyz/dehydration_37.xyz
# Dehydration hit: MR_129543_0 → dehydration_extxyz/dehydration_38.xyz
# Dehydration hit: MR_129543_1 → dehydration_extxyz/dehydration_39.xyz
# Dehydration hit: MR_129971_0 → dehydration_extxyz/dehydration_40.xyz
# Dehydration hit: MR_130070_0 → dehydration_extxyz/dehydration_41.xyz
# Dehydration hit: MR_130384_1 → dehydration_extxyz/dehydration_42.xyz
# Dehydration hit: MR_13059_0 → dehydration_extxyz/dehydration_43.xyz
# Dehydration hit: MR_13059_1 → dehydration_extxyz/dehydration_44.xyz
# Dehydration hit: MR_130637_0 → dehydration_extxyz/dehydration_45.xyz
# Dehydration hit: MR_131007_1 → dehydration_extxyz/dehydration_46.xyz
# Dehydration hit: MR_131787_0 → dehydration_extxyz/dehydration_47.xyz
# Dehydration hit: MR_132679_1 → dehydration_extxyz/dehydration_48.xyz
# Dehydration hit: MR_134294_0 → dehydration_extxyz/dehydration_49.xyz
# Dehydration hit: MR_135458_2 → dehydration_extxyz/dehydration_50.xyz
# Dehydration hit: MR_135706_1 → dehydration_extxyz/dehydration_51.xyz
# Dehydration hit: MR_137839_2 → dehydration_extxyz/dehydration_52.xyz
# Dehydration hit: MR_138937_0 → dehydration_extxyz/dehydration_53.xyz
# Dehydration hit: MR_139065_1 → dehydration_extxyz/dehydration_54.xyz
# Dehydration hit: MR_139067_1 → dehydration_extxyz/dehydration_55.xyz
# Dehydration hit: MR_140019_1 → dehydration_extxyz/dehydration_56.xyz
# Dehydration hit: MR_142612_0 → dehydration_extxyz/dehydration_57.xyz
# Dehydration hit: MR_142612_1 → dehydration_extxyz/dehydration_58.xyz
# Dehydration hit: MR_143470_0 → dehydration_extxyz/dehydration_59.xyz
# Dehydration hit: MR_143471_0 → dehydration_extxyz/dehydration_60.xyz
# Dehydration hit: MR_143471_1 → dehydration_extxyz/dehydration_61.xyz
# Dehydration hit: MR_143471_2 → dehydration_extxyz/dehydration_62.xyz
# Dehydration hit: MR_143475_0 → dehydration_extxyz/dehydration_63.xyz
# Dehydration hit: MR_143475_1 → dehydration_extxyz/dehydration_64.xyz
# Dehydration hit: MR_144610_2 → dehydration_extxyz/dehydration_65.xyz
# Dehydration hit: MR_14501_1 → dehydration_extxyz/dehydration_66.xyz
# Dehydration hit: MR_145537_1 → dehydration_extxyz/dehydration_67.xyz
# Dehydration hit: MR_146063_1 → dehydration_extxyz/dehydration_68.xyz
# Dehydration hit: MR_146068_2 → dehydration_extxyz/dehydration_69.xyz
# Dehydration hit: MR_148097_0 → dehydration_extxyz/dehydration_70.xyz
# Dehydration hit: MR_148533_0 → dehydration_extxyz/dehydration_71.xyz
# Dehydration hit: MR_148743_0 → dehydration_extxyz/dehydration_72.xyz
# Dehydration hit: MR_148819_1 → dehydration_extxyz/dehydration_73.xyz
# Dehydration hit: MR_150808_0 → dehydration_extxyz/dehydration_74.xyz
# Dehydration hit: MR_150808_1 → dehydration_extxyz/dehydration_75.xyz
# Dehydration hit: MR_150811_1 → dehydration_extxyz/dehydration_76.xyz
# Dehydration hit: MR_151957_1 → dehydration_extxyz/dehydration_77.xyz
# Dehydration hit: MR_15307_0 → dehydration_extxyz/dehydration_78.xyz
# Dehydration hit: MR_153524_2 → dehydration_extxyz/dehydration_79.xyz
# Dehydration hit: MR_153612_2 → dehydration_extxyz/dehydration_80.xyz
# Dehydration hit: MR_154103_0 → dehydration_extxyz/dehydration_81.xyz
# Dehydration hit: MR_154662_0 → dehydration_extxyz/dehydration_82.xyz
# Dehydration hit: MR_158057_2 → dehydration_extxyz/dehydration_83.xyz
# Dehydration hit: MR_158129_2 → dehydration_extxyz/dehydration_84.xyz
# Dehydration hit: MR_160991_1 → dehydration_extxyz/dehydration_85.xyz
# Dehydration hit: MR_161358_1 → dehydration_extxyz/dehydration_86.xyz
# Dehydration hit: MR_16143_0 → dehydration_extxyz/dehydration_87.xyz
# Dehydration hit: MR_161819_0 → dehydration_extxyz/dehydration_88.xyz
# Dehydration hit: MR_162134_1 → dehydration_extxyz/dehydration_89.xyz
# Dehydration hit: MR_162236_0 → dehydration_extxyz/dehydration_90.xyz
# Dehydration hit: MR_163086_0 → dehydration_extxyz/dehydration_91.xyz
# Dehydration hit: MR_163487_2 → dehydration_extxyz/dehydration_92.xyz
# Dehydration hit: MR_164130_0 → dehydration_extxyz/dehydration_93.xyz
# Dehydration hit: MR_164140_2 → dehydration_extxyz/dehydration_94.xyz
# Dehydration hit: MR_164198_1 → dehydration_extxyz/dehydration_95.xyz
# Dehydration hit: MR_164770_1 → dehydration_extxyz/dehydration_96.xyz
# Dehydration hit: MR_165649_1 → dehydration_extxyz/dehydration_97.xyz
# Dehydration hit: MR_168290_2 → dehydration_extxyz/dehydration_98.xyz
# Dehydration hit: MR_16894_0 → dehydration_extxyz/dehydration_99.xyz
# Dehydration hit: MR_175401_0 → dehydration_extxyz/dehydration_100.xyz
# Dehydration hit: MR_175465_0 → dehydration_extxyz/dehydration_101.xyz
# Dehydration hit: MR_175465_1 → dehydration_extxyz/dehydration_102.xyz
# Dehydration hit: MR_178370_2 → dehydration_extxyz/dehydration_103.xyz
# Dehydration hit: MR_178713_1 → dehydration_extxyz/dehydration_104.xyz
# Dehydration hit: MR_178713_2 → dehydration_extxyz/dehydration_105.xyz
# Dehydration hit: MR_17951_0 → dehydration_extxyz/dehydration_106.xyz
# Dehydration hit: MR_17955_1 → dehydration_extxyz/dehydration_107.xyz
# Dehydration hit: MR_180123_2 → dehydration_extxyz/dehydration_108.xyz
# Dehydration hit: MR_181769_2 → dehydration_extxyz/dehydration_109.xyz
# Dehydration hit: MR_182596_1 → dehydration_extxyz/dehydration_110.xyz
# Dehydration hit: MR_18333_1 → dehydration_extxyz/dehydration_111.xyz
# Dehydration hit: MR_183400_0 → dehydration_extxyz/dehydration_112.xyz
# Dehydration hit: MR_183400_1 → dehydration_extxyz/dehydration_113.xyz
# Dehydration hit: MR_184570_0 → dehydration_extxyz/dehydration_114.xyz
# Dehydration hit: MR_185400_1 → dehydration_extxyz/dehydration_115.xyz
# Dehydration hit: MR_186700_0 → dehydration_extxyz/dehydration_116.xyz
# Dehydration hit: MR_186700_1 → dehydration_extxyz/dehydration_117.xyz
# Dehydration hit: MR_186700_2 → dehydration_extxyz/dehydration_118.xyz
# Dehydration hit: MR_187233_0 → dehydration_extxyz/dehydration_119.xyz
# Dehydration hit: MR_19124_1 → dehydration_extxyz/dehydration_120.xyz
# Dehydration hit: MR_191278_1 → dehydration_extxyz/dehydration_121.xyz
# Dehydration hit: MR_191714_0 → dehydration_extxyz/dehydration_122.xyz
# Dehydration hit: MR_19205_2 → dehydration_extxyz/dehydration_123.xyz
# Dehydration hit: MR_193128_2 → dehydration_extxyz/dehydration_124.xyz
# Dehydration hit: MR_194165_0 → dehydration_extxyz/dehydration_125.xyz
# Dehydration hit: MR_194598_0 → dehydration_extxyz/dehydration_126.xyz
# Dehydration hit: MR_194598_1 → dehydration_extxyz/dehydration_127.xyz
# Dehydration hit: MR_194598_2 → dehydration_extxyz/dehydration_128.xyz
# Dehydration hit: MR_196708_0 → dehydration_extxyz/dehydration_129.xyz
# Dehydration hit: MR_196947_0 → dehydration_extxyz/dehydration_130.xyz
# Dehydration hit: MR_196947_2 → dehydration_extxyz/dehydration_131.xyz
# Dehydration hit: MR_197212_0 → dehydration_extxyz/dehydration_132.xyz
# Dehydration hit: MR_197212_1 → dehydration_extxyz/dehydration_133.xyz
# Dehydration hit: MR_197212_2 → dehydration_extxyz/dehydration_134.xyz
# Dehydration hit: MR_198040_1 → dehydration_extxyz/dehydration_135.xyz
# Dehydration hit: MR_198040_2 → dehydration_extxyz/dehydration_136.xyz
# Dehydration hit: MR_199571_1 → dehydration_extxyz/dehydration_137.xyz
# Dehydration hit: MR_199572_1 → dehydration_extxyz/dehydration_138.xyz
# Dehydration hit: MR_199573_0 → dehydration_extxyz/dehydration_139.xyz
# Dehydration hit: MR_199596_1 → dehydration_extxyz/dehydration_140.xyz
# Dehydration hit: MR_201226_1 → dehydration_extxyz/dehydration_141.xyz
# Dehydration hit: MR_20281_1 → dehydration_extxyz/dehydration_142.xyz
# Dehydration hit: MR_20287_2 → dehydration_extxyz/dehydration_143.xyz
# Dehydration hit: MR_204782_1 → dehydration_extxyz/dehydration_144.xyz
# Dehydration hit: MR_205528_2 → dehydration_extxyz/dehydration_145.xyz
# Dehydration hit: MR_208773_0 → dehydration_extxyz/dehydration_146.xyz
# Dehydration hit: MR_208800_1 → dehydration_extxyz/dehydration_147.xyz
# Dehydration hit: MR_208801_1 → dehydration_extxyz/dehydration_148.xyz
# Dehydration hit: MR_210795_1 → dehydration_extxyz/dehydration_149.xyz
# Dehydration hit: MR_210795_2 → dehydration_extxyz/dehydration_150.xyz
# Dehydration hit: MR_210796_0 → dehydration_extxyz/dehydration_151.xyz
# Dehydration hit: MR_210796_1 → dehydration_extxyz/dehydration_152.xyz
# Dehydration hit: MR_210796_2 → dehydration_extxyz/dehydration_153.xyz
# Dehydration hit: MR_214224_1 → dehydration_extxyz/dehydration_154.xyz
# Dehydration hit: MR_21509_0 → dehydration_extxyz/dehydration_155.xyz
# Dehydration hit: MR_21515_0 → dehydration_extxyz/dehydration_156.xyz
# Dehydration hit: MR_216628_1 → dehydration_extxyz/dehydration_157.xyz
# Dehydration hit: MR_216981_0 → dehydration_extxyz/dehydration_158.xyz
# Dehydration hit: MR_219070_0 → dehydration_extxyz/dehydration_159.xyz
# Dehydration hit: MR_219912_2 → dehydration_extxyz/dehydration_160.xyz
# Dehydration hit: MR_220985_0 → dehydration_extxyz/dehydration_161.xyz
# Dehydration hit: MR_222370_0 → dehydration_extxyz/dehydration_162.xyz
# Dehydration hit: MR_222370_2 → dehydration_extxyz/dehydration_163.xyz
# Dehydration hit: MR_222625_1 → dehydration_extxyz/dehydration_164.xyz
# Dehydration hit: MR_223348_2 → dehydration_extxyz/dehydration_165.xyz
# Dehydration hit: MR_225056_0 → dehydration_extxyz/dehydration_166.xyz
# Dehydration hit: MR_228343_1 → dehydration_extxyz/dehydration_167.xyz
# Dehydration hit: MR_228730_0 → dehydration_extxyz/dehydration_168.xyz
# Dehydration hit: MR_230181_0 → dehydration_extxyz/dehydration_169.xyz
# Dehydration hit: MR_230215_0 → dehydration_extxyz/dehydration_170.xyz
# Dehydration hit: MR_230215_2 → dehydration_extxyz/dehydration_171.xyz
# Dehydration hit: MR_230634_0 → dehydration_extxyz/dehydration_172.xyz
# Dehydration hit: MR_230634_1 → dehydration_extxyz/dehydration_173.xyz
# Dehydration hit: MR_232364_2 → dehydration_extxyz/dehydration_174.xyz
# Dehydration hit: MR_232955_0 → dehydration_extxyz/dehydration_175.xyz
# Dehydration hit: MR_233435_1 → dehydration_extxyz/dehydration_176.xyz
# Dehydration hit: MR_235941_0 → dehydration_extxyz/dehydration_177.xyz
# Dehydration hit: MR_24026_0 → dehydration_extxyz/dehydration_178.xyz
# Dehydration hit: MR_242142_0 → dehydration_extxyz/dehydration_179.xyz
# Dehydration hit: MR_243251_0 → dehydration_extxyz/dehydration_180.xyz
# Dehydration hit: MR_246142_0 → dehydration_extxyz/dehydration_181.xyz
# Dehydration hit: MR_246142_1 → dehydration_extxyz/dehydration_182.xyz
# Dehydration hit: MR_246142_2 → dehydration_extxyz/dehydration_183.xyz
# Dehydration hit: MR_246394_0 → dehydration_extxyz/dehydration_184.xyz
# Dehydration hit: MR_248650_0 → dehydration_extxyz/dehydration_185.xyz
# Dehydration hit: MR_248650_1 → dehydration_extxyz/dehydration_186.xyz
# Dehydration hit: MR_249687_1 → dehydration_extxyz/dehydration_187.xyz
# Dehydration hit: MR_249697_2 → dehydration_extxyz/dehydration_188.xyz
# Dehydration hit: MR_252103_0 → dehydration_extxyz/dehydration_189.xyz
# Dehydration hit: MR_25353_2 → dehydration_extxyz/dehydration_190.xyz
# Dehydration hit: MR_254042_0 → dehydration_extxyz/dehydration_191.xyz
# Dehydration hit: MR_254828_0 → dehydration_extxyz/dehydration_192.xyz
# Dehydration hit: MR_26297_0 → dehydration_extxyz/dehydration_193.xyz
# Dehydration hit: MR_267540_2 → dehydration_extxyz/dehydration_194.xyz
# Dehydration hit: MR_268283_2 → dehydration_extxyz/dehydration_195.xyz
# Dehydration hit: MR_269509_1 → dehydration_extxyz/dehydration_196.xyz
# Dehydration hit: MR_269968_2 → dehydration_extxyz/dehydration_197.xyz
# Dehydration hit: MR_272752_1 → dehydration_extxyz/dehydration_198.xyz
# Dehydration hit: MR_275734_2 → dehydration_extxyz/dehydration_199.xyz
# Dehydration hit: MR_276699_0 → dehydration_extxyz/dehydration_200.xyz
# Dehydration hit: MR_276699_1 → dehydration_extxyz/dehydration_201.xyz
# Dehydration hit: MR_276700_0 → dehydration_extxyz/dehydration_202.xyz
# Dehydration hit: MR_278991_0 → dehydration_extxyz/dehydration_203.xyz
# Dehydration hit: MR_279288_1 → dehydration_extxyz/dehydration_204.xyz
# Dehydration hit: MR_279288_2 → dehydration_extxyz/dehydration_205.xyz
# Dehydration hit: MR_280647_0 → dehydration_extxyz/dehydration_206.xyz
# Dehydration hit: MR_280900_1 → dehydration_extxyz/dehydration_207.xyz
# Dehydration hit: MR_28189_0 → dehydration_extxyz/dehydration_208.xyz
# Dehydration hit: MR_282633_1 → dehydration_extxyz/dehydration_209.xyz
# Dehydration hit: MR_282633_2 → dehydration_extxyz/dehydration_210.xyz
# Dehydration hit: MR_28568_0 → dehydration_extxyz/dehydration_211.xyz
# Dehydration hit: MR_28568_1 → dehydration_extxyz/dehydration_212.xyz
# Dehydration hit: MR_28568_2 → dehydration_extxyz/dehydration_213.xyz
# Dehydration hit: MR_28574_1 → dehydration_extxyz/dehydration_214.xyz
# Dehydration hit: MR_290289_0 → dehydration_extxyz/dehydration_215.xyz
# Dehydration hit: MR_29187_2 → dehydration_extxyz/dehydration_216.xyz
# Dehydration hit: MR_29198_0 → dehydration_extxyz/dehydration_217.xyz
# Dehydration hit: MR_29198_1 → dehydration_extxyz/dehydration_218.xyz
# Dehydration hit: MR_292941_0 → dehydration_extxyz/dehydration_219.xyz
# Dehydration hit: MR_295486_0 → dehydration_extxyz/dehydration_220.xyz
# Dehydration hit: MR_295695_1 → dehydration_extxyz/dehydration_221.xyz
# Dehydration hit: MR_295695_2 → dehydration_extxyz/dehydration_222.xyz
# Dehydration hit: MR_296303_2 → dehydration_extxyz/dehydration_223.xyz
# Dehydration hit: MR_297725_0 → dehydration_extxyz/dehydration_224.xyz
# Dehydration hit: MR_297725_1 → dehydration_extxyz/dehydration_225.xyz
# Dehydration hit: MR_297804_1 → dehydration_extxyz/dehydration_226.xyz
# Dehydration hit: MR_29817_1 → dehydration_extxyz/dehydration_227.xyz
# Dehydration hit: MR_298306_0 → dehydration_extxyz/dehydration_228.xyz
# Dehydration hit: MR_298306_2 → dehydration_extxyz/dehydration_229.xyz
# Dehydration hit: MR_29955_0 → dehydration_extxyz/dehydration_230.xyz
# Dehydration hit: MR_29955_1 → dehydration_extxyz/dehydration_231.xyz
# Dehydration hit: MR_29955_2 → dehydration_extxyz/dehydration_232.xyz
# Dehydration hit: MR_29968_0 → dehydration_extxyz/dehydration_233.xyz
# Dehydration hit: MR_299806_1 → dehydration_extxyz/dehydration_234.xyz
# Dehydration hit: MR_29983_1 → dehydration_extxyz/dehydration_235.xyz
# Dehydration hit: MR_301146_1 → dehydration_extxyz/dehydration_236.xyz
# Dehydration hit: MR_301878_2 → dehydration_extxyz/dehydration_237.xyz
# Dehydration hit: MR_301879_1 → dehydration_extxyz/dehydration_238.xyz
# Dehydration hit: MR_301882_1 → dehydration_extxyz/dehydration_239.xyz
# Dehydration hit: MR_303194_1 → dehydration_extxyz/dehydration_240.xyz
# Dehydration hit: MR_303194_2 → dehydration_extxyz/dehydration_241.xyz
# Dehydration hit: MR_304410_1 → dehydration_extxyz/dehydration_242.xyz
# Dehydration hit: MR_306760_1 → dehydration_extxyz/dehydration_243.xyz
# Dehydration hit: MR_30802_1 → dehydration_extxyz/dehydration_244.xyz
# Dehydration hit: MR_30812_2 → dehydration_extxyz/dehydration_245.xyz
# Dehydration hit: MR_313972_1 → dehydration_extxyz/dehydration_246.xyz
# Dehydration hit: MR_314198_1 → dehydration_extxyz/dehydration_247.xyz
# Dehydration hit: MR_314444_1 → dehydration_extxyz/dehydration_248.xyz
# Dehydration hit: MR_315628_2 → dehydration_extxyz/dehydration_249.xyz
# Dehydration hit: MR_315629_2 → dehydration_extxyz/dehydration_250.xyz
# Dehydration hit: MR_316574_0 → dehydration_extxyz/dehydration_251.xyz
# Dehydration hit: MR_317467_1 → dehydration_extxyz/dehydration_252.xyz
# Dehydration hit: MR_317928_0 → dehydration_extxyz/dehydration_253.xyz
# Dehydration hit: MR_319141_0 → dehydration_extxyz/dehydration_254.xyz
# Dehydration hit: MR_319273_2 → dehydration_extxyz/dehydration_255.xyz
# Dehydration hit: MR_3197_1 → dehydration_extxyz/dehydration_256.xyz
# Dehydration hit: MR_321605_1 → dehydration_extxyz/dehydration_257.xyz
# Dehydration hit: MR_322048_0 → dehydration_extxyz/dehydration_258.xyz
# Dehydration hit: MR_322628_1 → dehydration_extxyz/dehydration_259.xyz
# Dehydration hit: MR_323188_1 → dehydration_extxyz/dehydration_260.xyz
# Dehydration hit: MR_323306_1 → dehydration_extxyz/dehydration_261.xyz
# Dehydration hit: MR_323568_0 → dehydration_extxyz/dehydration_262.xyz
# Dehydration hit: MR_323568_1 → dehydration_extxyz/dehydration_263.xyz
# Dehydration hit: MR_324041_0 → dehydration_extxyz/dehydration_264.xyz
# Dehydration hit: MR_324041_1 → dehydration_extxyz/dehydration_265.xyz
# Dehydration hit: MR_324041_2 → dehydration_extxyz/dehydration_266.xyz
# Dehydration hit: MR_324478_0 → dehydration_extxyz/dehydration_267.xyz
# Dehydration hit: MR_32531_0 → dehydration_extxyz/dehydration_268.xyz
# Dehydration hit: MR_329658_0 → dehydration_extxyz/dehydration_269.xyz
# Dehydration hit: MR_329962_1 → dehydration_extxyz/dehydration_270.xyz
# Dehydration hit: MR_329963_2 → dehydration_extxyz/dehydration_271.xyz
# Dehydration hit: MR_330427_0 → dehydration_extxyz/dehydration_272.xyz
# Dehydration hit: MR_333930_1 → dehydration_extxyz/dehydration_273.xyz
# Dehydration hit: MR_335189_1 → dehydration_extxyz/dehydration_274.xyz
# Dehydration hit: MR_336979_0 → dehydration_extxyz/dehydration_275.xyz
# Dehydration hit: MR_337185_0 → dehydration_extxyz/dehydration_276.xyz
# Dehydration hit: MR_337185_1 → dehydration_extxyz/dehydration_277.xyz
# Dehydration hit: MR_33807_0 → dehydration_extxyz/dehydration_278.xyz
# Dehydration hit: MR_33807_1 → dehydration_extxyz/dehydration_279.xyz
# Dehydration hit: MR_339678_0 → dehydration_extxyz/dehydration_280.xyz
# Dehydration hit: MR_342870_1 → dehydration_extxyz/dehydration_281.xyz
# Dehydration hit: MR_34351_0 → dehydration_extxyz/dehydration_282.xyz
# Dehydration hit: MR_34351_1 → dehydration_extxyz/dehydration_283.xyz
# Dehydration hit: MR_343809_0 → dehydration_extxyz/dehydration_284.xyz
# Dehydration hit: MR_345722_1 → dehydration_extxyz/dehydration_285.xyz
# Dehydration hit: MR_346890_0 → dehydration_extxyz/dehydration_286.xyz
# Dehydration hit: MR_346890_1 → dehydration_extxyz/dehydration_287.xyz
# Dehydration hit: MR_348759_2 → dehydration_extxyz/dehydration_288.xyz
# Dehydration hit: MR_34901_1 → dehydration_extxyz/dehydration_289.xyz
# Dehydration hit: MR_352795_2 → dehydration_extxyz/dehydration_290.xyz
# Dehydration hit: MR_35406_1 → dehydration_extxyz/dehydration_291.xyz
# Dehydration hit: MR_358638_0 → dehydration_extxyz/dehydration_292.xyz
# Dehydration hit: MR_36226_1 → dehydration_extxyz/dehydration_293.xyz
# Dehydration hit: MR_36441_0 → dehydration_extxyz/dehydration_294.xyz
# Dehydration hit: MR_365100_2 → dehydration_extxyz/dehydration_295.xyz
# Dehydration hit: MR_370321_1 → dehydration_extxyz/dehydration_296.xyz
# Dehydration hit: MR_371908_0 → dehydration_extxyz/dehydration_297.xyz
# Dehydration hit: MR_371909_0 → dehydration_extxyz/dehydration_298.xyz
# Dehydration hit: MR_377621_1 → dehydration_extxyz/dehydration_299.xyz
# Dehydration hit: MR_377621_2 → dehydration_extxyz/dehydration_300.xyz
# Dehydration hit: MR_377626_0 → dehydration_extxyz/dehydration_301.xyz
# Dehydration hit: MR_382977_1 → dehydration_extxyz/dehydration_302.xyz
# Dehydration hit: MR_384618_0 → dehydration_extxyz/dehydration_303.xyz
# Dehydration hit: MR_384618_1 → dehydration_extxyz/dehydration_304.xyz
# Dehydration hit: MR_384618_2 → dehydration_extxyz/dehydration_305.xyz
# Dehydration hit: MR_38638_0 → dehydration_extxyz/dehydration_306.xyz
# Dehydration hit: MR_38688_2 → dehydration_extxyz/dehydration_307.xyz
# Dehydration hit: MR_387708_1 → dehydration_extxyz/dehydration_308.xyz
# Dehydration hit: MR_387708_2 → dehydration_extxyz/dehydration_309.xyz
# Dehydration hit: MR_389504_2 → dehydration_extxyz/dehydration_310.xyz
# Dehydration hit: MR_390011_0 → dehydration_extxyz/dehydration_311.xyz
# Dehydration hit: MR_393731_0 → dehydration_extxyz/dehydration_312.xyz
# Dehydration hit: MR_39695_0 → dehydration_extxyz/dehydration_313.xyz
# Dehydration hit: MR_39695_1 → dehydration_extxyz/dehydration_314.xyz
# Dehydration hit: MR_39695_2 → dehydration_extxyz/dehydration_315.xyz
# Dehydration hit: MR_402754_2 → dehydration_extxyz/dehydration_316.xyz
# Dehydration hit: MR_404718_0 → dehydration_extxyz/dehydration_317.xyz
# Dehydration hit: MR_404718_1 → dehydration_extxyz/dehydration_318.xyz
# Dehydration hit: MR_404718_2 → dehydration_extxyz/dehydration_319.xyz
# Dehydration hit: MR_404949_2 → dehydration_extxyz/dehydration_320.xyz
# Dehydration hit: MR_409060_1 → dehydration_extxyz/dehydration_321.xyz
# Dehydration hit: MR_41056_0 → dehydration_extxyz/dehydration_322.xyz
# Dehydration hit: MR_415025_1 → dehydration_extxyz/dehydration_323.xyz
# Dehydration hit: MR_422358_2 → dehydration_extxyz/dehydration_324.xyz
# Dehydration hit: MR_425032_1 → dehydration_extxyz/dehydration_325.xyz
# Dehydration hit: MR_42515_1 → dehydration_extxyz/dehydration_326.xyz
# Dehydration hit: MR_42607_0 → dehydration_extxyz/dehydration_327.xyz
# Dehydration hit: MR_42609_1 → dehydration_extxyz/dehydration_328.xyz
# Dehydration hit: MR_426165_2 → dehydration_extxyz/dehydration_329.xyz
# Dehydration hit: MR_426937_1 → dehydration_extxyz/dehydration_330.xyz
# Dehydration hit: MR_428268_2 → dehydration_extxyz/dehydration_331.xyz
# Dehydration hit: MR_429461_0 → dehydration_extxyz/dehydration_332.xyz
# Dehydration hit: MR_432736_0 → dehydration_extxyz/dehydration_333.xyz
# Dehydration hit: MR_4346_1 → dehydration_extxyz/dehydration_334.xyz
# Dehydration hit: MR_437161_0 → dehydration_extxyz/dehydration_335.xyz
# Dehydration hit: MR_438162_1 → dehydration_extxyz/dehydration_336.xyz
# Dehydration hit: MR_438163_1 → dehydration_extxyz/dehydration_337.xyz
# Dehydration hit: MR_441730_0 → dehydration_extxyz/dehydration_338.xyz
# Dehydration hit: MR_442547_1 → dehydration_extxyz/dehydration_339.xyz
# Dehydration hit: MR_44364_0 → dehydration_extxyz/dehydration_340.xyz
# Dehydration hit: MR_44364_2 → dehydration_extxyz/dehydration_341.xyz
# Dehydration hit: MR_44397_2 → dehydration_extxyz/dehydration_342.xyz
# Dehydration hit: MR_444962_0 → dehydration_extxyz/dehydration_343.xyz
# Dehydration hit: MR_44571_0 → dehydration_extxyz/dehydration_344.xyz
# Dehydration hit: MR_44571_1 → dehydration_extxyz/dehydration_345.xyz
# Dehydration hit: MR_446223_1 → dehydration_extxyz/dehydration_346.xyz
# Dehydration hit: MR_44965_0 → dehydration_extxyz/dehydration_347.xyz
# Dehydration hit: MR_449884_0 → dehydration_extxyz/dehydration_348.xyz
# Dehydration hit: MR_450796_2 → dehydration_extxyz/dehydration_349.xyz
# Dehydration hit: MR_450904_1 → dehydration_extxyz/dehydration_350.xyz
# Dehydration hit: MR_451667_1 → dehydration_extxyz/dehydration_351.xyz
# Dehydration hit: MR_451667_2 → dehydration_extxyz/dehydration_352.xyz
# Dehydration hit: MR_452157_0 → dehydration_extxyz/dehydration_353.xyz
# Dehydration hit: MR_453283_1 → dehydration_extxyz/dehydration_354.xyz
# Dehydration hit: MR_456151_1 → dehydration_extxyz/dehydration_355.xyz
# Dehydration hit: MR_456155_1 → dehydration_extxyz/dehydration_356.xyz
# Dehydration hit: MR_460014_0 → dehydration_extxyz/dehydration_357.xyz
# Dehydration hit: MR_460780_1 → dehydration_extxyz/dehydration_358.xyz
# Dehydration hit: MR_460787_1 → dehydration_extxyz/dehydration_359.xyz
# Dehydration hit: MR_461756_0 → dehydration_extxyz/dehydration_360.xyz
# Dehydration hit: MR_461911_1 → dehydration_extxyz/dehydration_361.xyz
# Dehydration hit: MR_462374_2 → dehydration_extxyz/dehydration_362.xyz
# Dehydration hit: MR_46382_1 → dehydration_extxyz/dehydration_363.xyz
# Dehydration hit: MR_464168_1 → dehydration_extxyz/dehydration_364.xyz
# Dehydration hit: MR_464945_2 → dehydration_extxyz/dehydration_365.xyz
# Dehydration hit: MR_466897_0 → dehydration_extxyz/dehydration_366.xyz
# Dehydration hit: MR_466897_1 → dehydration_extxyz/dehydration_367.xyz
# Dehydration hit: MR_467623_0 → dehydration_extxyz/dehydration_368.xyz
# Dehydration hit: MR_467623_1 → dehydration_extxyz/dehydration_369.xyz
# Dehydration hit: MR_469656_0 → dehydration_extxyz/dehydration_370.xyz
# Dehydration hit: MR_469828_0 → dehydration_extxyz/dehydration_371.xyz
# Dehydration hit: MR_473045_0 → dehydration_extxyz/dehydration_372.xyz
# Dehydration hit: MR_476963_2 → dehydration_extxyz/dehydration_373.xyz
# Dehydration hit: MR_477246_0 → dehydration_extxyz/dehydration_374.xyz
# Dehydration hit: MR_479342_0 → dehydration_extxyz/dehydration_375.xyz
# Dehydration hit: MR_48043_1 → dehydration_extxyz/dehydration_376.xyz
# Dehydration hit: MR_484862_2 → dehydration_extxyz/dehydration_377.xyz
# Dehydration hit: MR_48557_0 → dehydration_extxyz/dehydration_378.xyz
# Dehydration hit: MR_485714_1 → dehydration_extxyz/dehydration_379.xyz
# Dehydration hit: MR_486287_1 → dehydration_extxyz/dehydration_380.xyz
# Dehydration hit: MR_489786_0 → dehydration_extxyz/dehydration_381.xyz
# Dehydration hit: MR_493188_2 → dehydration_extxyz/dehydration_382.xyz
# Dehydration hit: MR_49473_1 → dehydration_extxyz/dehydration_383.xyz
# Dehydration hit: MR_49831_0 → dehydration_extxyz/dehydration_384.xyz
# Dehydration hit: MR_49831_1 → dehydration_extxyz/dehydration_385.xyz
# Dehydration hit: MR_49859_1 → dehydration_extxyz/dehydration_386.xyz
# Dehydration hit: MR_499359_1 → dehydration_extxyz/dehydration_387.xyz
# Dehydration hit: MR_500886_1 → dehydration_extxyz/dehydration_388.xyz
# Dehydration hit: MR_501531_0 → dehydration_extxyz/dehydration_389.xyz
# Dehydration hit: MR_50169_0 → dehydration_extxyz/dehydration_390.xyz
# Dehydration hit: MR_50169_2 → dehydration_extxyz/dehydration_391.xyz
# Dehydration hit: MR_50175_1 → dehydration_extxyz/dehydration_392.xyz
# Dehydration hit: MR_502603_0 → dehydration_extxyz/dehydration_393.xyz
# Dehydration hit: MR_502604_1 → dehydration_extxyz/dehydration_394.xyz
# Dehydration hit: MR_508065_1 → dehydration_extxyz/dehydration_395.xyz
# Dehydration hit: MR_509330_1 → dehydration_extxyz/dehydration_396.xyz
# Dehydration hit: MR_510139_0 → dehydration_extxyz/dehydration_397.xyz
# Dehydration hit: MR_510139_1 → dehydration_extxyz/dehydration_398.xyz
# Dehydration hit: MR_511306_1 → dehydration_extxyz/dehydration_399.xyz
# Dehydration hit: MR_511315_2 → dehydration_extxyz/dehydration_400.xyz
# Dehydration hit: MR_51629_0 → dehydration_extxyz/dehydration_401.xyz
# Dehydration hit: MR_518029_1 → dehydration_extxyz/dehydration_402.xyz
# Dehydration hit: MR_51939_2 → dehydration_extxyz/dehydration_403.xyz
# Dehydration hit: MR_520125_0 → dehydration_extxyz/dehydration_404.xyz
# Dehydration hit: MR_520125_2 → dehydration_extxyz/dehydration_405.xyz
# Dehydration hit: MR_521134_1 → dehydration_extxyz/dehydration_406.xyz
# Dehydration hit: MR_521202_0 → dehydration_extxyz/dehydration_407.xyz
# Dehydration hit: MR_522114_2 → dehydration_extxyz/dehydration_408.xyz
# Dehydration hit: MR_524355_0 → dehydration_extxyz/dehydration_409.xyz
# Dehydration hit: MR_525777_1 → dehydration_extxyz/dehydration_410.xyz
# Dehydration hit: MR_525777_2 → dehydration_extxyz/dehydration_411.xyz
# Dehydration hit: MR_525778_0 → dehydration_extxyz/dehydration_412.xyz
# Dehydration hit: MR_526852_0 → dehydration_extxyz/dehydration_413.xyz
# Dehydration hit: MR_527794_1 → dehydration_extxyz/dehydration_414.xyz
# Dehydration hit: MR_528204_1 → dehydration_extxyz/dehydration_415.xyz
# Dehydration hit: MR_531763_0 → dehydration_extxyz/dehydration_416.xyz
# Dehydration hit: MR_531810_0 → dehydration_extxyz/dehydration_417.xyz
# Dehydration hit: MR_531810_1 → dehydration_extxyz/dehydration_418.xyz
# Dehydration hit: MR_532057_0 → dehydration_extxyz/dehydration_419.xyz
# Dehydration hit: MR_532847_0 → dehydration_extxyz/dehydration_420.xyz
# Dehydration hit: MR_533669_2 → dehydration_extxyz/dehydration_421.xyz
# Dehydration hit: MR_538251_1 → dehydration_extxyz/dehydration_422.xyz
# Dehydration hit: MR_53839_1 → dehydration_extxyz/dehydration_423.xyz
# Dehydration hit: MR_53847_0 → dehydration_extxyz/dehydration_424.xyz
# Dehydration hit: MR_539767_1 → dehydration_extxyz/dehydration_425.xyz
# Dehydration hit: MR_540657_1 → dehydration_extxyz/dehydration_426.xyz
# Dehydration hit: MR_540959_0 → dehydration_extxyz/dehydration_427.xyz
# Dehydration hit: MR_540959_1 → dehydration_extxyz/dehydration_428.xyz
# Dehydration hit: MR_546262_1 → dehydration_extxyz/dehydration_429.xyz
# Dehydration hit: MR_546262_2 → dehydration_extxyz/dehydration_430.xyz
# Dehydration hit: MR_548233_2 → dehydration_extxyz/dehydration_431.xyz
# Dehydration hit: MR_549102_1 → dehydration_extxyz/dehydration_432.xyz
# Dehydration hit: MR_553867_1 → dehydration_extxyz/dehydration_433.xyz
# Dehydration hit: MR_555101_2 → dehydration_extxyz/dehydration_434.xyz
# Dehydration hit: MR_55877_0 → dehydration_extxyz/dehydration_435.xyz
# Dehydration hit: MR_559678_0 → dehydration_extxyz/dehydration_436.xyz
# Dehydration hit: MR_566128_0 → dehydration_extxyz/dehydration_437.xyz
# Dehydration hit: MR_566128_2 → dehydration_extxyz/dehydration_438.xyz
# Dehydration hit: MR_568284_1 → dehydration_extxyz/dehydration_439.xyz
# Dehydration hit: MR_571224_1 → dehydration_extxyz/dehydration_440.xyz
# Dehydration hit: MR_57354_0 → dehydration_extxyz/dehydration_441.xyz
# Dehydration hit: MR_57377_0 → dehydration_extxyz/dehydration_442.xyz
# Dehydration hit: MR_579785_2 → dehydration_extxyz/dehydration_443.xyz
# Dehydration hit: MR_580060_0 → dehydration_extxyz/dehydration_444.xyz
# Dehydration hit: MR_58278_2 → dehydration_extxyz/dehydration_445.xyz
# Dehydration hit: MR_58656_1 → dehydration_extxyz/dehydration_446.xyz
# Dehydration hit: MR_586768_0 → dehydration_extxyz/dehydration_447.xyz
# Dehydration hit: MR_586768_1 → dehydration_extxyz/dehydration_448.xyz
# Dehydration hit: MR_587966_2 → dehydration_extxyz/dehydration_449.xyz
# Dehydration hit: MR_589003_0 → dehydration_extxyz/dehydration_450.xyz
# Dehydration hit: MR_589656_2 → dehydration_extxyz/dehydration_451.xyz
# Dehydration hit: MR_59578_0 → dehydration_extxyz/dehydration_452.xyz
# Dehydration hit: MR_59627_1 → dehydration_extxyz/dehydration_453.xyz
# Dehydration hit: MR_59627_2 → dehydration_extxyz/dehydration_454.xyz
# Dehydration hit: MR_601236_1 → dehydration_extxyz/dehydration_455.xyz
# Dehydration hit: MR_604171_1 → dehydration_extxyz/dehydration_456.xyz
# Dehydration hit: MR_60474_0 → dehydration_extxyz/dehydration_457.xyz
# Dehydration hit: MR_605556_0 → dehydration_extxyz/dehydration_458.xyz
# Dehydration hit: MR_606298_2 → dehydration_extxyz/dehydration_459.xyz
# Dehydration hit: MR_608580_1 → dehydration_extxyz/dehydration_460.xyz
# Dehydration hit: MR_60908_0 → dehydration_extxyz/dehydration_461.xyz
# Dehydration hit: MR_60916_1 → dehydration_extxyz/dehydration_462.xyz
# Dehydration hit: MR_61028_0 → dehydration_extxyz/dehydration_463.xyz
# Dehydration hit: MR_612278_1 → dehydration_extxyz/dehydration_464.xyz
# Dehydration hit: MR_616367_2 → dehydration_extxyz/dehydration_465.xyz
# Dehydration hit: MR_617304_2 → dehydration_extxyz/dehydration_466.xyz
# Dehydration hit: MR_617522_1 → dehydration_extxyz/dehydration_467.xyz
# Dehydration hit: MR_618207_1 → dehydration_extxyz/dehydration_468.xyz
# Dehydration hit: MR_62038_2 → dehydration_extxyz/dehydration_469.xyz
# Dehydration hit: MR_62080_1 → dehydration_extxyz/dehydration_470.xyz
# Dehydration hit: MR_621069_1 → dehydration_extxyz/dehydration_471.xyz
# Dehydration hit: MR_624739_0 → dehydration_extxyz/dehydration_472.xyz
# Dehydration hit: MR_625249_1 → dehydration_extxyz/dehydration_473.xyz
# Dehydration hit: MR_628348_1 → dehydration_extxyz/dehydration_474.xyz
# Dehydration hit: MR_63233_0 → dehydration_extxyz/dehydration_475.xyz
# Dehydration hit: MR_63236_0 → dehydration_extxyz/dehydration_476.xyz
# Dehydration hit: MR_63248_0 → dehydration_extxyz/dehydration_477.xyz
# Dehydration hit: MR_633663_0 → dehydration_extxyz/dehydration_478.xyz
# Dehydration hit: MR_633663_2 → dehydration_extxyz/dehydration_479.xyz
# Dehydration hit: MR_635491_2 → dehydration_extxyz/dehydration_480.xyz
# Dehydration hit: MR_63661_1 → dehydration_extxyz/dehydration_481.xyz
# Dehydration hit: MR_637088_0 → dehydration_extxyz/dehydration_482.xyz
# Dehydration hit: MR_640605_0 → dehydration_extxyz/dehydration_483.xyz
# Dehydration hit: MR_640605_1 → dehydration_extxyz/dehydration_484.xyz
# Dehydration hit: MR_643600_2 → dehydration_extxyz/dehydration_485.xyz
# Dehydration hit: MR_64619_0 → dehydration_extxyz/dehydration_486.xyz
# Dehydration hit: MR_64619_1 → dehydration_extxyz/dehydration_487.xyz
# Dehydration hit: MR_64626_0 → dehydration_extxyz/dehydration_488.xyz
# Dehydration hit: MR_64626_2 → dehydration_extxyz/dehydration_489.xyz
# Dehydration hit: MR_646672_0 → dehydration_extxyz/dehydration_490.xyz
# Dehydration hit: MR_647693_1 → dehydration_extxyz/dehydration_491.xyz
# Dehydration hit: MR_648694_0 → dehydration_extxyz/dehydration_492.xyz
# Dehydration hit: MR_650642_1 → dehydration_extxyz/dehydration_493.xyz
# Dehydration hit: MR_651289_1 → dehydration_extxyz/dehydration_494.xyz
# Dehydration hit: MR_653265_0 → dehydration_extxyz/dehydration_495.xyz
# Dehydration hit: MR_653265_2 → dehydration_extxyz/dehydration_496.xyz
# Dehydration hit: MR_655503_0 → dehydration_extxyz/dehydration_497.xyz
# Dehydration hit: MR_656222_2 → dehydration_extxyz/dehydration_498.xyz
# Dehydration hit: MR_659641_2 → dehydration_extxyz/dehydration_499.xyz
# Dehydration hit: MR_661197_2 → dehydration_extxyz/dehydration_500.xyz
# Dehydration hit: MR_662153_1 → dehydration_extxyz/dehydration_501.xyz
# Dehydration hit: MR_665024_0 → dehydration_extxyz/dehydration_502.xyz
# Dehydration hit: MR_66667_0 → dehydration_extxyz/dehydration_503.xyz
# Dehydration hit: MR_667741_2 → dehydration_extxyz/dehydration_504.xyz
# Dehydration hit: MR_671169_0 → dehydration_extxyz/dehydration_505.xyz
# Dehydration hit: MR_671334_1 → dehydration_extxyz/dehydration_506.xyz
# Dehydration hit: MR_671715_0 → dehydration_extxyz/dehydration_507.xyz
# Dehydration hit: MR_671715_1 → dehydration_extxyz/dehydration_508.xyz
# Dehydration hit: MR_671716_2 → dehydration_extxyz/dehydration_509.xyz
# Dehydration hit: MR_673997_0 → dehydration_extxyz/dehydration_510.xyz
# Dehydration hit: MR_679015_1 → dehydration_extxyz/dehydration_511.xyz
# Dehydration hit: MR_679563_1 → dehydration_extxyz/dehydration_512.xyz
# Dehydration hit: MR_683482_2 → dehydration_extxyz/dehydration_513.xyz
# Dehydration hit: MR_68376_0 → dehydration_extxyz/dehydration_514.xyz
# Dehydration hit: MR_68376_1 → dehydration_extxyz/dehydration_515.xyz
# Dehydration hit: MR_684284_0 → dehydration_extxyz/dehydration_516.xyz
# Dehydration hit: MR_684284_1 → dehydration_extxyz/dehydration_517.xyz
# Dehydration hit: MR_684284_2 → dehydration_extxyz/dehydration_518.xyz
# Dehydration hit: MR_687108_0 → dehydration_extxyz/dehydration_519.xyz
# Dehydration hit: MR_690107_0 → dehydration_extxyz/dehydration_520.xyz
# Dehydration hit: MR_690107_1 → dehydration_extxyz/dehydration_521.xyz
# Dehydration hit: MR_691354_0 → dehydration_extxyz/dehydration_522.xyz
# Dehydration hit: MR_69244_1 → dehydration_extxyz/dehydration_523.xyz
# Dehydration hit: MR_698344_0 → dehydration_extxyz/dehydration_524.xyz
# Dehydration hit: MR_70354_0 → dehydration_extxyz/dehydration_525.xyz
# Dehydration hit: MR_70354_1 → dehydration_extxyz/dehydration_526.xyz
# Dehydration hit: MR_703973_0 → dehydration_extxyz/dehydration_527.xyz
# Dehydration hit: MR_703973_1 → dehydration_extxyz/dehydration_528.xyz
# Dehydration hit: MR_703973_2 → dehydration_extxyz/dehydration_529.xyz
# Dehydration hit: MR_707376_1 → dehydration_extxyz/dehydration_530.xyz
# Dehydration hit: MR_74507_2 → dehydration_extxyz/dehydration_531.xyz
# Dehydration hit: MR_75660_0 → dehydration_extxyz/dehydration_532.xyz
# Dehydration hit: MR_76056_2 → dehydration_extxyz/dehydration_533.xyz
# Dehydration hit: MR_78282_1 → dehydration_extxyz/dehydration_534.xyz
# Dehydration hit: MR_78929_1 → dehydration_extxyz/dehydration_535.xyz
# Dehydration hit: MR_7962_1 → dehydration_extxyz/dehydration_536.xyz
# Dehydration hit: MR_7965_2 → dehydration_extxyz/dehydration_537.xyz
# Dehydration hit: MR_7967_1 → dehydration_extxyz/dehydration_538.xyz
# Dehydration hit: MR_7972_0 → dehydration_extxyz/dehydration_539.xyz
# Dehydration hit: MR_80050_0 → dehydration_extxyz/dehydration_540.xyz
# Dehydration hit: MR_80050_1 → dehydration_extxyz/dehydration_541.xyz
# Dehydration hit: MR_80050_2 → dehydration_extxyz/dehydration_542.xyz
# Dehydration hit: MR_80607_2 → dehydration_extxyz/dehydration_543.xyz
# Dehydration hit: MR_81185_1 → dehydration_extxyz/dehydration_544.xyz
# Dehydration hit: MR_81189_0 → dehydration_extxyz/dehydration_545.xyz
# Dehydration hit: MR_84935_1 → dehydration_extxyz/dehydration_546.xyz
# Dehydration hit: MR_85284_0 → dehydration_extxyz/dehydration_547.xyz
# Dehydration hit: MR_87202_0 → dehydration_extxyz/dehydration_548.xyz
# Dehydration hit: MR_87202_2 → dehydration_extxyz/dehydration_549.xyz
# Dehydration hit: MR_87480_0 → dehydration_extxyz/dehydration_550.xyz
# Dehydration hit: MR_87480_1 → dehydration_extxyz/dehydration_551.xyz
# Dehydration hit: MR_87486_1 → dehydration_extxyz/dehydration_552.xyz
# Dehydration hit: MR_87486_2 → dehydration_extxyz/dehydration_553.xyz
# Dehydration hit: MR_87490_0 → dehydration_extxyz/dehydration_554.xyz
# Dehydration hit: MR_88176_0 → dehydration_extxyz/dehydration_555.xyz
# Dehydration hit: MR_90122_1 → dehydration_extxyz/dehydration_556.xyz
# Dehydration hit: MR_90234_1 → dehydration_extxyz/dehydration_557.xyz
# Dehydration hit: MR_90446_1 → dehydration_extxyz/dehydration_558.xyz
# Dehydration hit: MR_90539_0 → dehydration_extxyz/dehydration_559.xyz
# Dehydration hit: MR_94203_0 → dehydration_extxyz/dehydration_560.xyz
# Dehydration hit: MR_94597_2 → dehydration_extxyz/dehydration_561.xyz
# Dehydration hit: MR_95222_1 → dehydration_extxyz/dehydration_562.xyz
# Dehydration hit: MR_95242_2 → dehydration_extxyz/dehydration_563.xyz
# Dehydration hit: MR_95426_0 → dehydration_extxyz/dehydration_564.xyz
# Dehydration hit: MR_95796_1 → dehydration_extxyz/dehydration_565.xyz
# Dehydration hit: MR_99149_0 → dehydration_extxyz/dehydration_566.xyz
# Dehydration hit: MR_99614_2 → dehydration_extxyz/dehydration_567.xyz
# Total alcohol dehydrations: 568

# %%
import os
from rdkit import Chem
from ase import Atoms
from ase.io import write

# SMARTS for Tishchenko reaction: two aldehydes -> ester
aldehyde_pat       = Chem.MolFromSmarts('[CX3H1](=O)[#6]')
ester_pat          = Chem.MolFromSmarts('[#6]C(=O)O[#6]')

# SMARTS for Benzilic acid rearrangement: α-diketone -> α-hydroxy acid
adjacent_diketone_pat = Chem.MolFromSmarts('[#6](=O)[#6](=O)')
alpha_hydroxy_acid_pat = Chem.MolFromSmarts('[#6][CX4]([OX2H])[#6]')  # tertiary alcohol fragment
carboxylic_acid_pat    = Chem.MolFromSmarts('[CX3](=O)[OX2H]')        # COOH

def to_atoms(geom):
    return Atoms(numbers=geom['atomic_numbers'], positions=geom['positions'])

def save_extxyz(rxn, idx, rxn_type, out_dir):
    os.makedirs(out_dir, exist_ok=True)
    fname = os.path.join(out_dir, f"r{idx}.xyz")
    if os.path.exists(fname):
        os.remove(fname)
    for state in ('reactant', 'transition_state', 'product'):
        geom = rxn[state]
        atoms = to_atoms(geom)
        atoms.info['rxn_id'] = rxn['rxn_id']
        atoms.info['state']  = state
        write(fname, atoms, append=True, format='extxyz')

def find_tishchenko(h5path, out_dir="tishchenko_extxyz"):
    loader = RGD1Loader(h5path)
    idx = 0
    for rxn in loader:
        r_sm = rxn['reactant']['smiles']
        p_sm = rxn['product']['smiles']
        # reactant must be two aldehyde fragments
        if '.' not in r_sm:
            continue
        frags_r = r_sm.split('.')
        if len(frags_r) != 2:
            continue
        mols_r = [Chem.MolFromSmiles(f) for f in frags_r]
        if any(m is None for m in mols_r):
            continue
        if all(m.HasSubstructMatch(aldehyde_pat) for m in mols_r):
            p_mol = Chem.MolFromSmiles(p_sm)
            if p_mol and p_mol.HasSubstructMatch(ester_pat):
                save_extxyz(rxn, idx, "tishchenko", out_dir)
                print(f"Tishchenko hit: {rxn['rxn_id']} → {out_dir}/tishchenko_{idx}.xyz")
                idx += 1
    print(f"Total Tishchenko hits: {idx}")

def find_benzilic(h5path, out_dir="benzilic_extxyz"):
    loader = RGD1Loader(h5path)
    idx = 0
    for rxn in loader:
        r_sm = rxn['reactant']['smiles']
        p_sm = rxn['product']['smiles']
        r_mol = Chem.MolFromSmiles(r_sm)
        p_mol = Chem.MolFromSmiles(p_sm)
        if not r_mol or not p_mol:
            continue
        if r_mol.HasSubstructMatch(adjacent_diketone_pat):
            # product must have a tertiary alcohol and a carboxylic acid
            if (p_mol.HasSubstructMatch(alpha_hydroxy_acid_pat) 
                and p_mol.HasSubstructMatch(carboxylic_acid_pat)):
                save_extxyz(rxn, idx, "benzilic", out_dir)
                print(f"Benzilic hit: {rxn['rxn_id']} → {out_dir}/benzilic_{idx}.xyz")
                idx += 1
    print(f"Total Benzilic hits: {idx}")

# Example usage:
find_tishchenko("RGD1_CHNO.h5")
find_benzilic("RGD1_CHNO.h5")
# Out:
# Tishchenko hit: MR_42891_0 → tishchenko_extxyz/tishchenko_0.xyz
# Tishchenko hit: MR_42891_2 → tishchenko_extxyz/tishchenko_1.xyz
# Tishchenko hit: MR_668097_1 → tishchenko_extxyz/tishchenko_2.xyz
# Tishchenko hit: MR_6911_1 → tishchenko_extxyz/tishchenko_3.xyz
# Total Tishchenko hits: 4
# Benzilic hit: MR_139006_0 → benzilic_extxyz/benzilic_0.xyz
# Benzilic hit: MR_168150_1 → benzilic_extxyz/benzilic_1.xyz
# Benzilic hit: MR_171388_1 → benzilic_extxyz/benzilic_2.xyz
# Benzilic hit: MR_186696_1 → benzilic_extxyz/benzilic_3.xyz
# Benzilic hit: MR_191768_1 → benzilic_extxyz/benzilic_4.xyz
# Benzilic hit: MR_234263_0 → benzilic_extxyz/benzilic_5.xyz
# Benzilic hit: MR_234263_1 → benzilic_extxyz/benzilic_6.xyz
# Benzilic hit: MR_234263_2 → benzilic_extxyz/benzilic_7.xyz
# Benzilic hit: MR_243066_1 → benzilic_extxyz/benzilic_8.xyz
# Benzilic hit: MR_254784_1 → benzilic_extxyz/benzilic_9.xyz
# Benzilic hit: MR_257555_0 → benzilic_extxyz/benzilic_10.xyz
# Benzilic hit: MR_277143_0 → benzilic_extxyz/benzilic_11.xyz
# Benzilic hit: MR_277143_2 → benzilic_extxyz/benzilic_12.xyz
# Benzilic hit: MR_299318_1 → benzilic_extxyz/benzilic_13.xyz
# Benzilic hit: MR_327409_0 → benzilic_extxyz/benzilic_14.xyz
# Benzilic hit: MR_327409_2 → benzilic_extxyz/benzilic_15.xyz
# Benzilic hit: MR_334026_0 → benzilic_extxyz/benzilic_16.xyz
# Benzilic hit: MR_337038_1 → benzilic_extxyz/benzilic_17.xyz
# Benzilic hit: MR_343491_0 → benzilic_extxyz/benzilic_18.xyz
# Benzilic hit: MR_383328_2 → benzilic_extxyz/benzilic_19.xyz
# Benzilic hit: MR_420566_1 → benzilic_extxyz/benzilic_20.xyz
# Benzilic hit: MR_430759_1 → benzilic_extxyz/benzilic_21.xyz
# Benzilic hit: MR_435723_1 → benzilic_extxyz/benzilic_22.xyz
# Benzilic hit: MR_486691_0 → benzilic_extxyz/benzilic_23.xyz
# Benzilic hit: MR_506755_0 → benzilic_extxyz/benzilic_24.xyz
# Benzilic hit: MR_512601_0 → benzilic_extxyz/benzilic_25.xyz
# Benzilic hit: MR_526540_0 → benzilic_extxyz/benzilic_26.xyz
# Benzilic hit: MR_527924_1 → benzilic_extxyz/benzilic_27.xyz
# Benzilic hit: MR_540663_0 → benzilic_extxyz/benzilic_28.xyz
# Benzilic hit: MR_540663_2 → benzilic_extxyz/benzilic_29.xyz
# Benzilic hit: MR_547233_0 → benzilic_extxyz/benzilic_30.xyz
# Benzilic hit: MR_579842_1 → benzilic_extxyz/benzilic_31.xyz
# Benzilic hit: MR_579842_2 → benzilic_extxyz/benzilic_32.xyz
# Benzilic hit: MR_600633_1 → benzilic_extxyz/benzilic_33.xyz
# Benzilic hit: MR_62427_0 → benzilic_extxyz/benzilic_34.xyz
# Benzilic hit: MR_640334_2 → benzilic_extxyz/benzilic_35.xyz
# Benzilic hit: MR_643685_1 → benzilic_extxyz/benzilic_36.xyz
# Benzilic hit: MR_650767_1 → benzilic_extxyz/benzilic_37.xyz
# Benzilic hit: MR_652738_0 → benzilic_extxyz/benzilic_38.xyz
# Benzilic hit: MR_652739_0 → benzilic_extxyz/benzilic_39.xyz
# Benzilic hit: MR_700932_0 → benzilic_extxyz/benzilic_40.xyz
# Total Benzilic hits: 41

# %%
import os
from rdkit import Chem
from ase import Atoms
from ase.io import write

# SMARTS for Henry (nitroaldol) reaction
nitro_pat           = Chem.MolFromSmarts('[CX3;!$(C=*)][CH2][NX3+](=O)[O-]')  # nitroalkane fragment
aldehyde_pat        = Chem.MolFromSmarts('[CX3H1](=O)[#6]')                     # R-CHO
nitroalcohol_pat    = Chem.MolFromSmarts('[CX4]([OX2H])[NX3+](=O)[O-]')         # nitroalcohol product

# SMARTS for Knoevenagel condensation
diketone_pat        = Chem.MolFromSmarts('[#6]C(=O)CC(=O)[#6]')                 # 1,3-diketone
enone_prod_pat      = Chem.MolFromSmarts('[CX3H1]=[CX2]C(=O)[#6]')              # α,β-unsaturated carbonyl

def to_atoms(geom):
    return Atoms(numbers=geom['atomic_numbers'], positions=geom['positions'])

def save_extxyz(rxn, idx, rxn_type, out_dir):
    os.makedirs(out_dir, exist_ok=True)
    fname = os.path.join(out_dir, f"r{idx}.xyz")
    if os.path.exists(fname):
        os.remove(fname)
    for state in ('reactant', 'transition_state', 'product'):
        geom = rxn[state]
        atoms = to_atoms(geom)
        atoms.info['rxn_id'] = rxn['rxn_id']
        atoms.info['state']  = state
        write(fname, atoms, append=True, format='extxyz')

def find_henry(h5path, out_dir="henry_extxyz"):
    """
    Finds Henry (nitroaldol) reactions: nitroalkane + aldehyde -> nitroalcohol
    """
    loader = RGD1Loader(h5path)
    idx = 0
    for rxn in loader:
        r_sm = rxn['reactant']['smiles']
        p_sm = rxn['product']['smiles']
        # two-fragment reactant
        if '.' not in r_sm:
            continue
        frags = r_sm.split('.')
        if len(frags) != 2:
            continue
        mols_r = [Chem.MolFromSmiles(f) for f in frags]
        if any(m is None for m in mols_r):
            continue
        # one fragment must be nitroalkane, the other aldehyde
        if (mols_r[0].HasSubstructMatch(nitro_pat) and mols_r[1].HasSubstructMatch(aldehyde_pat)) \
        or (mols_r[1].HasSubstructMatch(nitro_pat) and mols_r[0].HasSubstructMatch(aldehyde_pat)):
            p_mol = Chem.MolFromSmiles(p_sm)
            if p_mol and p_mol.HasSubstructMatch(nitroalcohol_pat):
                save_extxyz(rxn, idx, "henry", out_dir)
                print(f"Henry hit: {rxn['rxn_id']} → {out_dir}/henry_{idx}.xyz")
                idx += 1
    print(f"Total Henry hits: {idx}")

def find_knoevenagel(h5path, out_dir="knoevenagel_extxyz"):
    """
    Finds Knoevenagel condensations: 1,3-diketone + aldehyde -> α,β-unsaturated carbonyl
    """
    loader = RGD1Loader(h5path)
    idx = 0
    for rxn in loader:
        r_sm = rxn['reactant']['smiles']
        p_sm = rxn['product']['smiles']
        # two-fragment reactant
        if '.' not in r_sm:
            continue
        frags = r_sm.split('.')
        if len(frags) != 2:
            continue
        mols_r = [Chem.MolFromSmiles(f) for f in frags]
        if any(m is None for m in mols_r):
            continue
        # one fragment is 1,3-diketone, other is aldehyde
        if (mols_r[0].HasSubstructMatch(diketone_pat) and mols_r[1].HasSubstructMatch(aldehyde_pat)) \
        or (mols_r[1].HasSubstructMatch(diketone_pat) and mols_r[0].HasSubstructMatch(aldehyde_pat)):
            p_mol = Chem.MolFromSmiles(p_sm)
            if p_mol and p_mol.HasSubstructMatch(enone_prod_pat):
                save_extxyz(rxn, idx, "knoevenagel", out_dir)
                print(f"Knoevenagel hit: {rxn['rxn_id']} → {out_dir}/knoevenagel_{idx}.xyz")
                idx += 1
    print(f"Total Knoevenagel hits: {idx}")

# Example usage:
find_henry("RGD1_CHNO.h5")
find_knoevenagel("RGD1_CHNO.h5")
# Out:
# Total Henry hits: 0
# Total Knoevenagel hits: 0

# %%
import os
from rdkit import Chem
from ase import Atoms
from ase.io import write

# SMARTS patterns
aldehyde_pat           = Chem.MolFromSmarts('[CX3H1](=O)[#6]')
benzoin_prod_pat      = Chem.MolFromSmarts('[#6]C(=O)C([OX2H])[#6]')

acid_pat              = Chem.MolFromSmarts('[CX3](=O)[OX2H]')
alcohol_pat           = Chem.MolFromSmarts('[CX4H2][OX2H]')
ester_pat             = Chem.MolFromSmarts('[#6]C(=O)O[#6]')

ketone_pat            = Chem.MolFromSmarts('[#6]C(=O)[#6]')
# Propargylic alcohol: RC#C-CH2OH
propargylic_alc_pat   = Chem.MolFromSmarts('[CX2]#C[CH2][OX2H]')
enone_prod_pat        = Chem.MolFromSmarts('[CX3H1]=[CX2]C(=O)[#6]')

def to_atoms(geom):
    return Atoms(numbers=geom['atomic_numbers'], positions=geom['positions'])

def save_extxyz(rxn, idx, rxn_type, out_dir):
    os.makedirs(out_dir, exist_ok=True)
    fname = os.path.join(out_dir, f"r{idx}.xyz")
    if os.path.exists(fname):
        os.remove(fname)
    for state in ('reactant', 'transition_state', 'product'):
        geom = rxn[state]
        atoms = to_atoms(geom)
        atoms.info['rxn_id'] = rxn['rxn_id']
        atoms.info['state']  = state
        write(fname, atoms, append=True, format='extxyz')

def find_benzoin(h5path, out_dir="benzoin_extxyz"):
    loader = RGD1Loader(h5path)
    idx = 0
    for rxn in loader:
        r_sm = rxn['reactant']['smiles']
        p_sm = rxn['product']['smiles']
        # two aldehyde fragments
        if '.' not in r_sm:
            continue
        frags = r_sm.split('.')
        mols = [Chem.MolFromSmiles(f) for f in frags]
        if any(m is None for m in mols):
            continue
        if all(m.HasSubstructMatch(aldehyde_pat) for m in mols):
            p_mol = Chem.MolFromSmiles(p_sm)
            if p_mol and p_mol.HasSubstructMatch(benzoin_prod_pat):
                save_extxyz(rxn, idx, "benzoin", out_dir)
                print(f"Benzoin hit: {rxn['rxn_id']} → {out_dir}/benzoin_{idx}.xyz")
                idx += 1
    print(f"Total Benzoin hits: {idx}")

def find_fischer_esterification(h5path, out_dir="fischer_extxyz"):
    loader = RGD1Loader(h5path)
    idx = 0
    for rxn in loader:
        r_sm = rxn['reactant']['smiles']
        p_sm = rxn['product']['smiles']
        # acid + alcohol
        if '.' not in r_sm:
            continue
        frags = r_sm.split('.')
        mols = [Chem.MolFromSmiles(f) for f in frags]
        if any(m is None for m in mols):
            continue
        if (mols[0].HasSubstructMatch(acid_pat) and mols[1].HasSubstructMatch(alcohol_pat)) \
        or (mols[1].HasSubstructMatch(acid_pat) and mols[0].HasSubstructMatch(alcohol_pat)):
            p_mol = Chem.MolFromSmiles(p_sm)
            if p_mol and p_mol.HasSubstructMatch(ester_pat):
                save_extxyz(rxn, idx, "fischer", out_dir)
                print(f"Fischer hit: {rxn['rxn_id']} → {out_dir}/fischer_{idx}.xyz")
                idx += 1
    print(f"Total Fischer esterification hits: {idx}")

def find_baeyer_villiger(h5path, out_dir="bv_extxyz"):
    loader = RGD1Loader(h5path)
    idx = 0
    for rxn in loader:
        r_sm = rxn['reactant']['smiles']
        p_sm = rxn['product']['smiles']
        # ketone → ester
        if '.' in r_sm or '.' in p_sm:
            continue
        r_mol = Chem.MolFromSmiles(r_sm)
        p_mol = Chem.MolFromSmiles(p_sm)
        if not r_mol or not p_mol:
            continue
        if r_mol.HasSubstructMatch(ketone_pat) and p_mol.HasSubstructMatch(ester_pat):
            save_extxyz(rxn, idx, "baeyer_villiger", out_dir)
            print(f"Baeyer–Villiger hit: {rxn['rxn_id']} → {out_dir}/baeyer_villiger_{idx}.xyz")
            idx += 1
    print(f"Total Baeyer–Villiger hits: {idx}")

def find_meyer_schuster(h5path, out_dir="ms_extxyz"):
    loader = RGD1Loader(h5path)
    idx = 0
    for rxn in loader:
        r_sm = rxn['reactant']['smiles']
        p_sm = rxn['product']['smiles']
        r_mol = Chem.MolFromSmiles(r_sm)
        p_mol = Chem.MolFromSmiles(p_sm)
        if not r_mol or not p_mol:
            continue
        if r_mol.HasSubstructMatch(propargylic_alc_pat) and p_mol.HasSubstructMatch(enone_prod_pat):
            save_extxyz(rxn, idx, "meyer_schuster", out_dir)
            print(f"Meyer–Schuster hit: {rxn['rxn_id']} → {out_dir}/meyer_schuster_{idx}.xyz")
            idx += 1
    print(f"Total Meyer–Schuster hits: {idx}")

def find_lactonization(h5path, out_dir="lactonization_extxyz"):
    loader = RGD1Loader(h5path)
    idx = 0
    for rxn in loader:
        r_sm = rxn['reactant']['smiles']
        p_sm = rxn['product']['smiles']
        if '.' in r_sm:
            continue
        r_mol = Chem.MolFromSmiles(r_sm)
        p_mol = Chem.MolFromSmiles(p_sm)
        if not r_mol or not p_mol:
            continue
        # intramolecular: has both acid and alcohol
        if r_mol.HasSubstructMatch(acid_pat) and r_mol.HasSubstructMatch(alcohol_pat):
            # product is cyclic ester
            if p_mol.GetRingInfo().NumRings() > 0 and p_mol.HasSubstructMatch(ester_pat):
                save_extxyz(rxn, idx, "lactonization", out_dir)
                print(f"Lactonization hit: {rxn['rxn_id']} → {out_dir}/lactonization_{idx}.xyz")
                idx += 1
    print(f"Total Lactonization hits: {idx}")

if __name__ == "__main__":
    H5 = "RGD1_CHNO.h5"
    find_benzoin(H5)
    find_fischer_esterification(H5)
    find_baeyer_villiger(H5)
    find_meyer_schuster(H5)
    find_lactonization(H5)
# Out:
# Benzoin hit: MR_395380_1 → benzoin_extxyz/benzoin_0.xyz
# Total Benzoin hits: 1
# Fischer hit: MR_109234_0 → fischer_extxyz/fischer_0.xyz
# Fischer hit: MR_273957_2 → fischer_extxyz/fischer_1.xyz
# Fischer hit: MR_81011_2 → fischer_extxyz/fischer_2.xyz
# Total Fischer esterification hits: 3
# Baeyer–Villiger hit: MR_103184_1 → bv_extxyz/baeyer_villiger_0.xyz
# Baeyer–Villiger hit: MR_105624_0 → bv_extxyz/baeyer_villiger_1.xyz
# Baeyer–Villiger hit: MR_106600_1 → bv_extxyz/baeyer_villiger_2.xyz
# Baeyer–Villiger hit: MR_107105_2 → bv_extxyz/baeyer_villiger_3.xyz
# Baeyer–Villiger hit: MR_119137_0 → bv_extxyz/baeyer_villiger_4.xyz
# Baeyer–Villiger hit: MR_123903_0 → bv_extxyz/baeyer_villiger_5.xyz
# Baeyer–Villiger hit: MR_12423_0 → bv_extxyz/baeyer_villiger_6.xyz
# Baeyer–Villiger hit: MR_124483_1 → bv_extxyz/baeyer_villiger_7.xyz
# Baeyer–Villiger hit: MR_126778_0 → bv_extxyz/baeyer_villiger_8.xyz
# Baeyer–Villiger hit: MR_126785_0 → bv_extxyz/baeyer_villiger_9.xyz
# Baeyer–Villiger hit: MR_126997_0 → bv_extxyz/baeyer_villiger_10.xyz
# Baeyer–Villiger hit: MR_126997_1 → bv_extxyz/baeyer_villiger_11.xyz
# Baeyer–Villiger hit: MR_127995_2 → bv_extxyz/baeyer_villiger_12.xyz
# Baeyer–Villiger hit: MR_128055_0 → bv_extxyz/baeyer_villiger_13.xyz
# Baeyer–Villiger hit: MR_12832_2 → bv_extxyz/baeyer_villiger_14.xyz
# Baeyer–Villiger hit: MR_134314_0 → bv_extxyz/baeyer_villiger_15.xyz
# Baeyer–Villiger hit: MR_135473_0 → bv_extxyz/baeyer_villiger_16.xyz
# Baeyer–Villiger hit: MR_136093_0 → bv_extxyz/baeyer_villiger_17.xyz
# Baeyer–Villiger hit: MR_136304_0 → bv_extxyz/baeyer_villiger_18.xyz
# Baeyer–Villiger hit: MR_137049_1 → bv_extxyz/baeyer_villiger_19.xyz
# Baeyer–Villiger hit: MR_137049_2 → bv_extxyz/baeyer_villiger_20.xyz
# Baeyer–Villiger hit: MR_144758_0 → bv_extxyz/baeyer_villiger_21.xyz
# Baeyer–Villiger hit: MR_147833_1 → bv_extxyz/baeyer_villiger_22.xyz
# Baeyer–Villiger hit: MR_150986_2 → bv_extxyz/baeyer_villiger_23.xyz
# Baeyer–Villiger hit: MR_153718_0 → bv_extxyz/baeyer_villiger_24.xyz
# Baeyer–Villiger hit: MR_156189_0 → bv_extxyz/baeyer_villiger_25.xyz
# Baeyer–Villiger hit: MR_15727_1 → bv_extxyz/baeyer_villiger_26.xyz
# Baeyer–Villiger hit: MR_163428_1 → bv_extxyz/baeyer_villiger_27.xyz
# Baeyer–Villiger hit: MR_172822_0 → bv_extxyz/baeyer_villiger_28.xyz
# Baeyer–Villiger hit: MR_172823_1 → bv_extxyz/baeyer_villiger_29.xyz
# Baeyer–Villiger hit: MR_18207_0 → bv_extxyz/baeyer_villiger_30.xyz
# Baeyer–Villiger hit: MR_18207_2 → bv_extxyz/baeyer_villiger_31.xyz
# Baeyer–Villiger hit: MR_183882_1 → bv_extxyz/baeyer_villiger_32.xyz
# Baeyer–Villiger hit: MR_185832_2 → bv_extxyz/baeyer_villiger_33.xyz
# Baeyer–Villiger hit: MR_186524_0 → bv_extxyz/baeyer_villiger_34.xyz
# Baeyer–Villiger hit: MR_187007_2 → bv_extxyz/baeyer_villiger_35.xyz
# Baeyer–Villiger hit: MR_19149_0 → bv_extxyz/baeyer_villiger_36.xyz
# Baeyer–Villiger hit: MR_193956_0 → bv_extxyz/baeyer_villiger_37.xyz
# Baeyer–Villiger hit: MR_193956_1 → bv_extxyz/baeyer_villiger_38.xyz
# Baeyer–Villiger hit: MR_195862_2 → bv_extxyz/baeyer_villiger_39.xyz
# Baeyer–Villiger hit: MR_196498_1 → bv_extxyz/baeyer_villiger_40.xyz
# Baeyer–Villiger hit: MR_201438_0 → bv_extxyz/baeyer_villiger_41.xyz
# Baeyer–Villiger hit: MR_202920_0 → bv_extxyz/baeyer_villiger_42.xyz
# Baeyer–Villiger hit: MR_206963_1 → bv_extxyz/baeyer_villiger_43.xyz
# Baeyer–Villiger hit: MR_207481_0 → bv_extxyz/baeyer_villiger_44.xyz
# Baeyer–Villiger hit: MR_209488_0 → bv_extxyz/baeyer_villiger_45.xyz
# Baeyer–Villiger hit: MR_212045_0 → bv_extxyz/baeyer_villiger_46.xyz
# Baeyer–Villiger hit: MR_215661_1 → bv_extxyz/baeyer_villiger_47.xyz
# Baeyer–Villiger hit: MR_219599_0 → bv_extxyz/baeyer_villiger_48.xyz
# Baeyer–Villiger hit: MR_220186_0 → bv_extxyz/baeyer_villiger_49.xyz
# Baeyer–Villiger hit: MR_220186_1 → bv_extxyz/baeyer_villiger_50.xyz
# Baeyer–Villiger hit: MR_220962_0 → bv_extxyz/baeyer_villiger_51.xyz
# Baeyer–Villiger hit: MR_230816_0 → bv_extxyz/baeyer_villiger_52.xyz
# Baeyer–Villiger hit: MR_230816_1 → bv_extxyz/baeyer_villiger_53.xyz
# Baeyer–Villiger hit: MR_234801_0 → bv_extxyz/baeyer_villiger_54.xyz
# Baeyer–Villiger hit: MR_236396_1 → bv_extxyz/baeyer_villiger_55.xyz
# Baeyer–Villiger hit: MR_236398_2 → bv_extxyz/baeyer_villiger_56.xyz
# Baeyer–Villiger hit: MR_24124_1 → bv_extxyz/baeyer_villiger_57.xyz
# Baeyer–Villiger hit: MR_244174_2 → bv_extxyz/baeyer_villiger_58.xyz
# Baeyer–Villiger hit: MR_245985_0 → bv_extxyz/baeyer_villiger_59.xyz
# Baeyer–Villiger hit: MR_248172_0 → bv_extxyz/baeyer_villiger_60.xyz
# Baeyer–Villiger hit: MR_250115_0 → bv_extxyz/baeyer_villiger_61.xyz
# Baeyer–Villiger hit: MR_250115_2 → bv_extxyz/baeyer_villiger_62.xyz
# Baeyer–Villiger hit: MR_253488_0 → bv_extxyz/baeyer_villiger_63.xyz
# Baeyer–Villiger hit: MR_255561_0 → bv_extxyz/baeyer_villiger_64.xyz
# Baeyer–Villiger hit: MR_255561_1 → bv_extxyz/baeyer_villiger_65.xyz
# Baeyer–Villiger hit: MR_256811_0 → bv_extxyz/baeyer_villiger_66.xyz
# Baeyer–Villiger hit: MR_258337_0 → bv_extxyz/baeyer_villiger_67.xyz
# Baeyer–Villiger hit: MR_260941_0 → bv_extxyz/baeyer_villiger_68.xyz
# Baeyer–Villiger hit: MR_261515_1 → bv_extxyz/baeyer_villiger_69.xyz
# Baeyer–Villiger hit: MR_263044_2 → bv_extxyz/baeyer_villiger_70.xyz
# Baeyer–Villiger hit: MR_268867_0 → bv_extxyz/baeyer_villiger_71.xyz
# Baeyer–Villiger hit: MR_268867_1 → bv_extxyz/baeyer_villiger_72.xyz
# Baeyer–Villiger hit: MR_268867_2 → bv_extxyz/baeyer_villiger_73.xyz
# Baeyer–Villiger hit: MR_269261_0 → bv_extxyz/baeyer_villiger_74.xyz
# Baeyer–Villiger hit: MR_271440_2 → bv_extxyz/baeyer_villiger_75.xyz
# Baeyer–Villiger hit: MR_273174_2 → bv_extxyz/baeyer_villiger_76.xyz
# Baeyer–Villiger hit: MR_274252_0 → bv_extxyz/baeyer_villiger_77.xyz
# Baeyer–Villiger hit: MR_28347_0 → bv_extxyz/baeyer_villiger_78.xyz
# Baeyer–Villiger hit: MR_293363_2 → bv_extxyz/baeyer_villiger_79.xyz
# Baeyer–Villiger hit: MR_299394_1 → bv_extxyz/baeyer_villiger_80.xyz
# Baeyer–Villiger hit: MR_300369_0 → bv_extxyz/baeyer_villiger_81.xyz
# Baeyer–Villiger hit: MR_301980_1 → bv_extxyz/baeyer_villiger_82.xyz
# Baeyer–Villiger hit: MR_306827_2 → bv_extxyz/baeyer_villiger_83.xyz
# Baeyer–Villiger hit: MR_307248_0 → bv_extxyz/baeyer_villiger_84.xyz
# Baeyer–Villiger hit: MR_308099_1 → bv_extxyz/baeyer_villiger_85.xyz
# Baeyer–Villiger hit: MR_308315_0 → bv_extxyz/baeyer_villiger_86.xyz
# Baeyer–Villiger hit: MR_311767_0 → bv_extxyz/baeyer_villiger_87.xyz
# Baeyer–Villiger hit: MR_314191_0 → bv_extxyz/baeyer_villiger_88.xyz
# Baeyer–Villiger hit: MR_316994_2 → bv_extxyz/baeyer_villiger_89.xyz
# Baeyer–Villiger hit: MR_323036_1 → bv_extxyz/baeyer_villiger_90.xyz
# Baeyer–Villiger hit: MR_324986_0 → bv_extxyz/baeyer_villiger_91.xyz
# Baeyer–Villiger hit: MR_324986_2 → bv_extxyz/baeyer_villiger_92.xyz
# Baeyer–Villiger hit: MR_335962_0 → bv_extxyz/baeyer_villiger_93.xyz
# Baeyer–Villiger hit: MR_339061_0 → bv_extxyz/baeyer_villiger_94.xyz
# Baeyer–Villiger hit: MR_339814_1 → bv_extxyz/baeyer_villiger_95.xyz
# Baeyer–Villiger hit: MR_340048_0 → bv_extxyz/baeyer_villiger_96.xyz
# Baeyer–Villiger hit: MR_346456_1 → bv_extxyz/baeyer_villiger_97.xyz
# Baeyer–Villiger hit: MR_351519_1 → bv_extxyz/baeyer_villiger_98.xyz
# Baeyer–Villiger hit: MR_366976_1 → bv_extxyz/baeyer_villiger_99.xyz
# Baeyer–Villiger hit: MR_367247_1 → bv_extxyz/baeyer_villiger_100.xyz
# Baeyer–Villiger hit: MR_37008_1 → bv_extxyz/baeyer_villiger_101.xyz
# Baeyer–Villiger hit: MR_376405_2 → bv_extxyz/baeyer_villiger_102.xyz
# Baeyer–Villiger hit: MR_381737_1 → bv_extxyz/baeyer_villiger_103.xyz
# Baeyer–Villiger hit: MR_385892_0 → bv_extxyz/baeyer_villiger_104.xyz
# Baeyer–Villiger hit: MR_386228_0 → bv_extxyz/baeyer_villiger_105.xyz
# Baeyer–Villiger hit: MR_389238_0 → bv_extxyz/baeyer_villiger_106.xyz
# Baeyer–Villiger hit: MR_389782_1 → bv_extxyz/baeyer_villiger_107.xyz
# Baeyer–Villiger hit: MR_390510_1 → bv_extxyz/baeyer_villiger_108.xyz
# Baeyer–Villiger hit: MR_394204_0 → bv_extxyz/baeyer_villiger_109.xyz
# Baeyer–Villiger hit: MR_39884_0 → bv_extxyz/baeyer_villiger_110.xyz
# Baeyer–Villiger hit: MR_403132_2 → bv_extxyz/baeyer_villiger_111.xyz
# Baeyer–Villiger hit: MR_41360_1 → bv_extxyz/baeyer_villiger_112.xyz
# Baeyer–Villiger hit: MR_414880_2 → bv_extxyz/baeyer_villiger_113.xyz
# Baeyer–Villiger hit: MR_41720_0 → bv_extxyz/baeyer_villiger_114.xyz
# Baeyer–Villiger hit: MR_422808_1 → bv_extxyz/baeyer_villiger_115.xyz
# Baeyer–Villiger hit: MR_42512_2 → bv_extxyz/baeyer_villiger_116.xyz
# Baeyer–Villiger hit: MR_428545_1 → bv_extxyz/baeyer_villiger_117.xyz
# Baeyer–Villiger hit: MR_434209_1 → bv_extxyz/baeyer_villiger_118.xyz
# Baeyer–Villiger hit: MR_44098_1 → bv_extxyz/baeyer_villiger_119.xyz
# Baeyer–Villiger hit: MR_442845_2 → bv_extxyz/baeyer_villiger_120.xyz
# Baeyer–Villiger hit: MR_448804_0 → bv_extxyz/baeyer_villiger_121.xyz
# Baeyer–Villiger hit: MR_44929_0 → bv_extxyz/baeyer_villiger_122.xyz
# Baeyer–Villiger hit: MR_45152_2 → bv_extxyz/baeyer_villiger_123.xyz
# Baeyer–Villiger hit: MR_452151_1 → bv_extxyz/baeyer_villiger_124.xyz
# Baeyer–Villiger hit: MR_456406_1 → bv_extxyz/baeyer_villiger_125.xyz
# Baeyer–Villiger hit: MR_459770_1 → bv_extxyz/baeyer_villiger_126.xyz
# Baeyer–Villiger hit: MR_460473_0 → bv_extxyz/baeyer_villiger_127.xyz
# Baeyer–Villiger hit: MR_461473_1 → bv_extxyz/baeyer_villiger_128.xyz
# Baeyer–Villiger hit: MR_469193_0 → bv_extxyz/baeyer_villiger_129.xyz
# Baeyer–Villiger hit: MR_470370_2 → bv_extxyz/baeyer_villiger_130.xyz
# Baeyer–Villiger hit: MR_471833_0 → bv_extxyz/baeyer_villiger_131.xyz
# Baeyer–Villiger hit: MR_47237_1 → bv_extxyz/baeyer_villiger_132.xyz
# Baeyer–Villiger hit: MR_47370_1 → bv_extxyz/baeyer_villiger_133.xyz
# Baeyer–Villiger hit: MR_47370_2 → bv_extxyz/baeyer_villiger_134.xyz
# Baeyer–Villiger hit: MR_475576_2 → bv_extxyz/baeyer_villiger_135.xyz
# Baeyer–Villiger hit: MR_478783_0 → bv_extxyz/baeyer_villiger_136.xyz
# Baeyer–Villiger hit: MR_484257_1 → bv_extxyz/baeyer_villiger_137.xyz
# Baeyer–Villiger hit: MR_489822_1 → bv_extxyz/baeyer_villiger_138.xyz
# Baeyer–Villiger hit: MR_490755_0 → bv_extxyz/baeyer_villiger_139.xyz
# Baeyer–Villiger hit: MR_492270_1 → bv_extxyz/baeyer_villiger_140.xyz
# Baeyer–Villiger hit: MR_492639_0 → bv_extxyz/baeyer_villiger_141.xyz
# Baeyer–Villiger hit: MR_49491_1 → bv_extxyz/baeyer_villiger_142.xyz
# Baeyer–Villiger hit: MR_49491_2 → bv_extxyz/baeyer_villiger_143.xyz
# Baeyer–Villiger hit: MR_495990_0 → bv_extxyz/baeyer_villiger_144.xyz
# Baeyer–Villiger hit: MR_49641_0 → bv_extxyz/baeyer_villiger_145.xyz
# Baeyer–Villiger hit: MR_49641_1 → bv_extxyz/baeyer_villiger_146.xyz
# Baeyer–Villiger hit: MR_497473_0 → bv_extxyz/baeyer_villiger_147.xyz
# Baeyer–Villiger hit: MR_498602_1 → bv_extxyz/baeyer_villiger_148.xyz
# Baeyer–Villiger hit: MR_50027_0 → bv_extxyz/baeyer_villiger_149.xyz
# Baeyer–Villiger hit: MR_50060_0 → bv_extxyz/baeyer_villiger_150.xyz
# Baeyer–Villiger hit: MR_500779_2 → bv_extxyz/baeyer_villiger_151.xyz
# Baeyer–Villiger hit: MR_500782_1 → bv_extxyz/baeyer_villiger_152.xyz
# Baeyer–Villiger hit: MR_502883_2 → bv_extxyz/baeyer_villiger_153.xyz
# Baeyer–Villiger hit: MR_50674_0 → bv_extxyz/baeyer_villiger_154.xyz
# Baeyer–Villiger hit: MR_50705_0 → bv_extxyz/baeyer_villiger_155.xyz
# Baeyer–Villiger hit: MR_508615_1 → bv_extxyz/baeyer_villiger_156.xyz
# Baeyer–Villiger hit: MR_512708_1 → bv_extxyz/baeyer_villiger_157.xyz
# Baeyer–Villiger hit: MR_515223_0 → bv_extxyz/baeyer_villiger_158.xyz
# Baeyer–Villiger hit: MR_515224_1 → bv_extxyz/baeyer_villiger_159.xyz
# Baeyer–Villiger hit: MR_516487_1 → bv_extxyz/baeyer_villiger_160.xyz
# Baeyer–Villiger hit: MR_517025_2 → bv_extxyz/baeyer_villiger_161.xyz
# Baeyer–Villiger hit: MR_520280_0 → bv_extxyz/baeyer_villiger_162.xyz
# Baeyer–Villiger hit: MR_523706_1 → bv_extxyz/baeyer_villiger_163.xyz
# Baeyer–Villiger hit: MR_527892_0 → bv_extxyz/baeyer_villiger_164.xyz
# Baeyer–Villiger hit: MR_528987_1 → bv_extxyz/baeyer_villiger_165.xyz
# Baeyer–Villiger hit: MR_53064_1 → bv_extxyz/baeyer_villiger_166.xyz
# Baeyer–Villiger hit: MR_53064_2 → bv_extxyz/baeyer_villiger_167.xyz
# Baeyer–Villiger hit: MR_541961_0 → bv_extxyz/baeyer_villiger_168.xyz
# Baeyer–Villiger hit: MR_541977_1 → bv_extxyz/baeyer_villiger_169.xyz
# Baeyer–Villiger hit: MR_545906_2 → bv_extxyz/baeyer_villiger_170.xyz
# Baeyer–Villiger hit: MR_547642_0 → bv_extxyz/baeyer_villiger_171.xyz
# Baeyer–Villiger hit: MR_551567_0 → bv_extxyz/baeyer_villiger_172.xyz
# Baeyer–Villiger hit: MR_552201_0 → bv_extxyz/baeyer_villiger_173.xyz
# Baeyer–Villiger hit: MR_556667_1 → bv_extxyz/baeyer_villiger_174.xyz
# Baeyer–Villiger hit: MR_571076_2 → bv_extxyz/baeyer_villiger_175.xyz
# Baeyer–Villiger hit: MR_57117_1 → bv_extxyz/baeyer_villiger_176.xyz
# Baeyer–Villiger hit: MR_576171_0 → bv_extxyz/baeyer_villiger_177.xyz
# Baeyer–Villiger hit: MR_60891_1 → bv_extxyz/baeyer_villiger_178.xyz
# Baeyer–Villiger hit: MR_611294_1 → bv_extxyz/baeyer_villiger_179.xyz
# Baeyer–Villiger hit: MR_61463_2 → bv_extxyz/baeyer_villiger_180.xyz
# Baeyer–Villiger hit: MR_616689_1 → bv_extxyz/baeyer_villiger_181.xyz
# Baeyer–Villiger hit: MR_620446_1 → bv_extxyz/baeyer_villiger_182.xyz
# Baeyer–Villiger hit: MR_620462_2 → bv_extxyz/baeyer_villiger_183.xyz
# Baeyer–Villiger hit: MR_630132_1 → bv_extxyz/baeyer_villiger_184.xyz
# Baeyer–Villiger hit: MR_636900_1 → bv_extxyz/baeyer_villiger_185.xyz
# Baeyer–Villiger hit: MR_64657_1 → bv_extxyz/baeyer_villiger_186.xyz
# Baeyer–Villiger hit: MR_646865_1 → bv_extxyz/baeyer_villiger_187.xyz
# Baeyer–Villiger hit: MR_648246_1 → bv_extxyz/baeyer_villiger_188.xyz
# Baeyer–Villiger hit: MR_650567_1 → bv_extxyz/baeyer_villiger_189.xyz
# Baeyer–Villiger hit: MR_67070_1 → bv_extxyz/baeyer_villiger_190.xyz
# Baeyer–Villiger hit: MR_672029_1 → bv_extxyz/baeyer_villiger_191.xyz
# Baeyer–Villiger hit: MR_679253_2 → bv_extxyz/baeyer_villiger_192.xyz
# Baeyer–Villiger hit: MR_682701_0 → bv_extxyz/baeyer_villiger_193.xyz
# Baeyer–Villiger hit: MR_686859_2 → bv_extxyz/baeyer_villiger_194.xyz
# Baeyer–Villiger hit: MR_688875_1 → bv_extxyz/baeyer_villiger_195.xyz
# Baeyer–Villiger hit: MR_691416_1 → bv_extxyz/baeyer_villiger_196.xyz
# Baeyer–Villiger hit: MR_691921_2 → bv_extxyz/baeyer_villiger_197.xyz
# Baeyer–Villiger hit: MR_694273_0 → bv_extxyz/baeyer_villiger_198.xyz
# Baeyer–Villiger hit: MR_697170_0 → bv_extxyz/baeyer_villiger_199.xyz
# Baeyer–Villiger hit: MR_7023_0 → bv_extxyz/baeyer_villiger_200.xyz
# Baeyer–Villiger hit: MR_703571_0 → bv_extxyz/baeyer_villiger_201.xyz
# Baeyer–Villiger hit: MR_70359_0 → bv_extxyz/baeyer_villiger_202.xyz
# Baeyer–Villiger hit: MR_7043_1 → bv_extxyz/baeyer_villiger_203.xyz
# Baeyer–Villiger hit: MR_72302_1 → bv_extxyz/baeyer_villiger_204.xyz
# Baeyer–Villiger hit: MR_76686_1 → bv_extxyz/baeyer_villiger_205.xyz
# Baeyer–Villiger hit: MR_77207_1 → bv_extxyz/baeyer_villiger_206.xyz
# Baeyer–Villiger hit: MR_81521_1 → bv_extxyz/baeyer_villiger_207.xyz
# Baeyer–Villiger hit: MR_81522_1 → bv_extxyz/baeyer_villiger_208.xyz
# Baeyer–Villiger hit: MR_86191_0 → bv_extxyz/baeyer_villiger_209.xyz
# Baeyer–Villiger hit: MR_9023_1 → bv_extxyz/baeyer_villiger_210.xyz
# Baeyer–Villiger hit: MR_92495_0 → bv_extxyz/baeyer_villiger_211.xyz
# Baeyer–Villiger hit: MR_93125_0 → bv_extxyz/baeyer_villiger_212.xyz
# Baeyer–Villiger hit: MR_97054_1 → bv_extxyz/baeyer_villiger_213.xyz
# Total Baeyer–Villiger hits: 214
# Total Meyer–Schuster hits: 0
# Total Lactonization hits: 0

# %%
import os
from rdkit import Chem
from ase import Atoms
from ase.io import write

# SMARTS for the Nef reaction: nitroalkane → carbonyl
nitro_pat     = Chem.MolFromSmarts('[#6][CH2][NX3+](=O)[O-]')
carbonyl_pat  = Chem.MolFromSmarts('[#6][CX3](=O)[#6]')

# SMARTS for the Mannich reaction: amine + aldehyde + ketone → β‑amino ketone
amine_pat         = Chem.MolFromSmarts('[NX3;H2]')          # primary amine
ald_pat           = Chem.MolFromSmarts('[CX3H1](=O)[#6]')    # aldehyde
enolizable_pat    = Chem.MolFromSmarts('[#6][CX3](=O)[CH2]') # ketone with CH2 α‑carbon
beta_amino_pat    = Chem.MolFromSmarts('C[NX3]C(=O)')        # β‑amino carbonyl

def to_atoms(geom):
    return Atoms(numbers=geom['atomic_numbers'], positions=geom['positions'])

def save_extxyz(rxn, idx, rxn_type, out_dir):
    os.makedirs(out_dir, exist_ok=True)
    fn = os.path.join(out_dir, f"r{idx}.xyz")
    if os.path.exists(fn):
        os.remove(fn)
    for state in ('reactant', 'transition_state', 'product'):
        atoms = to_atoms(rxn[state])
        atoms.info['rxn_id'] = rxn['rxn_id']
        atoms.info['state']  = state
        write(fn, atoms, append=True, format='extxyz')

def find_nef(h5path, out_dir="nef_extxyz"):
    """
    Nitroalkane  →  Carbonyl (Nef reaction)
    """
    loader = RGD1Loader(h5path)
    idx = 0
    for rxn in loader:
        r_sm = rxn['reactant']['smiles']
        p_sm = rxn['product']['smiles']
        r_mol = Chem.MolFromSmiles(r_sm)
        p_mol = Chem.MolFromSmiles(p_sm)
        if r_mol and p_mol:
            if r_mol.HasSubstructMatch(nitro_pat) and p_mol.HasSubstructMatch(carbonyl_pat):
                save_extxyz(rxn, idx, "nef", out_dir)
                print(f"Nef hit: {rxn['rxn_id']} → {out_dir}/nef_{idx}.xyz")
                idx += 1
    print(f"Total Nef hits: {idx}")

def find_mannich(h5path, out_dir="mannich_extxyz"):
    """
    Amine + Aldehyde + Ketone  →  β‑Amino ketone (Mannich reaction)
    """
    loader = RGD1Loader(h5path)
    idx = 0
    for rxn in loader:
        r_sm = rxn['reactant']['smiles']
        # need three fragments: amine, aldehyde, ketone
        if '.' not in r_sm:
            continue
        frags = r_sm.split('.')
        if len(frags) != 3:
            continue
        mols = [Chem.MolFromSmiles(f) for f in frags]
        if any(m is None for m in mols):
            continue
        # match one of each
        types = [m.HasSubstructMatch(amine_pat) for m in mols] + \
                [m.HasSubstructMatch(ald_pat) for m in mols] + \
                [m.HasSubstructMatch(enolizable_pat) for m in mols]
        # each SMARTS must be found exactly once
        if types.count(True) == 3:
            p_mol = Chem.MolFromSmiles(rxn['product']['smiles'])
            if p_mol and p_mol.HasSubstructMatch(beta_amino_pat):
                save_extxyz(rxn, idx, "mannich", out_dir)
                print(f"Mannich hit: {rxn['rxn_id']} → {out_dir}/mannich_{idx}.xyz")
                idx += 1
    print(f"Total Mannich hits: {idx}")

if __name__ == "__main__":
    H5 = "RGD1_CHNO.h5"
    find_nef(H5)
    find_mannich(H5)
# Out:
# Total Nef hits: 0
# Mannich hit: MR_316088_1 → mannich_extxyz/mannich_0.xyz
# Mannich hit: MR_350463_1 → mannich_extxyz/mannich_1.xyz
# Total Mannich hits: 2

# %%
import os
from rdkit import Chem
from rdkit.Chem.rdchem import BondType
from ase import Atoms
from ase.io import write

# SMARTS patterns
enone_pat     = Chem.MolFromSmarts('[CX3]=[CX3]')  # C=C

# SMARTS for [2+2] cycloaddition: two alkenes -> cyclobutane ring
alkene_pat    = Chem.MolFromSmarts('[CX3]=[CX3]')

# SMARTS for intramolecular cyclobutane formation: single fragment with two C=C

def to_atoms(geom):
    return Atoms(numbers=geom['atomic_numbers'], positions=geom['positions'])

def save_extxyz(rxn, idx, rxn_type, out_dir):
    os.makedirs(out_dir, exist_ok=True)
    fn = os.path.join(out_dir, f"r{idx}.xyz")
    if os.path.exists(fn):
        os.remove(fn)
    for state in ('reactant','transition_state','product'):
        geom = rxn[state]
        atoms = to_atoms(geom)
        atoms.info['rxn_id'] = rxn['rxn_id']
        atoms.info['state']  = state
        write(fn, atoms, append=True, format='extxyz')


def is_2plus2_cycloaddition(r_sm, p_sm):
    # two distinct alkene fragments
    if '.' not in r_sm:
        return False
    frags = r_sm.split('.')
    if len(frags) != 2:
        return False
    mols = [Chem.MolFromSmiles(f) for f in frags]
    if any(m is None for m in mols):
        return False
    if not all(m.HasSubstructMatch(alkene_pat) for m in mols):
        return False
    p_mol = Chem.MolFromSmiles(p_sm)
    if p_mol is None:
        return False
    # look for cyclobutane ring: single 4-membered ring
    for ring in p_mol.GetRingInfo().AtomRings():
        if len(ring) == 4:
            # ensure all ring bonds are single
            ok = True
            for i in range(4):
                a1 = ring[i]
                a2 = ring[(i+1)%4]
                b = p_mol.GetBondBetweenAtoms(a1, a2)
                if b.GetBondType() != BondType.SINGLE:
                    ok = False
                    break
            if ok:
                return True
    return False


def find_2plus2_cycloadditions(h5path, out_dir="2plus2_cycloadd_extxyz"):
    loader = RGD1Loader(h5path)
    idx = 0
    for rxn in loader:
        if is_2plus2_cycloaddition(rxn['reactant']['smiles'], rxn['product']['smiles']):
            save_extxyz(rxn, idx, '2plus2_cycloaddition', out_dir)
            print(f"[2+2] cycloaddition hit: {rxn['rxn_id']} -> {out_dir}/2plus2_cycloaddition_{idx}.xyz")
            idx += 1
    print(f"Total [2+2] cycloadditions: {idx}")


def find_cyclobutane_cyclizations(h5path, out_dir="cyclobutane_cyclization_extxyz"):
    loader = RGD1Loader(h5path)
    idx = 0
    for rxn in loader:
        r_sm = rxn['reactant']['smiles']
        p_sm = rxn['product']['smiles']
        # single fragment with two alkenes
        if '.' in r_sm:
            continue
        r_mol = Chem.MolFromSmiles(r_sm)
        p_mol = Chem.MolFromSmiles(p_sm)
        if r_mol is None or p_mol is None:
            continue
        # must have two distinct C=C in reactant
        if len(r_mol.GetSubstructMatches(alkene_pat)) < 2:
            continue
        # product must be cyclobutane as before
        for ring in p_mol.GetRingInfo().AtomRings():
            if len(ring) == 4:
                ok = True
                for i in range(4):
                    a1 = ring[i]
                    a2 = ring[(i+1)%4]
                    b = p_mol.GetBondBetweenAtoms(a1, a2)
                    if b.GetBondType() != BondType.SINGLE:
                        ok = False
                        break
                if ok:
                    save_extxyz(rxn, idx, 'cyclobutane_cyclization', out_dir)
                    print(f"Cyclobutane cyclization hit: {rxn['rxn_id']} -> {out_dir}/cyclobutane_cyclization_{idx}.xyz")
                    idx += 1
                    break
    print(f"Total cyclobutane cyclizations: {idx}")


if __name__ == '__main__':
    H5 = 'RGD1_CHNO.h5'
    find_2plus2_cycloadditions(H5)
    find_cyclobutane_cyclizations(H5)
# Out:
# [2+2] cycloaddition hit: MR_110337_0 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_0.xyz
# [2+2] cycloaddition hit: MR_142005_1 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_1.xyz
# [2+2] cycloaddition hit: MR_155026_2 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_2.xyz
# [2+2] cycloaddition hit: MR_156257_0 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_3.xyz
# [2+2] cycloaddition hit: MR_156257_1 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_4.xyz
# [2+2] cycloaddition hit: MR_17098_1 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_5.xyz
# [2+2] cycloaddition hit: MR_184185_1 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_6.xyz
# [2+2] cycloaddition hit: MR_203780_1 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_7.xyz
# [2+2] cycloaddition hit: MR_21490_2 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_8.xyz
# [2+2] cycloaddition hit: MR_216326_1 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_9.xyz
# [2+2] cycloaddition hit: MR_23675_0 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_10.xyz
# [2+2] cycloaddition hit: MR_250746_2 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_11.xyz
# [2+2] cycloaddition hit: MR_252051_0 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_12.xyz
# [2+2] cycloaddition hit: MR_293691_1 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_13.xyz
# [2+2] cycloaddition hit: MR_296726_1 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_14.xyz
# [2+2] cycloaddition hit: MR_342373_0 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_15.xyz
# [2+2] cycloaddition hit: MR_342373_2 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_16.xyz
# [2+2] cycloaddition hit: MR_352351_0 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_17.xyz
# [2+2] cycloaddition hit: MR_358454_0 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_18.xyz
# [2+2] cycloaddition hit: MR_439_2 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_19.xyz
# [2+2] cycloaddition hit: MR_447642_1 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_20.xyz
# [2+2] cycloaddition hit: MR_4775_1 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_21.xyz
# [2+2] cycloaddition hit: MR_480229_1 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_22.xyz
# [2+2] cycloaddition hit: MR_49591_2 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_23.xyz
# [2+2] cycloaddition hit: MR_502364_2 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_24.xyz
# [2+2] cycloaddition hit: MR_52130_2 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_25.xyz
# [2+2] cycloaddition hit: MR_535218_2 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_26.xyz
# [2+2] cycloaddition hit: MR_538598_1 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_27.xyz
# [2+2] cycloaddition hit: MR_546354_2 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_28.xyz
# [2+2] cycloaddition hit: MR_59923_1 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_29.xyz
# [2+2] cycloaddition hit: MR_648588_2 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_30.xyz
# [2+2] cycloaddition hit: MR_64_1 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_31.xyz
# [2+2] cycloaddition hit: MR_66481_1 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_32.xyz
# [2+2] cycloaddition hit: MR_669779_1 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_33.xyz
# [2+2] cycloaddition hit: MR_67114_0 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_34.xyz
# [2+2] cycloaddition hit: MR_67179_2 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_35.xyz
# [2+2] cycloaddition hit: MR_695141_1 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_36.xyz
# [2+2] cycloaddition hit: MR_705770_1 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_37.xyz
# [2+2] cycloaddition hit: MR_7586_1 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_38.xyz
# [2+2] cycloaddition hit: MR_92062_1 -> 2plus2_cycloadd_extxyz/2plus2_cycloaddition_39.xyz
# Total [2+2] cycloadditions: 40
# Cyclobutane cyclization hit: MR_106234_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_0.xyz
# Cyclobutane cyclization hit: MR_11082_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_1.xyz
# Cyclobutane cyclization hit: MR_110843_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_2.xyz
# Cyclobutane cyclization hit: MR_112740_2 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_3.xyz
# Cyclobutane cyclization hit: MR_112802_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_4.xyz
# Cyclobutane cyclization hit: MR_115683_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_5.xyz
# Cyclobutane cyclization hit: MR_11835_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_6.xyz
# Cyclobutane cyclization hit: MR_11835_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_7.xyz
# Cyclobutane cyclization hit: MR_118967_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_8.xyz
# Cyclobutane cyclization hit: MR_120450_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_9.xyz
# Cyclobutane cyclization hit: MR_122908_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_10.xyz
# Cyclobutane cyclization hit: MR_122909_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_11.xyz
# Cyclobutane cyclization hit: MR_127125_2 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_12.xyz
# Cyclobutane cyclization hit: MR_135312_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_13.xyz
# Cyclobutane cyclization hit: MR_136608_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_14.xyz
# Cyclobutane cyclization hit: MR_139445_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_15.xyz
# Cyclobutane cyclization hit: MR_144231_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_16.xyz
# Cyclobutane cyclization hit: MR_150422_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_17.xyz
# Cyclobutane cyclization hit: MR_152793_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_18.xyz
# Cyclobutane cyclization hit: MR_153421_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_19.xyz
# Cyclobutane cyclization hit: MR_154018_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_20.xyz
# Cyclobutane cyclization hit: MR_155886_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_21.xyz
# Cyclobutane cyclization hit: MR_156088_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_22.xyz
# Cyclobutane cyclization hit: MR_158072_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_23.xyz
# Cyclobutane cyclization hit: MR_167452_2 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_24.xyz
# Cyclobutane cyclization hit: MR_171121_2 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_25.xyz
# Cyclobutane cyclization hit: MR_17820_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_26.xyz
# Cyclobutane cyclization hit: MR_178312_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_27.xyz
# Cyclobutane cyclization hit: MR_179347_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_28.xyz
# Cyclobutane cyclization hit: MR_18409_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_29.xyz
# Cyclobutane cyclization hit: MR_18824_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_30.xyz
# Cyclobutane cyclization hit: MR_18840_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_31.xyz
# Cyclobutane cyclization hit: MR_199038_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_32.xyz
# Cyclobutane cyclization hit: MR_200232_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_33.xyz
# Cyclobutane cyclization hit: MR_201519_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_34.xyz
# Cyclobutane cyclization hit: MR_207272_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_35.xyz
# Cyclobutane cyclization hit: MR_215118_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_36.xyz
# Cyclobutane cyclization hit: MR_220718_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_37.xyz
# Cyclobutane cyclization hit: MR_220718_2 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_38.xyz
# Cyclobutane cyclization hit: MR_221522_2 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_39.xyz
# Cyclobutane cyclization hit: MR_222076_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_40.xyz
# Cyclobutane cyclization hit: MR_222390_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_41.xyz
# Cyclobutane cyclization hit: MR_224340_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_42.xyz
# Cyclobutane cyclization hit: MR_227671_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_43.xyz
# Cyclobutane cyclization hit: MR_234258_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_44.xyz
# Cyclobutane cyclization hit: MR_234334_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_45.xyz
# Cyclobutane cyclization hit: MR_235341_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_46.xyz
# Cyclobutane cyclization hit: MR_235341_2 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_47.xyz
# Cyclobutane cyclization hit: MR_237002_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_48.xyz
# Cyclobutane cyclization hit: MR_239728_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_49.xyz
# Cyclobutane cyclization hit: MR_245002_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_50.xyz
# Cyclobutane cyclization hit: MR_246308_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_51.xyz
# Cyclobutane cyclization hit: MR_255919_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_52.xyz
# Cyclobutane cyclization hit: MR_260668_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_53.xyz
# Cyclobutane cyclization hit: MR_261427_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_54.xyz
# Cyclobutane cyclization hit: MR_267503_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_55.xyz
# Cyclobutane cyclization hit: MR_26970_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_56.xyz
# Cyclobutane cyclization hit: MR_273045_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_57.xyz
# Cyclobutane cyclization hit: MR_273045_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_58.xyz
# Cyclobutane cyclization hit: MR_274196_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_59.xyz
# Cyclobutane cyclization hit: MR_284896_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_60.xyz
# Cyclobutane cyclization hit: MR_28971_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_61.xyz
# Cyclobutane cyclization hit: MR_302012_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_62.xyz
# Cyclobutane cyclization hit: MR_305574_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_63.xyz
# Cyclobutane cyclization hit: MR_308478_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_64.xyz
# Cyclobutane cyclization hit: MR_316553_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_65.xyz
# Cyclobutane cyclization hit: MR_318828_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_66.xyz
# Cyclobutane cyclization hit: MR_321040_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_67.xyz
# Cyclobutane cyclization hit: MR_333420_2 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_68.xyz
# Cyclobutane cyclization hit: MR_336405_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_69.xyz
# Cyclobutane cyclization hit: MR_338453_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_70.xyz
# Cyclobutane cyclization hit: MR_343127_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_71.xyz
# Cyclobutane cyclization hit: MR_348210_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_72.xyz
# Cyclobutane cyclization hit: MR_348211_2 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_73.xyz
# Cyclobutane cyclization hit: MR_351523_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_74.xyz
# Cyclobutane cyclization hit: MR_35265_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_75.xyz
# Cyclobutane cyclization hit: MR_354434_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_76.xyz
# Cyclobutane cyclization hit: MR_355598_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_77.xyz
# Cyclobutane cyclization hit: MR_355966_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_78.xyz
# Cyclobutane cyclization hit: MR_357950_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_79.xyz
# Cyclobutane cyclization hit: MR_358921_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_80.xyz
# Cyclobutane cyclization hit: MR_361451_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_81.xyz
# Cyclobutane cyclization hit: MR_361453_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_82.xyz
# Cyclobutane cyclization hit: MR_363186_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_83.xyz
# Cyclobutane cyclization hit: MR_363186_2 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_84.xyz
# Cyclobutane cyclization hit: MR_365351_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_85.xyz
# Cyclobutane cyclization hit: MR_370083_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_86.xyz
# Cyclobutane cyclization hit: MR_373937_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_87.xyz
# Cyclobutane cyclization hit: MR_375803_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_88.xyz
# Cyclobutane cyclization hit: MR_381329_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_89.xyz
# Cyclobutane cyclization hit: MR_387019_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_90.xyz
# Cyclobutane cyclization hit: MR_387735_2 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_91.xyz
# Cyclobutane cyclization hit: MR_389028_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_92.xyz
# Cyclobutane cyclization hit: MR_403066_2 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_93.xyz
# Cyclobutane cyclization hit: MR_404691_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_94.xyz
# Cyclobutane cyclization hit: MR_406532_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_95.xyz
# Cyclobutane cyclization hit: MR_406738_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_96.xyz
# Cyclobutane cyclization hit: MR_410334_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_97.xyz
# Cyclobutane cyclization hit: MR_418845_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_98.xyz
# Cyclobutane cyclization hit: MR_427789_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_99.xyz
# Cyclobutane cyclization hit: MR_427789_2 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_100.xyz
# Cyclobutane cyclization hit: MR_430013_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_101.xyz
# Cyclobutane cyclization hit: MR_432402_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_102.xyz
# Cyclobutane cyclization hit: MR_432631_2 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_103.xyz
# Cyclobutane cyclization hit: MR_433167_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_104.xyz
# Cyclobutane cyclization hit: MR_433172_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_105.xyz
# Cyclobutane cyclization hit: MR_433172_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_106.xyz
# Cyclobutane cyclization hit: MR_437826_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_107.xyz
# Cyclobutane cyclization hit: MR_440850_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_108.xyz
# Cyclobutane cyclization hit: MR_442731_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_109.xyz
# Cyclobutane cyclization hit: MR_44742_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_110.xyz
# Cyclobutane cyclization hit: MR_447966_2 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_111.xyz
# Cyclobutane cyclization hit: MR_458272_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_112.xyz
# Cyclobutane cyclization hit: MR_461601_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_113.xyz
# Cyclobutane cyclization hit: MR_462629_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_114.xyz
# Cyclobutane cyclization hit: MR_463002_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_115.xyz
# Cyclobutane cyclization hit: MR_467204_2 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_116.xyz
# Cyclobutane cyclization hit: MR_468818_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_117.xyz
# Cyclobutane cyclization hit: MR_474050_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_118.xyz
# Cyclobutane cyclization hit: MR_474050_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_119.xyz
# Cyclobutane cyclization hit: MR_474050_2 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_120.xyz
# Cyclobutane cyclization hit: MR_479701_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_121.xyz
# Cyclobutane cyclization hit: MR_486968_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_122.xyz
# Cyclobutane cyclization hit: MR_490220_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_123.xyz
# Cyclobutane cyclization hit: MR_492948_2 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_124.xyz
# Cyclobutane cyclization hit: MR_494715_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_125.xyz
# Cyclobutane cyclization hit: MR_502238_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_126.xyz
# Cyclobutane cyclization hit: MR_505879_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_127.xyz
# Cyclobutane cyclization hit: MR_505905_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_128.xyz
# Cyclobutane cyclization hit: MR_508080_2 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_129.xyz
# Cyclobutane cyclization hit: MR_515268_2 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_130.xyz
# Cyclobutane cyclization hit: MR_515586_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_131.xyz
# Cyclobutane cyclization hit: MR_520231_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_132.xyz
# Cyclobutane cyclization hit: MR_520970_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_133.xyz
# Cyclobutane cyclization hit: MR_526874_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_134.xyz
# Cyclobutane cyclization hit: MR_529902_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_135.xyz
# Cyclobutane cyclization hit: MR_535145_2 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_136.xyz
# Cyclobutane cyclization hit: MR_537440_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_137.xyz
# Cyclobutane cyclization hit: MR_540566_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_138.xyz
# Cyclobutane cyclization hit: MR_54089_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_139.xyz
# Cyclobutane cyclization hit: MR_54089_2 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_140.xyz
# Cyclobutane cyclization hit: MR_544062_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_141.xyz
# Cyclobutane cyclization hit: MR_554255_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_142.xyz
# Cyclobutane cyclization hit: MR_555865_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_143.xyz
# Cyclobutane cyclization hit: MR_56335_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_144.xyz
# Cyclobutane cyclization hit: MR_56335_2 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_145.xyz
# Cyclobutane cyclization hit: MR_566557_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_146.xyz
# Cyclobutane cyclization hit: MR_566872_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_147.xyz
# Cyclobutane cyclization hit: MR_567934_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_148.xyz
# Cyclobutane cyclization hit: MR_568848_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_149.xyz
# Cyclobutane cyclization hit: MR_576192_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_150.xyz
# Cyclobutane cyclization hit: MR_579446_2 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_151.xyz
# Cyclobutane cyclization hit: MR_583756_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_152.xyz
# Cyclobutane cyclization hit: MR_584149_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_153.xyz
# Cyclobutane cyclization hit: MR_584149_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_154.xyz
# Cyclobutane cyclization hit: MR_584149_2 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_155.xyz
# Cyclobutane cyclization hit: MR_59886_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_156.xyz
# Cyclobutane cyclization hit: MR_601892_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_157.xyz
# Cyclobutane cyclization hit: MR_609219_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_158.xyz
# Cyclobutane cyclization hit: MR_611454_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_159.xyz
# Cyclobutane cyclization hit: MR_616727_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_160.xyz
# Cyclobutane cyclization hit: MR_619111_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_161.xyz
# Cyclobutane cyclization hit: MR_622494_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_162.xyz
# Cyclobutane cyclization hit: MR_628344_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_163.xyz
# Cyclobutane cyclization hit: MR_636008_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_164.xyz
# Cyclobutane cyclization hit: MR_636696_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_165.xyz
# Cyclobutane cyclization hit: MR_639426_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_166.xyz
# Cyclobutane cyclization hit: MR_639426_2 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_167.xyz
# Cyclobutane cyclization hit: MR_640408_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_168.xyz
# Cyclobutane cyclization hit: MR_645006_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_169.xyz
# Cyclobutane cyclization hit: MR_645006_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_170.xyz
# Cyclobutane cyclization hit: MR_647424_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_171.xyz
# Cyclobutane cyclization hit: MR_64746_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_172.xyz
# Cyclobutane cyclization hit: MR_64746_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_173.xyz
# Cyclobutane cyclization hit: MR_67155_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_174.xyz
# Cyclobutane cyclization hit: MR_671688_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_175.xyz
# Cyclobutane cyclization hit: MR_673756_2 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_176.xyz
# Cyclobutane cyclization hit: MR_683412_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_177.xyz
# Cyclobutane cyclization hit: MR_690669_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_178.xyz
# Cyclobutane cyclization hit: MR_691416_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_179.xyz
# Cyclobutane cyclization hit: MR_697053_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_180.xyz
# Cyclobutane cyclization hit: MR_697079_2 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_181.xyz
# Cyclobutane cyclization hit: MR_698981_2 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_182.xyz
# Cyclobutane cyclization hit: MR_701034_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_183.xyz
# Cyclobutane cyclization hit: MR_704643_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_184.xyz
# Cyclobutane cyclization hit: MR_74725_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_185.xyz
# Cyclobutane cyclization hit: MR_74758_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_186.xyz
# Cyclobutane cyclization hit: MR_75310_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_187.xyz
# Cyclobutane cyclization hit: MR_80753_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_188.xyz
# Cyclobutane cyclization hit: MR_81235_2 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_189.xyz
# Cyclobutane cyclization hit: MR_8125_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_190.xyz
# Cyclobutane cyclization hit: MR_83727_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_191.xyz
# Cyclobutane cyclization hit: MR_86675_1 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_192.xyz
# Cyclobutane cyclization hit: MR_88337_0 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_193.xyz
# Cyclobutane cyclization hit: MR_88337_2 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_194.xyz
# Cyclobutane cyclization hit: MR_96308_2 -> cyclobutane_cyclization_extxyz/cyclobutane_cyclization_195.xyz
# Total cyclobutane cyclizations: 196

# %%
'''
import os
import torch
import numpy as np
from sklearn.preprocessing import OneHotEncoder
from rdkit import Chem
from rdkit.Chem import rdMolDescriptors
from ase import Atoms
from ase.io import write

class RGD1TorchLoaderDict:
    """
    Loads an RGD1 dataset saved as a torch checkpoint (a list of Data objects),
    and yields reactions as dicts in the same format as the original HDF5-based loader.
    """
    def __init__(self, checkpoint_path, device='cpu'):
        # Load your list of Data objects
        self.data_list = torch.load(checkpoint_path, map_location=device, weights_only=False)
        # Reconstruct the atom encoder to invert one-hot back to Z
        self.atom_types = np.array([1, 6, 7, 8])  # H, C, N, O
        self.encoder = OneHotEncoder(sparse_output=False)
        self.encoder.fit(self.atom_types.reshape(-1, 1))
    
    def __len__(self):
        return len(self.data_list)
    
    def __iter__(self):
        for data in self.data_list:
            yield self._to_reaction_dict(data)
    
    def __getitem__(self, idx):
        return self._to_reaction_dict(self.data_list[idx])
    
    def _decode_atomic_numbers(self, z_tensor):
        # z_tensor: (N, 5) padded one-hot
        z = z_tensor.cpu().numpy()
        # only first len(atom_types) columns contain the one-hot
        one_hot = z[:, :len(self.atom_types)]
        idxs = one_hot.argmax(axis=1)
        return self.atom_types[idxs].tolist()
    
    def _to_reaction_dict(self, data):
        react = {
            'smiles':            data.formula_reactant,
            'atomic_numbers':    self._decode_atomic_numbers(data.z_reactant),
            'positions':         data.pos_reactant.cpu().numpy(),
            'energy':            data.E_reactant.item(),
        }
        ts = {
            'smiles':            data.formula_transition_state,
            'atomic_numbers':    self._decode_atomic_numbers(data.z_transition_state),
            'positions':         data.pos_transition_state.cpu().numpy(),
            'energy':            data.E_transition_state.item(),
        }
        prod = {
            'smiles':            data.formula_product,
            'atomic_numbers':    self._decode_atomic_numbers(data.z_product),
            'positions':         data.pos_product.cpu().numpy(),
            'energy':            data.E_product.item(),
        }
        return {
            'rxn_id':            data.rxn,
            'reactant':          react,
            'transition_state':  ts,
            'product':           prod
        }

# SMARTS patterns and detectors
PATTERNS = {
    # 'claisen': {
    #     'reactant': Chem.MolFromSmarts('[#6]=[#6]-[#6]-O-[#6]'),
    #     'product':  Chem.MolFromSmarts('[#6]-[#6]=[#6]-C(=O)[#6]')
    # },
    'cope': {
        'reactant': Chem.MolFromSmarts('[#6]=[#6]-[#6]-[#6]-[#6]=[#6]'),
        'product':  Chem.MolFromSmarts('[#6]=[#6]-[#6]-[#6]-[#6]=[#6]')
    },
    # 'pinacol': {
    #     'reactant': Chem.MolFromSmarts('C([OX2H])[C;!H0]([OX2H])'),
    #     'product':  Chem.MolFromSmarts('C(=O)C([OX2H])')
    # },
    # 'wagner_meerwein': {
    #     'reactant': None,
    #     'product':  None
    # }
}

'''
